# %%
import gym
from scipy.special import expit as sigmoid
import numpy as np
import numpy.random as npr
import time
from itertools import count
from collections import deque
import matplotlib.pyplot as plt
from a2c_ppo_acktr import utils

from layer import Layer

# %%
class args(object):
    num_hidden = 8
    bandwidth = 3
    eval_interval = None
    log_interval = 250
    use_gae = False
    num_updates = 1e5
    num_steps = 10
    memory_capacity = num_steps
    ppo_epoch = 1
    num_mini_batch = 10
    value_loss_coef = 0.5
    entropy_coef = 0.01
    lr = 1e-3
    lbfgs_history = 1000
    max_grad_norm = 0.005
    clip_param = 0.005
    gamma = 0.99
    gae_lambda = 0.95
    use_proper_time_limits = False

# %%
env = gym.make('CartPole-v0')
input = Layer(4, 1, args.bandwidth, post_width=args.num_hidden, args=args, post_process=None)
hidden = Layer(args.num_hidden, args.bandwidth, args.bandwidth, post_width=1, args=args, post_process=None)
output = Layer(1, args.bandwidth, 1, post_process=sigmoid, args=args)
# Out:
# /home/f1ery/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
episode_rewards = deque(maxlen=args.log_interval)
done = True

for j in count(len(input.units[0].action_losses) + 1):
    input.clear_memory()
    hidden.clear_memory()
    output.clear_memory()
    if done:
        state = env.reset()
        episode_rewards.append(0)
        input.reset()
        hidden.reset()
        output.reset()
    for unit in input.units + hidden.units + output.units:
        utils.update_linear_schedule(unit.agent.optimizer, j, args.num_updates, args.lr)
    for step in range(args.num_steps):
        action = output(hidden(input([state[i:i+1] for i in range(4)])))[0][0]
        action = int(action > 0.5)
        state, reward, done, info = env.step(action)
        input.reward(reward)
        hidden.reward(reward)
        output.reward(reward)
        episode_rewards[-1] += reward
        if done:
            input.done()
            hidden.done()
            output.done()
    input.update()
    hidden.update()
    output.update()
    if j % args.log_interval == 0:
        print('Iter: %d, Avg/Max/Min. reward: %0.1f/%0.1f/%0.1f' % (j, sum(episode_rewards)/len(episode_rewards), max(episode_rewards), min(episode_rewards)))
# Out:
# Iter: 65750, Avg/Max/Min. reward: 20.8/48.0/9.0
# Iter: 66000, Avg/Max/Min. reward: 21.9/72.0/9.0
# Iter: 66250, Avg/Max/Min. reward: 22.4/81.0/8.0
# Iter: 66500, Avg/Max/Min. reward: 22.8/91.0/8.0
# Iter: 66750, Avg/Max/Min. reward: 22.6/91.0/9.0
# Iter: 67000, Avg/Max/Min. reward: 22.1/91.0/8.0
# Iter: 67250, Avg/Max/Min. reward: 21.6/72.0/8.0
# Iter: 67500, Avg/Max/Min. reward: 21.5/69.0/8.0
# Iter: 67750, Avg/Max/Min. reward: 21.9/67.0/8.0
# Iter: 68000, Avg/Max/Min. reward: 22.3/67.0/8.0
# Iter: 68250, Avg/Max/Min. reward: 22.6/73.0/8.0
# Iter: 68500, Avg/Max/Min. reward: 22.7/73.0/8.0
# Iter: 68750, Avg/Max/Min. reward: 22.8/83.0/8.0
# Iter: 69000, Avg/Max/Min. reward: 22.9/83.0/9.0
# Iter: 69250, Avg/Max/Min. reward: 22.5/99.0/9.0
# Iter: 69500, Avg/Max/Min. reward: 22.6/99.0/9.0
# Iter: 69750, Avg/Max/Min. reward: 22.4/105.0/9.0
# Iter: 70000, Avg/Max/Min. reward: 22.3/105.0/9.0
# Iter: 70250, Avg/Max/Min. reward: 22.1/105.0/9.0
# Iter: 70500, Avg/Max/Min. reward: 22.3/76.0/9.0
# Iter: 70750, Avg/Max/Min. reward: 21.8/73.0/9.0
# Iter: 71000, Avg/Max/Min. reward: 21.5/67.0/9.0
# Iter: 71250, Avg/Max/Min. reward: 22.3/65.0/9.0
# Iter: 71500, Avg/Max/Min. reward: 22.8/70.0/9.0
# Iter: 71750, Avg/Max/Min. reward: 22.3/70.0/8.0
# Iter: 72000, Avg/Max/Min. reward: 22.5/83.0/8.0
# Iter: 72250, Avg/Max/Min. reward: 23.5/123.0/8.0
# Iter: 72500, Avg/Max/Min. reward: 23.1/123.0/9.0
# Iter: 72750, Avg/Max/Min. reward: 22.1/90.0/9.0
# Iter: 73000, Avg/Max/Min. reward: 21.7/90.0/9.0
# Iter: 73250, Avg/Max/Min. reward: 22.4/110.0/9.0
# Iter: 73500, Avg/Max/Min. reward: 22.9/110.0/9.0
# Iter: 73750, Avg/Max/Min. reward: 23.1/110.0/9.0
# Iter: 74000, Avg/Max/Min. reward: 23.7/77.0/9.0
# Iter: 74250, Avg/Max/Min. reward: 24.0/76.0/8.0
# Iter: 74500, Avg/Max/Min. reward: 22.8/68.0/8.0
# Iter: 74750, Avg/Max/Min. reward: 22.4/84.0/8.0
# Iter: 75000, Avg/Max/Min. reward: 21.9/84.0/9.0
# Iter: 75250, Avg/Max/Min. reward: 23.0/93.0/8.0
# Iter: 75500, Avg/Max/Min. reward: 22.0/93.0/8.0
# Iter: 75750, Avg/Max/Min. reward: 21.5/66.0/8.0
# Iter: 76000, Avg/Max/Min. reward: 21.8/71.0/9.0
# Iter: 76250, Avg/Max/Min. reward: 22.7/92.0/8.0
# Iter: 76500, Avg/Max/Min. reward: 22.7/92.0/8.0
# Iter: 76750, Avg/Max/Min. reward: 21.7/65.0/9.0
# Iter: 77000, Avg/Max/Min. reward: 22.5/67.0/9.0
# Iter: 77250, Avg/Max/Min. reward: 22.2/67.0/8.0
# Iter: 77500, Avg/Max/Min. reward: 21.4/64.0/8.0
# Iter: 77750, Avg/Max/Min. reward: 21.6/64.0/8.0
# Iter: 78000, Avg/Max/Min. reward: 21.4/58.0/9.0
# Iter: 78250, Avg/Max/Min. reward: 22.4/63.0/9.0
# Iter: 78500, Avg/Max/Min. reward: 22.4/63.0/9.0
# Iter: 78750, Avg/Max/Min. reward: 22.1/63.0/8.0
# Iter: 79000, Avg/Max/Min. reward: 22.2/101.0/8.0
# Iter: 79250, Avg/Max/Min. reward: 21.6/101.0/9.0
# Iter: 79500, Avg/Max/Min. reward: 22.1/101.0/9.0
# Iter: 79750, Avg/Max/Min. reward: 21.9/67.0/9.0
# Iter: 80000, Avg/Max/Min. reward: 22.0/96.0/9.0
# Iter: 80250, Avg/Max/Min. reward: 22.2/96.0/9.0
# Iter: 80500, Avg/Max/Min. reward: 21.9/96.0/9.0
# Iter: 80750, Avg/Max/Min. reward: 22.1/75.0/9.0
# Iter: 81000, Avg/Max/Min. reward: 22.6/87.0/9.0
# Iter: 81250, Avg/Max/Min. reward: 22.6/87.0/9.0
# Iter: 81500, Avg/Max/Min. reward: 23.4/87.0/9.0
# Iter: 81750, Avg/Max/Min. reward: 22.5/58.0/8.0
# Iter: 82000, Avg/Max/Min. reward: 21.6/71.0/8.0
# Iter: 82250, Avg/Max/Min. reward: 21.4/78.0/9.0
# Iter: 82500, Avg/Max/Min. reward: 22.0/78.0/9.0
# Iter: 82750, Avg/Max/Min. reward: 21.7/70.0/9.0
# Iter: 83000, Avg/Max/Min. reward: 22.1/78.0/9.0
# Iter: 83250, Avg/Max/Min. reward: 23.2/81.0/8.0
# Iter: 83500, Avg/Max/Min. reward: 24.3/81.0/8.0
# Iter: 83750, Avg/Max/Min. reward: 23.0/81.0/8.0
# Iter: 84000, Avg/Max/Min. reward: 23.0/80.0/8.0
# Iter: 84250, Avg/Max/Min. reward: 21.9/66.0/8.0
# Iter: 84500, Avg/Max/Min. reward: 22.5/69.0/8.0
# Iter: 84750, Avg/Max/Min. reward: 22.9/69.0/8.0
# Iter: 85000, Avg/Max/Min. reward: 22.5/69.0/8.0
# Iter: 85250, Avg/Max/Min. reward: 21.6/61.0/8.0
# Iter: 85500, Avg/Max/Min. reward: 21.2/61.0/8.0
# Iter: 85750, Avg/Max/Min. reward: 22.6/61.0/9.0
# Iter: 86000, Avg/Max/Min. reward: 22.7/85.0/9.0
# Iter: 86250, Avg/Max/Min. reward: 21.9/103.0/9.0
# Iter: 86500, Avg/Max/Min. reward: 22.1/103.0/9.0
# Iter: 86750, Avg/Max/Min. reward: 22.2/62.0/9.0
# Iter: 87000, Avg/Max/Min. reward: 23.6/77.0/9.0
# Iter: 87250, Avg/Max/Min. reward: 21.9/77.0/9.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-abccd3a21502> in <module>
#      27             output.done()
#      28     input.update()
# ---> 29     hidden.update()
#      30     output.update()
#      31     if j % args.log_interval == 0:
#
# ~/cascade_rl/on_policy/layer.py in update(self)
#      74         for unit in self.units:
#      75             if unit.memory.step > 2:
# ---> 76                 unit.update()
#      77
#      78     def clear_memory(self):
#
# ~/cascade_rl/on_policy/unit.py in update(self)
#
# ~/cascade_rl/on_policy/a2c_ppo_acktr/algo/ppo.py in update(self, rollouts)
#      88         num_updates = self.ppo_epoch * self.num_mini_batch
#      89
# ---> 90         value_loss_epoch /= num_updates
#      91         action_loss_epoch /= num_updates
#      92         dist_entropy_epoch /= num_updates
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/lbfgs.py in step(self, closure)
#     375                 q = flat_grad.neg()
#     376                 for i in range(num_old - 1, -1, -1):
# --> 377                     al[i] = old_stps[i].dot(q) * ro[i]
#     378                     q.add_(-al[i], old_dirs[i])
#     379
#
# KeyboardInterrupt:

# %%
print('INPUTS')
input.plot_stats(n=10000)
print('HIDDEN')
hidden.plot_stats(n=10000)
print('OUTPUTS')
output.plot_stats(n=10000)
# Out:
# INPUTS
# HIDDEN
# OUTPUTS
