# %%
import gym
from scipy.special import expit as sigmoid
import numpy as np
import numpy.random as npr
import time
from itertools import count
from collections import deque
import matplotlib.pyplot as plt
from a2c_ppo_acktr import utils
import random
from tqdm import trange

from heap import Heap

# %%
import torch

def save(heap, fname='heap.pth'):
    heap_dict = {
        'num_units' : heap.num_units,
        'num_inputs' : heap.num_inputs,
        'num_outputs' : heap.num_outputs,
        'num_hidden' : heap.num_hidden,
        'threshold' : heap.threshold,
        'slip_reward' : heap.slip_reward,
        'signal_split' : heap.signal_split,
        'postwidth' : heap.postwidth,
        'bandwidth' : heap.bandwidth,
        'gamma' : heap.gamma,
        'num_mini_batch' : heap.num_mini_batch,
        'distance_edge' : heap.distance_edge,
        'post_process' : heap.post_process,
        #'discount_mode' : heap.discount_mode,
        'universal_critic_state' : heap.critic.state_dict(),
        'postcodes' : heap.postcodes,
        'units' : []
    }
    for unit in heap.units:
        unit_dict = {
            'num_inputs' : unit.num_inputs,
            'action_space' : unit.action_space,
            #'recurrent' : unit.actor_critic.recurrent,
            'actor_critic_state' : unit.actor_critic.state_dict()
        }
        heap_dict['units'].append(unit_dict)
    torch.save(heap_dict, fname)

# %%
def load(heap, fname='heap.pth'):
    heap_dict = torch.load(fname)
    heap.num_units = heap_dict['num_units']
    heap.num_inputs = heap_dict['num_inputs']
    heap.num_outputs = heap_dict['num_outputs']
    heap.num_hidden = heap_dict['num_hidden']
    heap.threshold = heap_dict['threshold']
    heap.slip_reward = heap_dict['slip_reward']
    heap.signal_split = heap_dict['signal_split']
    heap.postwidth = heap_dict['postwidth']
    heap.bandwidth = heap_dict['bandwidth']
    heap.gamma = heap_dict['gamma']
    heap.num_mini_batch = heap_dict['num_mini_batch']
    heap.distance_edge = heap_dict['distance_edge']
    heap.post_process = heap_dict['post_process']
    heap.critic.load_state_dict(heap_dict['universal_critic_state'])
    heap.postcodes = heap_dict['postcodes']
    heap.build_index()
    heap.build_units(args, env.action_space)
    for unit, unit_dict in zip(heap.units, heap_dict['units']):
        unit.num_inputs = unit_dict['num_inputs']
        unit.action_space = unit_dict['action_space']
        unit.actor_critic.load_state_dict(unit_dict['actor_critic_state'])

# %%
new_heap = Heap(4, 25, 1, env.action_space, args=args, post_process=None)

# %%
load(new_heap)

# %%
save(heap)

# %%
class args(object):
    bandwidth = 3
    postwidth = 3
    critic_hidden = 128
    threshold = 0.1
    slip_reward = 0
    signal_split = 1
    fps = 25
    log_interval = 10
    use_gae = False
    num_updates = 1e4
    num_steps = 1000
    sleep_freq = 0
    sleep_skip = False
    memory_capacity = 1
    ppo_epoch = 4
    num_mini_batch = 2
    value_loss_coef = 0.5
    entropy_coef = 0.01
    lr = 1e-4
    eps = 1e-5
    alpha = 0.99
    max_grad_norm = 0.2
    clip_param = 0.2
    gamma = 0.99
    gae_lambda = 0.95
    distance_edge = float('inf')
    discount_mode = 'parallel'
    use_proper_time_limits = False

# %%
env = gym.make('CartPole-v0')
heap = Heap(4, 25, 1, env.action_space, args=args, post_process=None)
# Out:
# /home/f1ery/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
heap.postcodes
# Out:
# [array([0.88049395, 0.24879927, 0.4962853 ]),
#  array([0.36319587, 0.44909645, 0.4812445 ]),
#  array([0.8012941 , 0.40712345, 0.51952647]),
#  array([0.6382476 , 0.21465426, 0.97219233]),
#  array([0.15519029, 0.68784865, 0.66740363]),
#  array([0.21699529, 0.28839173, 0.77657846]),
#  array([0.40426036, 0.38362789, 0.0790857 ]),
#  array([0.17667224, 0.82867109, 0.13442391]),
#  array([1.14899765e-01, 1.59676273e-05, 5.10038052e-02]),
#  array([0.5069343 , 0.39941502, 0.99408042]),
#  array([0.44873648, 0.01237318, 0.32011609]),
#  array([0.16115999, 0.82440548, 0.16145873]),
#  array([0.13001093, 0.22544805, 0.22944771]),
#  array([0.15186261, 0.60109718, 0.19566396]),
#  array([0.8057939 , 0.34381149, 0.53598086]),
#  array([0.61202674, 0.57088441, 0.30815133]),
#  array([0.19828473, 0.24122012, 0.10965283]),
#  array([0.23811307, 0.63988475, 0.30893135]),
#  array([0.94181396, 0.35816738, 0.19019809]),
#  array([0.63961646, 0.15259721, 0.96743683]),
# ...

# %%
pc = np.array(heap.postcodes)

# %%
np.mean(np.sqrt(np.sum((pc[:, np.newaxis] - pc[np.newaxis, :])**2, axis=-1)))
# Out:
# 0.6135753874634045

# %%
episode_rewards = deque(maxlen=int(args.log_interval*args.num_steps/20))
episode_relaxes = deque(maxlen=int(args.log_interval*args.num_steps/20))
fpses = deque(maxlen=500)
done = True

eval_rewards = []
eval_relaxes = []
eval_fps = []
for i in trange(250):
    heap.reset()
    heap.clear_memory()
    state = env.reset()
    _done = False
    eval_rewards.append(0)
    eval_relaxes.append(0)
    while not _done:
        action, fps = heap(state, n=args.fps)
        eval_fps.append(fps)
        if action:
            action = int(action[0] > 0.5)
        else:
            eval_relaxes[-1] += 1
            break
        state, reward, _done, _ = env.step(action)
        eval_rewards[-1] += reward
print('Eval Avg/Max/Min. reward: %0.1f/%0.1f/%0.1f, Avg relaxation: %0.2f, Avg FPS: %0.2f' % (sum(eval_rewards)/len(eval_rewards), max(eval_rewards), min(eval_rewards), sum(eval_relaxes)/len(eval_relaxes), sum(eval_fps)/len(eval_fps)))

for j in count(2392):
    #for unit in heap.units:
    #    utils.update_linear_schedule(unit.agent.optimizer, j, args.num_updates, args.lr)
    heap.clear_memory()
    step = 0
    while step < args.num_steps:
        if done:
            state = env.reset()
            episode_rewards.append(0)
            episode_relaxes.append(0)
            heap.reset()
            done = False
        while not done:
            out_action, fps = heap(state, n=args.fps)
            fpses.append(fps)
            if out_action:
                action = int(out_action[0] > 0.5)
            else:
                episode_relaxes[-1] += 1
                heap.done()
                done = True
                break
            state, reward, done, info = env.step(action)
            heap.reward(reward)
            episode_rewards[-1] += reward
            if done:
                if episode_rewards[-1] < 200:
                    heap.done()
                break
            step += 1
    print(j, round(sum(episode_rewards)/len(episode_rewards), 2), round(sum(fpses)/len(fpses), 2))
    heap.update(state)
    if j % args.log_interval == 0:
        done = True
        eval_rewards = []
        eval_relaxes = []
        eval_fps = []
        for i in trange(250):
            heap.reset()
            heap.clear_memory()
            state = env.reset()
            _done = False
            eval_rewards.append(0)
            eval_relaxes.append(0)
            while not _done:
                action, fps = heap(state, n=args.fps)
                eval_fps.append(fps)
                if action:
                    action = int(action[0] > 0.5)
                else:
                    eval_relaxes[-1] += 1
                    break
                state, reward, _done, _ = env.step(action)
                eval_rewards[-1] += reward
        print('Iter: %d, Avg/Max/Min. reward: %0.1f/%0.1f/%0.1f, Avg relaxation: %0.2f, Avg FPS: %0.2f\nEval Avg/Max/Min. reward: %0.1f/%0.1f/%0.1f, Avg relaxation: %0.2f, Avg FPS: %0.2f' % (j, sum(episode_rewards)/len(episode_rewards), max(episode_rewards), min(episode_rewards), sum(episode_relaxes)/len(episode_relaxes), sum(fpses)/len(fpses), sum(eval_rewards)/len(eval_rewards), max(eval_rewards), min(eval_rewards), sum(eval_relaxes)/len(eval_relaxes), sum(eval_fps)/len(eval_fps)))
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
#
#   0%|          | 1/250 [00:01<07:52,  1.90s/it]
#
#   1%|          | 2/250 [00:02<06:29,  1.57s/it]
#
#   1%|          | 3/250 [00:04<06:57,  1.69s/it]
#
#   2%|▏         | 4/250 [00:05<06:06,  1.49s/it]
#
#   2%|▏         | 5/250 [00:07<06:58,  1.71s/it]
#
#   2%|▏         | 6/250 [00:09<06:27,  1.59s/it]
#
#   3%|▎         | 7/250 [00:10<05:32,  1.37s/it]
#
#   3%|▎         | 8/250 [00:10<04:33,  1.13s/it]
#
#   4%|▎         | 9/250 [00:11<03:55,  1.02it/s]
#
#   4%|▍         | 10/250 [00:11<03:20,  1.20it/s]
#
#   4%|▍         | 11/250 [00:13<04:56,  1.24s/it]
#
#   5%|▍         | 12/250 [00:14<03:54,  1.01it/s]
#
#   5%|▌         | 13/250 [00:15<03:50,  1.03it/s]
#
#   6%|▌         | 14/250 [00:15<03:26,  1.14it/s]
#
#   6%|▌         | 15/250 [00:17<03:58,  1.02s/it]
#
#   6%|▋         | 16/250 [00:19<04:51,  1.25s/it]
#
#   7%|▋         | 17/250 [00:20<04:40,  1.20s/it]
#
#   7%|▋         | 18/250 [00:21<04:57,  1.28s/it]
#
# ...

# %%
import matplotlib.pyplot as plt

new_heap.reset()
new_heap.clear_memory()
state = env.reset()
i = 0
while True:
    action, fps = new_heap(state, n=args.fps)
    if action:
        action = int(action[0] > 0.5)
    else:
        break
    state, reward, _done, _ = env.step(action)
    if _done:
        break
    i += 1
    print(i, fps, new_heap.unit_actions)
# Out:
# 1 0 [(4, 9, array([0.35747653, 0.24767172, 0.39485177], dtype=float32))]
# 2 0 [(9, 14, array([0.40581697, 0.32526523, 0.26891774], dtype=float32))]
# 3 0 [(14, 29, array([0.32814097, 0.3533068 , 0.31855232], dtype=float32)), (15, 29, array([0.30447444, 0.3744785 , 0.32104707], dtype=float32))]
# 4 0 []
# 5 0 [(17, 29, array([0.38805425, 0.2873923 , 0.32455355], dtype=float32))]
# 6 0 []
# 7 0 [(17, 29, array([0.36445856, 0.33875984, 0.29678163], dtype=float32))]
# 8 0 [(15, 29, array([0.2427329 , 0.4556964 , 0.30157086], dtype=float32))]
# 9 0 []
# 10 0 [(14, 29, array([0.3414295 , 0.3705915 , 0.28797904], dtype=float32))]
# 11 0 [(15, 29, array([0.18440491, 0.49748638, 0.31810874], dtype=float32))]
# 12 0 []
# 13 0 [(23, 29, array([0.40122876, 0.39142916, 0.20734216], dtype=float32))]
# 14 0 []
# 15 0 [(15, 29, array([0.29311013, 0.39437282, 0.31251708], dtype=float32))]
# 16 0 []
# 17 0 [(15, 29, array([0.27926245, 0.30437222, 0.41636539], dtype=float32))]
# 18 0 []
# ...

# %%
n = 100
heap.plot_stats(n=n)
# Out:
# INPUTS
# HIDDEN
# OUTPUTS

# %%
for (id, act, obs) in zip(heap.memory.unit_ids, heap.memory.actions, heap.memory.obs):
    from_vec = obs[:3].numpy()
    if np.all(from_vec == 0):
        from_id = 'env'
    else:
        if np.sum((from_vec - heap.postcodes[0])**2) < 1e-5:
            from_id = 0
        elif np.sum((from_vec - heap.postcodes[1])**2) < 1e-5:
            from_id = 1
        elif np.sum((from_vec - heap.postcodes[2])**2) < 1e-5:
            from_id = 2
        elif np.sum((from_vec - heap.postcodes[3])**2) < 1e-5:
            from_id = 3
        else:
            from_id = heap.index.get_nns_by_vector(from_vec, n=1)[0]
    to_vec = act[1:4].numpy()
    did_act = '+'
    if np.all(to_vec == 0) or np.all(to_vec == 1):
        to_id = 'env'
    else:
        to_id = heap.index.get_nns_by_vector(to_vec, n=1)[0]
        if act[0] < 0.1:
            did_act = '-'
    print(from_id, '->', id, '->', to_id, did_act)
# Out:
# env -> 0 -> 29 +
# env -> 1 -> 29 +
# env -> 2 -> 29 +
# env -> 3 -> 29 +
# 0 -> 29 -> env +
# 1 -> 29 -> env +
# 2 -> 29 -> env +
# 3 -> 29 -> env +
# env -> 0 -> 29 +
# env -> 1 -> 29 +
# env -> 2 -> 29 +
# env -> 3 -> 15 +
# 0 -> 29 -> env +
# 1 -> 29 -> env +
# 2 -> 29 -> env +
# 3 -> 15 -> 29 +
# env -> 0 -> 29 +
# env -> 1 -> 29 +
# env -> 2 -> 29 +
# env -> 3 -> 29 +
# 15 -> 29 -> env +
# 0 -> 29 -> env +
# 1 -> 29 -> env +
# 2 -> 29 -> env +
# 3 -> 29 -> env +
# env -> 0 -> 29 +
# env -> 1 -> 29 +
# env -> 2 -> 29 +
# env -> 3 -> 29 +
# 0 -> 29 -> env +
# 1 -> 29 -> env +
# 2 -> 29 -> env +
# 3 -> 29 -> env +
# env -> 0 -> 29 +
# env -> 1 -> 29 +
# env -> 2 -> 29 +
# env -> 3 -> 28 +
# 0 -> 29 -> env +
# 1 -> 29 -> env +
# 2 -> 29 -> env +
# 3 -> 28 -> 14 +
# env -> 0 -> 29 +
# env -> 1 -> 29 +
# env -> 2 -> 29 +
# env -> 3 -> 29 +
# 28 -> 14 -> 10 +
# 0 -> 29 -> env +
# 1 -> 29 -> env +
# 2 -> 29 -> env +
# 3 -> 29 -> env +
# env -> 0 -> 29 +
# env -> 1 -> 29 +
# ...
