# %%
import gym
from scipy.special import expit as sigmoid
import numpy as np
import numpy.random as npr
import time
from itertools import count
from collections import deque
import matplotlib.pyplot as plt
from a2c_ppo_acktr import utils

from layer import Layer

# %%
class args(object):
    num_hidden = 8
    bandwidth = 3
    eval_interval = None
    log_interval = 10
    use_gae = False
    num_updates = 1e5
    num_steps = 32
    clip_param = 0.2
    ppo_epoch = 4
    num_mini_batch = 32
    value_loss_coef = 0.5
    entropy_coef = 0.01
    lr = 1e-8
    eps = 1e-5
    max_grad_norm = 0.2
    gamma = 0.99
    gae_lambda = 0.95
    use_proper_time_limits = False

# %%
env = gym.make('CartPole-v0')
input = Layer(4, 1, args.bandwidth, post_width=args.num_hidden, args=args, post_process=None)
hidden = Layer(args.num_hidden, args.bandwidth, args.bandwidth, post_width=1, args=args, post_process=None)
output = Layer(1, args.bandwidth, 1, post_process=sigmoid, args=args)
# Out:
# /home/f1ery/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
episode_rewards = deque(maxlen=10)
done = True

for j in count(1):
    input.clear_memory()
    hidden.clear_memory()
    output.clear_memory()
    if done:
        state = env.reset()
        episode_rewards.append(0)
    for unit in input.units + hidden.units + output.units:
        utils.update_linear_schedule(unit.agent.optimizer, j, args.num_updates, args.lr)
    for step in range(args.num_steps):
        action = output(hidden(input([state[i:i+1] for i in range(4)])))[0][0]
        action = int(action > 0.5)
        state, reward, done, info = env.step(action)
        episode_rewards[-1] += reward
        if done:
            input.done()
            hidden.done()
            output.done()
    input.update()
    hidden.update()
    output.update()
    print('Iter: %d, Avg/Max/Min. reward: %0.2f/%0.2f/%0.2f' % (j, sum(episode_rewards)/len(episode_rewards), max(episode_rewards), min(episode_rewards)))
# Out:
# /home/f1ery/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Iter: 1, Avg/Max/Min. reward: 14.00/14.00/14.00
# Iter: 2, Avg/Max/Min. reward: 13.00/14.00/12.00
# Iter: 3, Avg/Max/Min. reward: 12.00/14.00/10.00
# Iter: 4, Avg/Max/Min. reward: 14.75/23.00/10.00
# Iter: 5, Avg/Max/Min. reward: 16.00/23.00/10.00
# Iter: 6, Avg/Max/Min. reward: 15.83/23.00/10.00
# Iter: 7, Avg/Max/Min. reward: 14.86/23.00/9.00
# Iter: 8, Avg/Max/Min. reward: 14.75/23.00/9.00
# Iter: 9, Avg/Max/Min. reward: 14.11/23.00/9.00
# Iter: 10, Avg/Max/Min. reward: 15.90/32.00/9.00
# Iter: 11, Avg/Max/Min. reward: 17.20/45.00/9.00
# Iter: 12, Avg/Max/Min. reward: 19.00/45.00/9.00
# Iter: 13, Avg/Max/Min. reward: 21.60/58.00/9.00
# Iter: 14, Avg/Max/Min. reward: 22.10/58.00/9.00
# Iter: 15, Avg/Max/Min. reward: 23.70/58.00/9.00
# Iter: 16, Avg/Max/Min. reward: 22.50/58.00/9.00
# Iter: 17, Avg/Max/Min. reward: 21.60/58.00/9.00
# Iter: 18, Avg/Max/Min. reward: 21.60/58.00/9.00
# Iter: 19, Avg/Max/Min. reward: 22.90/58.00/9.00
# Iter: 20, Avg/Max/Min. reward: 24.70/58.00/9.00
# Iter: 21, Avg/Max/Min. reward: 24.90/58.00/9.00
# Iter: 22, Avg/Max/Min. reward: 25.40/58.00/11.00
# Iter: 23, Avg/Max/Min. reward: 22.50/58.00/11.00
# Iter: 24, Avg/Max/Min. reward: 18.00/34.00/11.00
# Iter: 25, Avg/Max/Min. reward: 18.80/34.00/11.00
# Iter: 26, Avg/Max/Min. reward: 18.00/34.00/11.00
# Iter: 27, Avg/Max/Min. reward: 19.10/34.00/12.00
# Iter: 28, Avg/Max/Min. reward: 20.60/34.00/13.00
# Iter: 29, Avg/Max/Min. reward: 22.30/34.00/13.00
# Iter: 30, Avg/Max/Min. reward: 25.30/62.00/13.00
# Iter: 31, Avg/Max/Min. reward: 25.40/62.00/13.00
# Iter: 32, Avg/Max/Min. reward: 24.00/62.00/13.00
# Iter: 33, Avg/Max/Min. reward: 24.10/62.00/13.00
# Iter: 34, Avg/Max/Min. reward: 24.90/62.00/13.00
# Iter: 35, Avg/Max/Min. reward: 25.10/62.00/15.00
# Iter: 36, Avg/Max/Min. reward: 24.10/62.00/15.00
# Iter: 37, Avg/Max/Min. reward: 23.50/62.00/12.00
# Iter: 38, Avg/Max/Min. reward: 24.30/62.00/12.00
# Iter: 39, Avg/Max/Min. reward: 24.80/62.00/12.00
# Iter: 40, Avg/Max/Min. reward: 28.00/64.00/12.00
# Iter: 41, Avg/Max/Min. reward: 30.20/86.00/12.00
# Iter: 42, Avg/Max/Min. reward: 25.60/86.00/12.00
# Iter: 43, Avg/Max/Min. reward: 25.40/86.00/12.00
# Iter: 44, Avg/Max/Min. reward: 24.60/86.00/12.00
# Iter: 45, Avg/Max/Min. reward: 24.30/86.00/12.00
# Iter: 46, Avg/Max/Min. reward: 24.50/86.00/12.00
# Iter: 47, Avg/Max/Min. reward: 24.40/86.00/12.00
# Iter: 48, Avg/Max/Min. reward: 23.80/86.00/9.00
# Iter: 49, Avg/Max/Min. reward: 25.80/86.00/9.00
# Iter: 50, Avg/Max/Min. reward: 25.60/86.00/9.00
# Iter: 51, Avg/Max/Min. reward: 20.10/32.00/9.00
# Iter: 52, Avg/Max/Min. reward: 20.10/32.00/9.00
# Iter: 53, Avg/Max/Min. reward: 19.90/32.00/9.00
# Iter: 54, Avg/Max/Min. reward: 20.90/32.00/9.00
# Iter: 55, Avg/Max/Min. reward: 20.80/32.00/9.00
# Iter: 56, Avg/Max/Min. reward: 20.00/32.00/9.00
# Iter: 57, Avg/Max/Min. reward: 20.00/32.00/9.00
# Iter: 58, Avg/Max/Min. reward: 22.30/32.00/11.00
# Iter: 59, Avg/Max/Min. reward: 23.50/44.00/11.00
# Iter: 60, Avg/Max/Min. reward: 22.10/44.00/11.00
# Iter: 61, Avg/Max/Min. reward: 22.20/44.00/11.00
# Iter: 62, Avg/Max/Min. reward: 21.90/44.00/11.00
# Iter: 63, Avg/Max/Min. reward: 23.50/44.00/11.00
# Iter: 64, Avg/Max/Min. reward: 24.50/44.00/11.00
# Iter: 65, Avg/Max/Min. reward: 25.60/44.00/11.00
# Iter: 66, Avg/Max/Min. reward: 25.00/44.00/11.00
# Iter: 67, Avg/Max/Min. reward: 24.90/44.00/10.00
# Iter: 68, Avg/Max/Min. reward: 25.60/44.00/10.00
# Iter: 69, Avg/Max/Min. reward: 25.70/44.00/10.00
# Iter: 70, Avg/Max/Min. reward: 23.00/42.00/10.00
# Iter: 71, Avg/Max/Min. reward: 22.70/42.00/10.00
# Iter: 72, Avg/Max/Min. reward: 21.70/42.00/10.00
# Iter: 73, Avg/Max/Min. reward: 20.10/42.00/10.00
# Iter: 74, Avg/Max/Min. reward: 17.90/30.00/10.00
# Iter: 75, Avg/Max/Min. reward: 16.20/25.00/10.00
# Iter: 76, Avg/Max/Min. reward: 17.80/32.00/10.00
# Iter: 77, Avg/Max/Min. reward: 20.10/55.00/10.00
# Iter: 78, Avg/Max/Min. reward: 20.70/55.00/12.00
# Iter: 79, Avg/Max/Min. reward: 19.70/55.00/12.00
# Iter: 80, Avg/Max/Min. reward: 21.40/55.00/12.00
# Iter: 81, Avg/Max/Min. reward: 22.60/55.00/12.00
# Iter: 82, Avg/Max/Min. reward: 23.50/55.00/12.00
# Iter: 83, Avg/Max/Min. reward: 25.20/55.00/12.00
# Iter: 84, Avg/Max/Min. reward: 24.90/55.00/12.00
# Iter: 85, Avg/Max/Min. reward: 24.60/55.00/9.00
# Iter: 86, Avg/Max/Min. reward: 25.80/55.00/9.00
# Iter: 87, Avg/Max/Min. reward: 26.50/55.00/9.00
# Iter: 88, Avg/Max/Min. reward: 27.10/55.00/9.00
# Iter: 89, Avg/Max/Min. reward: 24.80/44.00/9.00
# Iter: 90, Avg/Max/Min. reward: 25.10/44.00/9.00
# Iter: 91, Avg/Max/Min. reward: 25.30/44.00/9.00
# Iter: 92, Avg/Max/Min. reward: 25.80/44.00/9.00
# Iter: 93, Avg/Max/Min. reward: 22.60/39.00/9.00
# Iter: 94, Avg/Max/Min. reward: 23.20/39.00/9.00
# Iter: 95, Avg/Max/Min. reward: 23.60/39.00/9.00
# Iter: 96, Avg/Max/Min. reward: 22.10/39.00/9.00
# Iter: 97, Avg/Max/Min. reward: 22.20/39.00/9.00
# Iter: 98, Avg/Max/Min. reward: 22.90/39.00/12.00
# Iter: 99, Avg/Max/Min. reward: 22.20/36.00/12.00
# Iter: 100, Avg/Max/Min. reward: 23.40/44.00/12.00
# Iter: 101, Avg/Max/Min. reward: 23.10/44.00/12.00
# Iter: 102, Avg/Max/Min. reward: 20.60/44.00/10.00
# Iter: 103, Avg/Max/Min. reward: 20.90/44.00/10.00
# Iter: 104, Avg/Max/Min. reward: 20.50/44.00/10.00
# Iter: 105, Avg/Max/Min. reward: 20.60/44.00/10.00
# Iter: 106, Avg/Max/Min. reward: 18.50/44.00/10.00
# Iter: 107, Avg/Max/Min. reward: 17.70/44.00/9.00
# Iter: 108, Avg/Max/Min. reward: 18.70/44.00/9.00
# Iter: 109, Avg/Max/Min. reward: 19.40/44.00/9.00
# Iter: 110, Avg/Max/Min. reward: 17.40/27.00/9.00
# Iter: 111, Avg/Max/Min. reward: 17.20/27.00/9.00
# Iter: 112, Avg/Max/Min. reward: 19.20/30.00/9.00
# Iter: 113, Avg/Max/Min. reward: 18.80/30.00/9.00
# Iter: 114, Avg/Max/Min. reward: 18.90/30.00/9.00
# Iter: 115, Avg/Max/Min. reward: 19.40/30.00/9.00
# Iter: 116, Avg/Max/Min. reward: 19.00/30.00/9.00
# Iter: 117, Avg/Max/Min. reward: 20.30/30.00/11.00
# Iter: 118, Avg/Max/Min. reward: 19.80/30.00/11.00
# Iter: 119, Avg/Max/Min. reward: 20.20/30.00/11.00
# Iter: 120, Avg/Max/Min. reward: 20.20/30.00/11.00
# Iter: 121, Avg/Max/Min. reward: 22.00/32.00/11.00
# Iter: 122, Avg/Max/Min. reward: 22.50/37.00/11.00
# Iter: 123, Avg/Max/Min. reward: 21.50/37.00/11.00
# Iter: 124, Avg/Max/Min. reward: 20.90/37.00/11.00
# Iter: 125, Avg/Max/Min. reward: 20.10/37.00/9.00
# Iter: 126, Avg/Max/Min. reward: 19.70/37.00/9.00
# Iter: 127, Avg/Max/Min. reward: 19.80/37.00/9.00
# Iter: 128, Avg/Max/Min. reward: 19.00/37.00/9.00
# Iter: 129, Avg/Max/Min. reward: 18.00/37.00/9.00
# Iter: 130, Avg/Max/Min. reward: 18.10/37.00/9.00
# Iter: 131, Avg/Max/Min. reward: 18.90/37.00/9.00
# Iter: 132, Avg/Max/Min. reward: 20.00/43.00/9.00
# Iter: 133, Avg/Max/Min. reward: 19.50/43.00/9.00
# Iter: 134, Avg/Max/Min. reward: 19.70/43.00/9.00
# Iter: 135, Avg/Max/Min. reward: 20.90/43.00/9.00
# Iter: 136, Avg/Max/Min. reward: 22.60/49.00/9.00
# Iter: 137, Avg/Max/Min. reward: 24.00/49.00/9.00
# Iter: 138, Avg/Max/Min. reward: 24.20/49.00/11.00
# Iter: 139, Avg/Max/Min. reward: 25.80/49.00/11.00
# Iter: 140, Avg/Max/Min. reward: 27.50/49.00/11.00
# Iter: 141, Avg/Max/Min. reward: 27.30/49.00/11.00
# Iter: 142, Avg/Max/Min. reward: 29.30/49.00/11.00
# Iter: 143, Avg/Max/Min. reward: 29.40/49.00/11.00
# Iter: 144, Avg/Max/Min. reward: 29.20/49.00/11.00
# Iter: 145, Avg/Max/Min. reward: 27.20/49.00/11.00
# Iter: 146, Avg/Max/Min. reward: 27.00/49.00/11.00
# Iter: 147, Avg/Max/Min. reward: 29.30/55.00/11.00
# Iter: 148, Avg/Max/Min. reward: 27.60/55.00/11.00
# Iter: 149, Avg/Max/Min. reward: 29.10/55.00/11.00
# Iter: 150, Avg/Max/Min. reward: 29.80/55.00/11.00
# Iter: 151, Avg/Max/Min. reward: 29.90/55.00/11.00
# Iter: 152, Avg/Max/Min. reward: 31.00/55.00/12.00
# Iter: 153, Avg/Max/Min. reward: 30.40/55.00/12.00
# Iter: 154, Avg/Max/Min. reward: 29.20/55.00/12.00
# Iter: 155, Avg/Max/Min. reward: 29.50/55.00/15.00
# Iter: 156, Avg/Max/Min. reward: 29.20/55.00/15.00
# Iter: 157, Avg/Max/Min. reward: 29.50/55.00/15.00
# Iter: 158, Avg/Max/Min. reward: 30.40/55.00/15.00
# Iter: 159, Avg/Max/Min. reward: 31.80/55.00/15.00
# Iter: 160, Avg/Max/Min. reward: 28.40/47.00/15.00
# Iter: 161, Avg/Max/Min. reward: 24.90/46.00/12.00
# Iter: 162, Avg/Max/Min. reward: 24.80/46.00/12.00
# Iter: 163, Avg/Max/Min. reward: 24.10/46.00/12.00
# Iter: 164, Avg/Max/Min. reward: 24.20/46.00/12.00
# Iter: 165, Avg/Max/Min. reward: 24.70/46.00/12.00
# Iter: 166, Avg/Max/Min. reward: 25.00/46.00/12.00
# Iter: 167, Avg/Max/Min. reward: 23.50/46.00/12.00
# Iter: 168, Avg/Max/Min. reward: 23.60/46.00/12.00
# Iter: 169, Avg/Max/Min. reward: 20.80/32.00/12.00
# Iter: 170, Avg/Max/Min. reward: 21.50/32.00/12.00
# Iter: 171, Avg/Max/Min. reward: 22.20/32.00/15.00
# Iter: 172, Avg/Max/Min. reward: 20.50/30.00/15.00
# Iter: 173, Avg/Max/Min. reward: 22.00/30.00/15.00
# Iter: 174, Avg/Max/Min. reward: 21.00/30.00/15.00
# Iter: 175, Avg/Max/Min. reward: 20.40/30.00/15.00
# Iter: 176, Avg/Max/Min. reward: 21.20/30.00/15.00
# Iter: 177, Avg/Max/Min. reward: 22.90/32.00/15.00
# Iter: 178, Avg/Max/Min. reward: 24.20/45.00/15.00
# Iter: 179, Avg/Max/Min. reward: 22.70/45.00/15.00
# Iter: 180, Avg/Max/Min. reward: 22.20/45.00/13.00
# Iter: 181, Avg/Max/Min. reward: 22.60/45.00/13.00
# Iter: 182, Avg/Max/Min. reward: 24.30/49.00/13.00
# Iter: 183, Avg/Max/Min. reward: 24.90/49.00/13.00
# Iter: 184, Avg/Max/Min. reward: 25.10/49.00/13.00
# Iter: 185, Avg/Max/Min. reward: 24.40/49.00/13.00
# Iter: 186, Avg/Max/Min. reward: 23.80/49.00/9.00
# Iter: 187, Avg/Max/Min. reward: 24.30/49.00/9.00
# Iter: 188, Avg/Max/Min. reward: 24.90/49.00/9.00
# Iter: 189, Avg/Max/Min. reward: 21.50/49.00/9.00
# Iter: 190, Avg/Max/Min. reward: 23.20/49.00/9.00
# Iter: 191, Avg/Max/Min. reward: 24.40/49.00/9.00
# Iter: 192, Avg/Max/Min. reward: 24.80/49.00/9.00
# Iter: 193, Avg/Max/Min. reward: 22.20/44.00/9.00
# Iter: 194, Avg/Max/Min. reward: 20.90/44.00/9.00
# Iter: 195, Avg/Max/Min. reward: 21.60/44.00/9.00
# Iter: 196, Avg/Max/Min. reward: 22.50/44.00/9.00
# Iter: 197, Avg/Max/Min. reward: 22.60/44.00/9.00
# Iter: 198, Avg/Max/Min. reward: 23.40/44.00/11.00
# Iter: 199, Avg/Max/Min. reward: 22.40/44.00/11.00
# Iter: 200, Avg/Max/Min. reward: 22.40/44.00/11.00
# Iter: 201, Avg/Max/Min. reward: 23.70/45.00/11.00
# Iter: 202, Avg/Max/Min. reward: 25.10/45.00/11.00
# Iter: 203, Avg/Max/Min. reward: 23.70/45.00/11.00
# Iter: 204, Avg/Max/Min. reward: 23.60/45.00/11.00
# Iter: 205, Avg/Max/Min. reward: 22.90/45.00/11.00
# Iter: 206, Avg/Max/Min. reward: 23.40/45.00/11.00
# Iter: 207, Avg/Max/Min. reward: 23.40/45.00/11.00
# Iter: 208, Avg/Max/Min. reward: 23.10/45.00/11.00
# Iter: 209, Avg/Max/Min. reward: 24.40/45.00/11.00
# Iter: 210, Avg/Max/Min. reward: 25.20/45.00/16.00
# Iter: 211, Avg/Max/Min. reward: 22.50/30.00/16.00
# Iter: 212, Avg/Max/Min. reward: 22.00/30.00/16.00
# Iter: 213, Avg/Max/Min. reward: 21.50/30.00/16.00
# Iter: 214, Avg/Max/Min. reward: 22.00/30.00/16.00
# Iter: 215, Avg/Max/Min. reward: 21.90/30.00/15.00
# Iter: 216, Avg/Max/Min. reward: 22.40/30.00/15.00
# Iter: 217, Avg/Max/Min. reward: 21.20/30.00/12.00
# Iter: 218, Avg/Max/Min. reward: 21.20/30.00/12.00
# Iter: 219, Avg/Max/Min. reward: 20.30/30.00/12.00
# Iter: 220, Avg/Max/Min. reward: 21.60/32.00/12.00
# Iter: 221, Avg/Max/Min. reward: 22.30/39.00/12.00
# Iter: 222, Avg/Max/Min. reward: 22.20/39.00/12.00
# Iter: 223, Avg/Max/Min. reward: 21.80/39.00/12.00
# Iter: 224, Avg/Max/Min. reward: 20.60/39.00/12.00
# Iter: 225, Avg/Max/Min. reward: 19.50/39.00/10.00
# Iter: 226, Avg/Max/Min. reward: 20.30/39.00/10.00
# Iter: 227, Avg/Max/Min. reward: 20.00/39.00/10.00
# Iter: 228, Avg/Max/Min. reward: 20.80/39.00/10.00
# Iter: 229, Avg/Max/Min. reward: 19.20/39.00/10.00
# Iter: 230, Avg/Max/Min. reward: 19.90/39.00/10.00
# Iter: 231, Avg/Max/Min. reward: 17.30/28.00/10.00
# Iter: 232, Avg/Max/Min. reward: 17.40/28.00/10.00
# Iter: 233, Avg/Max/Min. reward: 19.00/32.00/10.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-4df2db6e786b> in <module>
#      21             output.done()
#      22     input.update()
# ---> 23     hidden.update()
#      24     output.update()
#      25     print('Iter: %d, Avg/Max/Min. reward: %0.2f/%0.2f/%0.2f' % (j, sum(episode_rewards)/len(episode_rewards), max(episode_rewards), min(episode_rewards)))
#
# ~/cascade_rl/on_policy/layer.py in update(self)
#      69     def update(self):
#      70         for unit in self.units:
# ---> 71             unit.update()
#      72
#      73     def clear_memory(self):
#
# ~/cascade_rl/on_policy/unit.py in update(self)
#      79         self.memory.compute_returns(next_value, self.args.use_gae, self.args.gamma,
#      80                                self.args.gae_lambda, self.args.use_proper_time_limits)
# ---> 81         value_loss, action_loss, dist_entropy = self.agent.update(self.memory)
#      82         self.value_losses.append(value_loss)
#      83         self.action_losses.append(action_loss)
#
# ~/cascade_rl/on_policy/a2c_ppo_acktr/algo/ppo.py in update(self, rollouts)
#      79                 self.optimizer.zero_grad()
#      80                 (value_loss * self.value_loss_coef + action_loss -
# ---> 81                  dist_entropy * self.entropy_coef).backward()
#      82                 nn.utils.clip_grad_norm_(self.actor_critic.parameters(),
#      83                                          self.max_grad_norm)
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
input.plot_stats()
hidden.plot_stats()
output.plot_stats()
