# %%
from sac import SAC
from replay_memory import ReplayMemory
import gym
from gym import spaces
from addict import Dict
import numpy as np
import itertools
from scipy.special import softmax
import random
from tqdm import tqdm

# %%
WARM_UP = 0
MEMORY_SIZE = 10000
ACT_THRESHOLD = 0
BATCH_SIZE = 64
UPDATES_PER_STEP = 1
PRINT_FREQ = 1000
TEST_EPISODES = 1000
MIN_REQUIRED_UPDATES = 0

# %%
num_inputs = 4
num_hidden = 4
num_outputs = 1
bandwidth = 3

# %%
env = gym.make('CartPole-v0')
env.action_space.shape = (1,)
env.action_space.high = np.array([1])
env.action_space.low = np.array([0])

# %%
input_layer_action_space = gym.spaces.Box(low=0, high=1, shape=(num_hidden + bandwidth,))
hidden_layer_action_space = gym.spaces.Box(low=0, high=1, shape=(num_outputs + bandwidth,))
output_layer_action_space = env.action_space
# Out:
# /home/f1ery/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
args = Dict()
args.gamma = 0.99
args.tau = 1
args.alpha = 0.0
args.policy = 'Gaussian'
args.target_update_interval = 400
args.automatic_entropy_tuning = False
args.cuda = False
args.hidden_size = 256
args.lr = 0.003

# %%
input_layer = [SAC(1, input_layer_action_space, args) for _ in range(num_inputs)]
input_memory = [ReplayMemory(MEMORY_SIZE) for _ in range(num_inputs)]
input_updates = [0 for _ in range(num_inputs)]
hidden_layer = [SAC(bandwidth, hidden_layer_action_space, args) for _ in range(num_hidden)]
hidden_memory = [ReplayMemory(MEMORY_SIZE) for _ in range(num_hidden)]
hidden_updates = [0 for _ in range(num_hidden)]
output_layer = [SAC(bandwidth, output_layer_action_space, args) for _ in range(num_outputs)]
output_memory = [ReplayMemory(MEMORY_SIZE) for _ in range(num_outputs)]
output_updates = [0 for _ in range(num_outputs)]

# %%
def eval_layers(input_state):
    isa = [tuple() for _ in range(num_inputs)]
    hsa = [tuple() for _ in range(num_hidden)]
    osa = [tuple() for _ in range(num_outputs)]
    input_actions = [agent.select_action(input_state[i:i+1]) for i, agent in enumerate(input_layer)]
    for i, input_action in enumerate(input_actions):
        input_action[:num_hidden] = softmax(input_action[:num_hidden])
        if max(input_action[:num_hidden]) > ACT_THRESHOLD:
            isa[i] = (input_state[i:i+1], input_action, True)
            input_actions[i] = (np.argmax(input_action[:num_hidden]), input_action[num_hidden:])
        else:
            isa[i] = (input_state[i:i+1], input_action, False)
            input_actions[i] = tuple()
    hidden_state = [tuple() for _ in range(num_hidden)]
    for input_action in input_actions:
        try:
            hidden_i, hidden_msg = input_action
        except:
            continue
        try:
            hidden_state[hidden_i] += hidden_msg
        except:
            hidden_state[hidden_i] = hidden_msg
    hidden_actions = []
    for i, _hidden_state in enumerate(hidden_state):
        if len(_hidden_state):
            hidden_action = hidden_layer[i].select_action(softmax(hidden_state[i])) 
            if hidden_action[0] > ACT_THRESHOLD:
                hsa[i] = (_hidden_state, hidden_action, True)
                hidden_actions.append((0, hidden_action[1:]))
            else:
                hsa[i] = (_hidden_state, hidden_action, False)
                hidden_actions.append(tuple())
    output_state = [tuple() for _ in range(num_outputs)]
    for hidden_action in hidden_actions:
        try:
            output_i, output_msg = hidden_action
        except:
            continue
        try:
            output_state[output_i] += output_msg
        except:
            output_state[output_i] = output_msg
    output_actions = [agent.select_action(softmax(output_state[i])) for i, agent in enumerate(output_layer) if len(output_state[i])]
    if output_actions:
        osa = [(output_state[0], output_actions[0], True)]
    else:
        osa = [tuple()]
    inner_activations = Dict()
    inner_activations.isa = isa
    inner_activations.osa = osa
    inner_activations.hsa = hsa
    try:
        if output_actions[0] > 0.5:
            return 1, inner_activations
        else:
            return 0, inner_activations
    except:
        return random.randint(0, 1), inner_activations

# %%
def sample_layers(input_state):
    isa = [tuple() for _ in range(num_inputs)]
    hsa = [tuple() for _ in range(num_hidden)]
    osa = [tuple() for _ in range(num_outputs)]
    input_actions = [input_layer_action_space.sample() for _ in input_layer]
    for i, input_action in enumerate(input_actions):
        input_action[:num_hidden] = softmax(input_action[:num_hidden])
        if max(input_action[:num_hidden]) > ACT_THRESHOLD:
            isa[i] = (input_state[i:i+1], input_action, True)
            input_actions[i] = (np.argmax(input_action[:num_hidden]), input_action[num_hidden:])
        else:
            isa[i] = (input_state[i:i+1], input_action, False)
            input_actions[i] = tuple()
    hidden_state = [tuple() for _ in range(num_hidden)]
    for input_action in input_actions:
        try:
            hidden_i, hidden_msg = input_action
        except:
            continue
        try:
            hidden_state[hidden_i] += hidden_msg
        except:
            hidden_state[hidden_i] = hidden_msg
    hidden_actions = []
    for i, _hidden_state in enumerate(hidden_state):
        if len(_hidden_state):
            hidden_action = hidden_layer_action_space.sample()
            if hidden_action[0] > ACT_THRESHOLD:
                hidden_actions.append((0, hidden_action[1:]))
                hsa[i] = (_hidden_state, hidden_action, True)
            else:
                hidden_actions.append(tuple())
                hsa[i] = (_hidden_state, hidden_action, False)
    output_state = [tuple() for _ in range(num_outputs)]
    for hidden_action in hidden_actions:
        try:
            output_i, output_msg = hidden_action
        except:
            continue
        try:
            output_state[output_i] += output_msg
        except:
            output_state[output_i] = output_msg
    output_actions = [np.array([output_layer_action_space.sample()]) for i, _ in enumerate(output_layer) if len(output_state[i])]
    osa = [(output_state[0], output_actions[0], True)]
    inner_activations = Dict()
    inner_activations.isa = isa
    inner_activations.osa = osa
    inner_activations.hsa = hsa
    try:
        if output_actions[0] > 0.5:
            return 1, inner_activations
        else:
            return 0, inner_activations
    except:
        return random.randint(0, 1), inner_activations

# %%
def push_memory(inner_activations, reward, next_state, mask):
    isa = inner_activations.isa
    hsa = inner_activations.hsa
    osa = inner_activations.osa
    for i, ((state, action, flag), mem) in enumerate(zip(isa, input_memory)):
        _next_state = next_state[i:i+1]
        if flag:
            mem.push(state, action, reward, _next_state, mask)
        else:
            mem.push(state, action, 0, _next_state, mask)
    next_action, next_inner_activations = eval_layers(next_state)
    for hsa, mem, next_hsa in zip(hsa, hidden_memory, next_inner_activations.hsa):
        try:
            state, action, flag = hsa
            _next_state, _, _ = next_hsa
        except:
            continue
        if flag:
            mem.push(state, action, reward, _next_state, mask)
        else:
            mem.push(state, action, 0, _next_state, mask)
    for osa, mem, next_osa in zip(osa, output_memory, next_inner_activations.osa):
        try:
            state, action, flag = osa
            _next_state, _, _ = next_osa
        except:
            continue
        if flag:
            mem.push(state, action, reward, _next_state, mask)
        else:
            mem.push(state, action, 0, _next_state, mask)
    return next_action, next_inner_activations

# %%
def norm_stats(stats):
    for k in stats:
        stats[k] /= stats.cnt
    return stats
def average_stats(lst):
    avg = Dict()
    for stats in lst:
        for k in stats:
            avg[k] += stats[k]
        avg.cnt += 1
    return norm_stats(avg)
def get_avg_loss(train_stats):
    try:
        input_loss = (train_stats.input.critic_1_loss + train_stats.input.critic_2_loss)/2
    except:
        input_loss = float('nan')
    try:
        hidden_loss = (train_stats.hidden.critic_1_loss + train_stats.hidden.critic_2_loss)/2
    except:
        hidden_loss = float('nan')
    try:
        output_loss = (train_stats.output.critic_1_loss + train_stats.output.critic_2_loss)/2
    except:
        output_loss = float('nan')
    return input_loss, hidden_loss, output_loss

# %%
total_steps = 0
last_total_steps = 0
total_reward = 0.0
act_stats = Dict()
act_stats.input = np.array([0.0 for _ in input_layer])
act_stats.hidden = np.array([0.0 for _ in hidden_layer])
act_stats.output = np.array([0.0 for _ in output_layer])
for i_episode in itertools.count(1):
    episode_reward = 0
    episode_steps = 0
    done = False
    state = env.reset()
    inner_activations = {}
    action = None
    train_stats = Dict()
    train_stats.input = []
    train_stats.hidden = []
    train_stats.output = []
    while not done:
        if WARM_UP > total_steps:
            action, inner_activations = sample_layers(state)  # Sample random action
        else:
            if total_steps == WARM_UP:
                print('--WARM UP ENDED--'*3)
            if not inner_activations:
                action, inner_activations = eval_layers(state)  # Sample action from policy
        for i, isa in enumerate(inner_activations.isa):
            if len(isa):
                act_stats.input[i] += 1
        for i, hsa in enumerate(inner_activations.hsa):
            if len(hsa):
                act_stats.hidden[i] += 1
        for i, osa in enumerate(inner_activations.osa):
            if len(osa):
                act_stats.output[i] += 1

        # Number of updates per step in environment
        for i in range(UPDATES_PER_STEP):
            # Update parameters of all the networks
            for j, (agent, memory, updates) in enumerate(zip(input_layer, input_memory, input_updates)):
                input_stats = Dict()
                if len(memory) > BATCH_SIZE and inner_activations.isa[j]:
                    critic_1_loss, critic_2_loss, policy_loss, ent_loss, alpha = agent.update_parameters(memory, BATCH_SIZE, updates)
                    input_stats.critic_1_loss += critic_1_loss
                    input_stats.critic_2_loss += critic_2_loss
                    input_stats.policy_loss += policy_loss
                    input_stats.ent_loss += ent_loss
                    input_stats.alpha += alpha
                    input_stats.cnt += 1
                    input_updates[j] += 1
                norm_stats(input_stats)
                train_stats.input.append(input_stats)
            for j, (agent, memory, updates) in enumerate(zip(hidden_layer, hidden_memory, hidden_updates)):
                hidden_stats = Dict()
                if len(memory) > BATCH_SIZE and inner_activations.hsa[j]:
                    critic_1_loss, critic_2_loss, policy_loss, ent_loss, alpha = agent.update_parameters(memory, BATCH_SIZE, updates)
                    hidden_stats.critic_1_loss += critic_1_loss
                    hidden_stats.critic_2_loss += critic_2_loss
                    hidden_stats.policy_loss += policy_loss
                    hidden_stats.ent_loss += ent_loss
                    hidden_stats.alpha += alpha
                    hidden_stats.cnt += 1
                    hidden_updates[j] += 1
                norm_stats(hidden_stats)
                train_stats.hidden.append(hidden_stats)
            for j, (agent, memory, updates) in enumerate(zip(output_layer, output_memory, output_updates)):
                output_stats = Dict()
                if len(memory) > BATCH_SIZE and inner_activations.osa[j]:
                    critic_1_loss, critic_2_loss, policy_loss, ent_loss, alpha = agent.update_parameters(memory, BATCH_SIZE, updates)
                    output_stats.critic_1_loss += critic_1_loss
                    output_stats.critic_2_loss += critic_2_loss
                    output_stats.policy_loss += policy_loss
                    output_stats.ent_loss += ent_loss
                    output_stats.alpha += alpha
                    output_stats.cnt += 1
                    output_updates[j] += 1
                norm_stats(output_stats)
                train_stats.output.append(output_stats)

        next_state, reward, done, _ = env.step(action) # Step
        episode_steps += 1
        total_steps += 1
        episode_reward += reward

        # Ignore the "done" signal if it comes from hitting the time horizon.
        # (https://github.com/openai/spinningup/blob/master/spinup/algos/sac/sac.py)
        mask = 1 if episode_steps == env._max_episode_steps else float(not done)
        action, inner_activations = push_memory(inner_activations, reward, next_state, mask)

        state = next_state
    total_reward += episode_reward
    train_stats.input = average_stats(train_stats.input)
    train_stats.hidden = average_stats(train_stats.hidden)
    train_stats.output = average_stats(train_stats.output)
    loss = get_avg_loss(train_stats)
    print("Episode: {}, episode steps: {}, avg. reward: {}, loss_i: {}, loss_h: {}, loss_o: {}".format(i_episode, episode_steps, round(total_reward/((i_episode % PRINT_FREQ) or PRINT_FREQ), 2), *list(map(lambda x : round(x, 3), loss))))
    if i_episode % args.target_update_interval == 0 and total_steps > 0:
        ptr = -1
        input_update_map = np.array(input_updates) >= MIN_REQUIRED_UPDATES
        hidden_update_map = np.array(hidden_updates) >= MIN_REQUIRED_UPDATES
        output_update_map = np.array(output_updates) >= MIN_REQUIRED_UPDATES
        for j, agent, memory, updates in zip(list(range(num_inputs)) + list(range(num_hidden)) + list(range(num_outputs)), input_layer + hidden_layer + output_layer, input_memory + hidden_memory + output_memory, input_updates + hidden_updates + output_updates):
            if j == 0:
                ptr += 1
            if updates >= MIN_REQUIRED_UPDATES:
                agent.update_target()
                memory.empty()
                if ptr == 0:
                    input_updates[j] = 0
                elif ptr == 1:
                    hidden_updates[j] = 0
                else:
                    output_updates[j] = 0
        print('--TARGET UPDATED--'*3)
        print('i: %s' % input_update_map)
        print('h: %s' % hidden_update_map)
        print('o: %s' % output_update_map)
        print('-'*80)
    if i_episode % PRINT_FREQ == 0:
        act_stats.input /= total_steps - last_total_steps
        act_stats.hidden /= total_steps - last_total_steps
        act_stats.output /= total_steps - last_total_steps
        last_total_steps = total_steps
        total_reward = 0
        print("-"*80)
        print('Train episodes: %d' % PRINT_FREQ)
        print('-'*80)
        print('LOSS')
        print('i: %s' % str(train_stats.input))
        print('h: %s' % str(train_stats.hidden))
        print('o: %s' % str(train_stats.output))
        print('ACTIVATIONS')
        print('i: %s' % str(list(map(lambda x : round(x, 2), act_stats.input))))
        print('h: %s' % str(list(map(lambda x : round(x, 2), act_stats.hidden))))
        print('o: %s' % str(list(map(lambda x : round(x, 2), act_stats.output))))
        print('UPDATES')
        print('i: %s' % input_updates)
        print('h: %s' % hidden_updates)
        print('o: %s' % output_updates)
        print('MEMORY')
        print('i: %s' % str(list(map(len, input_memory))))
        print('h: %s' % str(list(map(len, hidden_memory))))
        print('o: %s' % str(list(map(len, output_memory))))
        act_stats.input = np.array([0.0 for _ in input_layer])
        act_stats.hidden = np.array([0.0 for _ in hidden_layer])
        act_stats.output = np.array([0.0 for _ in output_layer])
        print('\n')
        avg_reward = 0.
        max_reward = 0.
        for _  in tqdm(range(TEST_EPISODES)):
            state = env.reset()
            episode_reward = 0
            done = False
            while not done:
                action, _ = eval_layers(state)

                next_state, reward, done, _ = env.step(action)
                episode_reward += reward


                state = next_state
            avg_reward += episode_reward
            max_reward = max(episode_reward, max_reward)
        avg_reward /= TEST_EPISODES

        print("-"*80)
        print("Test Episodes: {}, Avg. Reward: {}, Max. Reward: {}".format(TEST_EPISODES, round(avg_reward, 2), round(max_reward, 2)))
        print("-"*80)
# Out:
# --WARM UP ENDED----WARM UP ENDED----WARM UP ENDED--
# Episode: 1, episode steps: 25, avg. reward: 25.0, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 2, episode steps: 20, avg. reward: 22.5, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 3, episode steps: 13, avg. reward: 19.33, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 4, episode steps: 9, avg. reward: 16.75, loss_i: 7.374, loss_h: nan, loss_o: 1.515
# Episode: 5, episode steps: 16, avg. reward: 16.6, loss_i: 0.283, loss_h: nan, loss_o: 0.149
# Episode: 6, episode steps: 23, avg. reward: 17.67, loss_i: 0.103, loss_h: nan, loss_o: 0.05
# Episode: 7, episode steps: 11, avg. reward: 16.71, loss_i: 0.048, loss_h: nan, loss_o: 0.043
# Episode: 8, episode steps: 13, avg. reward: 16.25, loss_i: 0.033, loss_h: 5.882, loss_o: 0.038
# Episode: 9, episode steps: 15, avg. reward: 16.11, loss_i: 0.024, loss_h: 12.319, loss_o: 0.038
# Episode: 10, episode steps: 17, avg. reward: 16.2, loss_i: 0.02, loss_h: 0.098, loss_o: 0.03
# Episode: 11, episode steps: 23, avg. reward: 16.82, loss_i: 0.018, loss_h: 7.875, loss_o: 0.032
# Episode: 12, episode steps: 25, avg. reward: 17.5, loss_i: 0.016, loss_h: 0.034, loss_o: 0.03
# Episode: 13, episode steps: 34, avg. reward: 18.77, loss_i: 0.014, loss_h: 0.022, loss_o: 0.026
# Episode: 14, episode steps: 12, avg. reward: 18.29, loss_i: 0.013, loss_h: 0.017, loss_o: 0.025
# Episode: 15, episode steps: 25, avg. reward: 18.73, loss_i: 0.012, loss_h: 3.073, loss_o: 0.025
# Episode: 16, episode steps: 43, avg. reward: 20.25, loss_i: 0.011, loss_h: 0.016, loss_o: 0.023
# Episode: 17, episode steps: 15, avg. reward: 19.94, loss_i: 0.01, loss_h: 0.015, loss_o: 0.024
# Episode: 18, episode steps: 13, avg. reward: 19.56, loss_i: 0.009, loss_h: 1.381, loss_o: 0.022
# Episode: 19, episode steps: 25, avg. reward: 19.84, loss_i: 0.008, loss_h: 2.457, loss_o: 0.021
# Episode: 20, episode steps: 14, avg. reward: 19.55, loss_i: 0.008, loss_h: 1.21, loss_o: 0.02
# Episode: 21, episode steps: 16, avg. reward: 19.38, loss_i: 0.007, loss_h: 1.389, loss_o: 0.019
# Episode: 22, episode steps: 13, avg. reward: 19.09, loss_i: 0.007, loss_h: 1.267, loss_o: 0.018
# Episode: 23, episode steps: 12, avg. reward: 18.78, loss_i: 0.007, loss_h: 0.96, loss_o: 0.016
# Episode: 24, episode steps: 21, avg. reward: 18.88, loss_i: 0.007, loss_h: 0.012, loss_o: 0.018
# Episode: 25, episode steps: 14, avg. reward: 18.68, loss_i: 0.006, loss_h: 1.214, loss_o: 0.017
# Episode: 26, episode steps: 15, avg. reward: 18.54, loss_i: 0.006, loss_h: 0.012, loss_o: 0.017
# Episode: 27, episode steps: 10, avg. reward: 18.22, loss_i: 0.006, loss_h: 0.011, loss_o: 0.017
# Episode: 28, episode steps: 21, avg. reward: 18.32, loss_i: 0.006, loss_h: 0.011, loss_o: 0.015
# Episode: 29, episode steps: 14, avg. reward: 18.17, loss_i: 0.005, loss_h: 0.011, loss_o: 0.015
# Episode: 30, episode steps: 22, avg. reward: 18.3, loss_i: 0.005, loss_h: 0.01, loss_o: 0.014
# Episode: 31, episode steps: 23, avg. reward: 18.45, loss_i: 0.005, loss_h: 0.01, loss_o: 0.015
# Episode: 32, episode steps: 19, avg. reward: 18.47, loss_i: 0.005, loss_h: 0.01, loss_o: 0.015
# Episode: 33, episode steps: 11, avg. reward: 18.24, loss_i: 0.004, loss_h: 0.68, loss_o: 0.014
# Episode: 34, episode steps: 9, avg. reward: 17.97, loss_i: 0.004, loss_h: 0.009, loss_o: 0.013
# Episode: 35, episode steps: 10, avg. reward: 17.74, loss_i: 0.004, loss_h: 0.009, loss_o: 0.014
# Episode: 36, episode steps: 20, avg. reward: 17.81, loss_i: 0.004, loss_h: 0.009, loss_o: 0.013
# Episode: 37, episode steps: 8, avg. reward: 17.54, loss_i: 0.004, loss_h: 0.453, loss_o: 0.012
# Episode: 38, episode steps: 15, avg. reward: 17.47, loss_i: 0.004, loss_h: 0.009, loss_o: 0.013
# Episode: 39, episode steps: 27, avg. reward: 17.72, loss_i: 0.004, loss_h: 0.009, loss_o: 0.013
# Episode: 40, episode steps: 24, avg. reward: 17.88, loss_i: 0.004, loss_h: 1.296, loss_o: 0.012
# Episode: 41, episode steps: 16, avg. reward: 17.83, loss_i: 0.003, loss_h: 0.009, loss_o: 0.011
# Episode: 42, episode steps: 16, avg. reward: 17.79, loss_i: 0.003, loss_h: 0.008, loss_o: 0.011
# Episode: 43, episode steps: 23, avg. reward: 17.91, loss_i: 0.003, loss_h: 0.008, loss_o: 0.01
# Episode: 44, episode steps: 13, avg. reward: 17.8, loss_i: 0.003, loss_h: 0.008, loss_o: 0.01
# Episode: 45, episode steps: 15, avg. reward: 17.73, loss_i: 0.003, loss_h: 0.008, loss_o: 0.01
# Episode: 46, episode steps: 10, avg. reward: 17.57, loss_i: 0.003, loss_h: 0.47, loss_o: 0.009
# Episode: 47, episode steps: 12, avg. reward: 17.45, loss_i: 0.003, loss_h: 0.587, loss_o: 0.01
# Episode: 48, episode steps: 21, avg. reward: 17.52, loss_i: 0.003, loss_h: 0.007, loss_o: 0.01
# Episode: 49, episode steps: 13, avg. reward: 17.43, loss_i: 0.003, loss_h: 0.007, loss_o: 0.009
# Episode: 50, episode steps: 12, avg. reward: 17.32, loss_i: 0.003, loss_h: 0.007, loss_o: 0.009
# Episode: 51, episode steps: 20, avg. reward: 17.37, loss_i: 0.003, loss_h: 0.008, loss_o: 0.009
# Episode: 52, episode steps: 10, avg. reward: 17.23, loss_i: 0.003, loss_h: 0.456, loss_o: 0.008
# Episode: 53, episode steps: 13, avg. reward: 17.15, loss_i: 0.003, loss_h: 0.007, loss_o: 0.008
# Episode: 54, episode steps: 14, avg. reward: 17.09, loss_i: 0.003, loss_h: 0.672, loss_o: 0.007
# Episode: 55, episode steps: 17, avg. reward: 17.09, loss_i: 0.002, loss_h: 0.007, loss_o: 0.008
# Episode: 56, episode steps: 11, avg. reward: 16.98, loss_i: 0.002, loss_h: 0.007, loss_o: 0.008
# Episode: 57, episode steps: 13, avg. reward: 16.91, loss_i: 0.002, loss_h: 0.006, loss_o: 0.008
# Episode: 58, episode steps: 15, avg. reward: 16.88, loss_i: 0.002, loss_h: 0.657, loss_o: 0.007
# Episode: 59, episode steps: 11, avg. reward: 16.78, loss_i: 0.002, loss_h: 0.007, loss_o: 0.008
# Episode: 60, episode steps: 9, avg. reward: 16.65, loss_i: 0.002, loss_h: 0.006, loss_o: 0.008
# Episode: 61, episode steps: 23, avg. reward: 16.75, loss_i: 0.002, loss_h: 0.007, loss_o: 0.008
# Episode: 62, episode steps: 23, avg. reward: 16.85, loss_i: 0.002, loss_h: 0.006, loss_o: 0.007
# Episode: 63, episode steps: 16, avg. reward: 16.84, loss_i: 0.002, loss_h: 0.006, loss_o: 0.007
# Episode: 64, episode steps: 18, avg. reward: 16.86, loss_i: 0.002, loss_h: 0.006, loss_o: 0.007
# Episode: 65, episode steps: 13, avg. reward: 16.8, loss_i: 0.002, loss_h: 0.006, loss_o: 0.007
# Episode: 66, episode steps: 10, avg. reward: 16.7, loss_i: 0.002, loss_h: 0.006, loss_o: 0.007
# Episode: 67, episode steps: 11, avg. reward: 16.61, loss_i: 0.002, loss_h: 0.368, loss_o: 0.007
# Episode: 68, episode steps: 12, avg. reward: 16.54, loss_i: 0.002, loss_h: 0.006, loss_o: 0.006
# Episode: 69, episode steps: 9, avg. reward: 16.43, loss_i: 0.002, loss_h: 0.006, loss_o: 0.007
# Episode: 70, episode steps: 9, avg. reward: 16.33, loss_i: 0.002, loss_h: 0.322, loss_o: 0.006
# Episode: 71, episode steps: 11, avg. reward: 16.25, loss_i: 0.002, loss_h: 0.389, loss_o: 0.006
# Episode: 72, episode steps: 11, avg. reward: 16.18, loss_i: 0.002, loss_h: 0.006, loss_o: 0.006
# Episode: 73, episode steps: 15, avg. reward: 16.16, loss_i: 0.002, loss_h: 0.587, loss_o: 0.006
# Episode: 74, episode steps: 11, avg. reward: 16.09, loss_i: 0.002, loss_h: 0.005, loss_o: 0.006
# Episode: 75, episode steps: 11, avg. reward: 16.03, loss_i: 0.002, loss_h: 0.006, loss_o: 0.005
# Episode: 76, episode steps: 12, avg. reward: 15.97, loss_i: 0.002, loss_h: 0.005, loss_o: 0.006
# Episode: 77, episode steps: 11, avg. reward: 15.91, loss_i: 0.002, loss_h: 0.005, loss_o: 0.005
# Episode: 78, episode steps: 10, avg. reward: 15.83, loss_i: 0.002, loss_h: 0.005, loss_o: 0.006
# Episode: 79, episode steps: 16, avg. reward: 15.84, loss_i: 0.002, loss_h: 0.005, loss_o: 0.005
# Episode: 80, episode steps: 14, avg. reward: 15.81, loss_i: 0.002, loss_h: 0.005, loss_o: 0.005
# Episode: 81, episode steps: 14, avg. reward: 15.79, loss_i: 0.002, loss_h: 0.005, loss_o: 0.005
# Episode: 82, episode steps: 12, avg. reward: 15.74, loss_i: 0.002, loss_h: 0.372, loss_o: 0.005
# Episode: 83, episode steps: 11, avg. reward: 15.69, loss_i: 0.002, loss_h: 0.312, loss_o: 0.005
# Episode: 84, episode steps: 12, avg. reward: 15.64, loss_i: 0.002, loss_h: 0.005, loss_o: 0.005
# Episode: 85, episode steps: 9, avg. reward: 15.56, loss_i: 0.002, loss_h: 0.005, loss_o: 0.005
# Episode: 86, episode steps: 20, avg. reward: 15.62, loss_i: 0.002, loss_h: 0.674, loss_o: 0.005
# Episode: 87, episode steps: 10, avg. reward: 15.55, loss_i: 0.002, loss_h: 0.004, loss_o: 0.005
# Episode: 88, episode steps: 11, avg. reward: 15.5, loss_i: 0.002, loss_h: 0.004, loss_o: 0.005
# Episode: 89, episode steps: 10, avg. reward: 15.44, loss_i: 0.002, loss_h: 0.005, loss_o: 0.004
# Episode: 90, episode steps: 12, avg. reward: 15.4, loss_i: 0.002, loss_h: 0.004, loss_o: 0.004
# Episode: 91, episode steps: 12, avg. reward: 15.36, loss_i: 0.002, loss_h: 0.312, loss_o: 0.005
# Episode: 92, episode steps: 8, avg. reward: 15.28, loss_i: 0.002, loss_h: 0.004, loss_o: 0.005
# Episode: 93, episode steps: 8, avg. reward: 15.2, loss_i: 0.002, loss_h: 0.004, loss_o: 0.004
# Episode: 94, episode steps: 13, avg. reward: 15.18, loss_i: 0.002, loss_h: 0.004, loss_o: 0.005
# Episode: 95, episode steps: 10, avg. reward: 15.13, loss_i: 0.002, loss_h: 0.293, loss_o: 0.005
# Episode: 96, episode steps: 8, avg. reward: 15.05, loss_i: 0.002, loss_h: 0.004, loss_o: 0.005
# Episode: 97, episode steps: 11, avg. reward: 15.01, loss_i: 0.002, loss_h: 0.005, loss_o: 0.004
# Episode: 98, episode steps: 14, avg. reward: 15.0, loss_i: 0.002, loss_h: 0.359, loss_o: 0.005
# Episode: 99, episode steps: 14, avg. reward: 14.99, loss_i: 0.002, loss_h: 0.004, loss_o: 0.004
# Episode: 100, episode steps: 9, avg. reward: 14.93, loss_i: 0.002, loss_h: 0.243, loss_o: 0.005
# Episode: 101, episode steps: 12, avg. reward: 14.9, loss_i: 0.002, loss_h: 0.351, loss_o: 0.004
# Episode: 102, episode steps: 9, avg. reward: 14.84, loss_i: 0.002, loss_h: 0.004, loss_o: 0.004
# Episode: 103, episode steps: 11, avg. reward: 14.81, loss_i: 0.002, loss_h: 0.279, loss_o: 0.004
# Episode: 104, episode steps: 13, avg. reward: 14.79, loss_i: 0.002, loss_h: 0.004, loss_o: 0.004
# Episode: 105, episode steps: 12, avg. reward: 14.76, loss_i: 0.002, loss_h: 0.004, loss_o: 0.004
# Episode: 106, episode steps: 9, avg. reward: 14.71, loss_i: 0.002, loss_h: 0.2, loss_o: 0.004
# Episode: 107, episode steps: 10, avg. reward: 14.66, loss_i: 0.002, loss_h: 0.004, loss_o: 0.004
# Episode: 108, episode steps: 12, avg. reward: 14.64, loss_i: 0.002, loss_h: 0.343, loss_o: 0.004
# Episode: 109, episode steps: 12, avg. reward: 14.61, loss_i: 0.002, loss_h: 0.332, loss_o: 0.003
# Episode: 110, episode steps: 12, avg. reward: 14.59, loss_i: 0.002, loss_h: 0.004, loss_o: 0.004
# Episode: 111, episode steps: 9, avg. reward: 14.54, loss_i: 0.001, loss_h: 0.004, loss_o: 0.004
# Episode: 112, episode steps: 10, avg. reward: 14.5, loss_i: 0.001, loss_h: 0.004, loss_o: 0.004
# Episode: 113, episode steps: 12, avg. reward: 14.48, loss_i: 0.002, loss_h: 0.004, loss_o: 0.003
# Episode: 114, episode steps: 15, avg. reward: 14.48, loss_i: 0.002, loss_h: 0.004, loss_o: 0.004
# Episode: 115, episode steps: 12, avg. reward: 14.46, loss_i: 0.001, loss_h: 0.004, loss_o: 0.004
# Episode: 116, episode steps: 18, avg. reward: 14.49, loss_i: 0.001, loss_h: 0.454, loss_o: 0.004
# Episode: 117, episode steps: 12, avg. reward: 14.47, loss_i: 0.002, loss_h: 0.004, loss_o: 0.004
# Episode: 118, episode steps: 13, avg. reward: 14.46, loss_i: 0.001, loss_h: 0.004, loss_o: 0.003
# Episode: 119, episode steps: 9, avg. reward: 14.41, loss_i: 0.002, loss_h: 0.004, loss_o: 0.004
# Episode: 120, episode steps: 11, avg. reward: 14.38, loss_i: 0.002, loss_h: 0.269, loss_o: 0.003
# Episode: 121, episode steps: 11, avg. reward: 14.36, loss_i: 0.002, loss_h: 0.004, loss_o: 0.004
# Episode: 122, episode steps: 9, avg. reward: 14.31, loss_i: 0.001, loss_h: 0.215, loss_o: 0.003
# Episode: 123, episode steps: 10, avg. reward: 14.28, loss_i: 0.001, loss_h: 0.004, loss_o: 0.003
# Episode: 124, episode steps: 10, avg. reward: 14.24, loss_i: 0.001, loss_h: 0.004, loss_o: 0.003
# Episode: 125, episode steps: 12, avg. reward: 14.22, loss_i: 0.002, loss_h: 0.299, loss_o: 0.003
# Episode: 126, episode steps: 10, avg. reward: 14.19, loss_i: 0.002, loss_h: 0.004, loss_o: 0.003
# Episode: 127, episode steps: 11, avg. reward: 14.17, loss_i: 0.001, loss_h: 0.004, loss_o: 0.003
# Episode: 128, episode steps: 9, avg. reward: 14.12, loss_i: 0.001, loss_h: 0.215, loss_o: 0.003
# Episode: 129, episode steps: 11, avg. reward: 14.1, loss_i: 0.001, loss_h: 0.004, loss_o: 0.003
# Episode: 130, episode steps: 13, avg. reward: 14.09, loss_i: 0.001, loss_h: 0.004, loss_o: 0.003
# Episode: 131, episode steps: 8, avg. reward: 14.05, loss_i: 0.001, loss_h: 0.004, loss_o: 0.003
# Episode: 132, episode steps: 11, avg. reward: 14.02, loss_i: 0.002, loss_h: 0.003, loss_o: 0.003
# Episode: 133, episode steps: 14, avg. reward: 14.02, loss_i: 0.001, loss_h: 0.004, loss_o: 0.003
# Episode: 134, episode steps: 8, avg. reward: 13.98, loss_i: 0.001, loss_h: 0.004, loss_o: 0.003
# Episode: 135, episode steps: 11, avg. reward: 13.96, loss_i: 0.001, loss_h: 0.004, loss_o: 0.003
# Episode: 136, episode steps: 10, avg. reward: 13.93, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 137, episode steps: 9, avg. reward: 13.89, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 138, episode steps: 13, avg. reward: 13.88, loss_i: 0.001, loss_h: 0.316, loss_o: 0.003
# Episode: 139, episode steps: 12, avg. reward: 13.87, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 140, episode steps: 10, avg. reward: 13.84, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 141, episode steps: 16, avg. reward: 13.86, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 142, episode steps: 9, avg. reward: 13.82, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 143, episode steps: 12, avg. reward: 13.81, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 144, episode steps: 9, avg. reward: 13.78, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 145, episode steps: 10, avg. reward: 13.75, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 146, episode steps: 19, avg. reward: 13.79, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 147, episode steps: 11, avg. reward: 13.77, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 148, episode steps: 12, avg. reward: 13.76, loss_i: 0.001, loss_h: 0.24, loss_o: 0.003
# Episode: 149, episode steps: 11, avg. reward: 13.74, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 150, episode steps: 10, avg. reward: 13.71, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 151, episode steps: 8, avg. reward: 13.68, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 152, episode steps: 11, avg. reward: 13.66, loss_i: 0.001, loss_h: 0.222, loss_o: 0.003
# Episode: 153, episode steps: 10, avg. reward: 13.63, loss_i: 0.001, loss_h: 0.224, loss_o: 0.003
# Episode: 154, episode steps: 10, avg. reward: 13.61, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 155, episode steps: 15, avg. reward: 13.62, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 156, episode steps: 12, avg. reward: 13.61, loss_i: 0.001, loss_h: 0.28, loss_o: 0.002
# Episode: 157, episode steps: 11, avg. reward: 13.59, loss_i: 0.001, loss_h: 0.201, loss_o: 0.003
# Episode: 158, episode steps: 9, avg. reward: 13.56, loss_i: 0.001, loss_h: 0.002, loss_o: 0.003
# Episode: 159, episode steps: 10, avg. reward: 13.54, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 160, episode steps: 10, avg. reward: 13.52, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 161, episode steps: 18, avg. reward: 13.55, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 162, episode steps: 9, avg. reward: 13.52, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 163, episode steps: 12, avg. reward: 13.51, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 164, episode steps: 14, avg. reward: 13.51, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 165, episode steps: 9, avg. reward: 13.48, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 166, episode steps: 10, avg. reward: 13.46, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 167, episode steps: 9, avg. reward: 13.44, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 168, episode steps: 11, avg. reward: 13.42, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 169, episode steps: 12, avg. reward: 13.41, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 170, episode steps: 13, avg. reward: 13.41, loss_i: 0.001, loss_h: 0.25, loss_o: 0.002
# Episode: 171, episode steps: 9, avg. reward: 13.39, loss_i: 0.001, loss_h: 0.003, loss_o: 0.003
# Episode: 172, episode steps: 8, avg. reward: 13.35, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 173, episode steps: 10, avg. reward: 13.34, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 174, episode steps: 12, avg. reward: 13.33, loss_i: 0.001, loss_h: 0.206, loss_o: 0.003
# Episode: 175, episode steps: 9, avg. reward: 13.3, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 176, episode steps: 12, avg. reward: 13.3, loss_i: 0.001, loss_h: 0.002, loss_o: 0.003
# Episode: 177, episode steps: 12, avg. reward: 13.29, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 178, episode steps: 11, avg. reward: 13.28, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 179, episode steps: 20, avg. reward: 13.31, loss_i: 0.001, loss_h: 0.002, loss_o: 0.003
# Episode: 180, episode steps: 12, avg. reward: 13.31, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 181, episode steps: 10, avg. reward: 13.29, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 182, episode steps: 12, avg. reward: 13.28, loss_i: 0.001, loss_h: 0.209, loss_o: 0.002
# Episode: 183, episode steps: 10, avg. reward: 13.26, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 184, episode steps: 11, avg. reward: 13.25, loss_i: 0.001, loss_h: 0.182, loss_o: 0.002
# Episode: 185, episode steps: 14, avg. reward: 13.25, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 186, episode steps: 11, avg. reward: 13.24, loss_i: 0.001, loss_h: 0.183, loss_o: 0.002
# Episode: 187, episode steps: 10, avg. reward: 13.22, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 188, episode steps: 10, avg. reward: 13.21, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 189, episode steps: 12, avg. reward: 13.2, loss_i: 0.001, loss_h: 0.17, loss_o: 0.002
# Episode: 190, episode steps: 9, avg. reward: 13.18, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 191, episode steps: 9, avg. reward: 13.16, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 192, episode steps: 9, avg. reward: 13.14, loss_i: 0.001, loss_h: 0.136, loss_o: 0.002
# Episode: 193, episode steps: 10, avg. reward: 13.12, loss_i: 0.001, loss_h: 0.158, loss_o: 0.002
# Episode: 194, episode steps: 9, avg. reward: 13.1, loss_i: 0.001, loss_h: 0.002, loss_o: 0.003
# Episode: 195, episode steps: 10, avg. reward: 13.08, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 196, episode steps: 8, avg. reward: 13.06, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 197, episode steps: 15, avg. reward: 13.07, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 198, episode steps: 9, avg. reward: 13.05, loss_i: 0.001, loss_h: 0.132, loss_o: 0.002
# Episode: 199, episode steps: 9, avg. reward: 13.03, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 200, episode steps: 13, avg. reward: 13.03, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 201, episode steps: 9, avg. reward: 13.0, loss_i: 0.001, loss_h: 0.002, loss_o: 0.003
# Episode: 202, episode steps: 9, avg. reward: 12.99, loss_i: 0.001, loss_h: 0.003, loss_o: 0.002
# Episode: 203, episode steps: 9, avg. reward: 12.97, loss_i: 0.001, loss_h: 0.157, loss_o: 0.002
# Episode: 204, episode steps: 14, avg. reward: 12.97, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 205, episode steps: 9, avg. reward: 12.95, loss_i: 0.001, loss_h: 0.127, loss_o: 0.002
# Episode: 206, episode steps: 9, avg. reward: 12.93, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 207, episode steps: 12, avg. reward: 12.93, loss_i: 0.001, loss_h: 0.193, loss_o: 0.002
# Episode: 208, episode steps: 9, avg. reward: 12.91, loss_i: 0.001, loss_h: 0.129, loss_o: 0.002
# Episode: 209, episode steps: 10, avg. reward: 12.89, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 210, episode steps: 9, avg. reward: 12.88, loss_i: 0.001, loss_h: 0.152, loss_o: 0.002
# Episode: 211, episode steps: 11, avg. reward: 12.87, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 212, episode steps: 12, avg. reward: 12.86, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 213, episode steps: 9, avg. reward: 12.85, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 214, episode steps: 9, avg. reward: 12.83, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 215, episode steps: 10, avg. reward: 12.81, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 216, episode steps: 11, avg. reward: 12.81, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 217, episode steps: 12, avg. reward: 12.8, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 218, episode steps: 9, avg. reward: 12.78, loss_i: 0.001, loss_h: 0.128, loss_o: 0.002
# Episode: 219, episode steps: 10, avg. reward: 12.77, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 220, episode steps: 11, avg. reward: 12.76, loss_i: 0.001, loss_h: 0.127, loss_o: 0.002
# Episode: 221, episode steps: 9, avg. reward: 12.75, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 222, episode steps: 13, avg. reward: 12.75, loss_i: 0.001, loss_h: 0.216, loss_o: 0.002
# Episode: 223, episode steps: 12, avg. reward: 12.74, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 224, episode steps: 9, avg. reward: 12.73, loss_i: 0.001, loss_h: 0.12, loss_o: 0.002
# Episode: 225, episode steps: 9, avg. reward: 12.71, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 226, episode steps: 11, avg. reward: 12.7, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 227, episode steps: 10, avg. reward: 12.69, loss_i: 0.001, loss_h: 0.157, loss_o: 0.002
# Episode: 228, episode steps: 12, avg. reward: 12.69, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 229, episode steps: 9, avg. reward: 12.67, loss_i: 0.001, loss_h: 0.119, loss_o: 0.002
# Episode: 230, episode steps: 10, avg. reward: 12.66, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 231, episode steps: 10, avg. reward: 12.65, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 232, episode steps: 11, avg. reward: 12.64, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 233, episode steps: 12, avg. reward: 12.64, loss_i: 0.001, loss_h: 0.163, loss_o: 0.002
# Episode: 234, episode steps: 9, avg. reward: 12.62, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 235, episode steps: 10, avg. reward: 12.61, loss_i: 0.001, loss_h: 0.116, loss_o: 0.002
# Episode: 236, episode steps: 9, avg. reward: 12.6, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 237, episode steps: 12, avg. reward: 12.59, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 238, episode steps: 11, avg. reward: 12.59, loss_i: 0.001, loss_h: 0.138, loss_o: 0.002
# Episode: 239, episode steps: 10, avg. reward: 12.58, loss_i: 0.001, loss_h: 0.119, loss_o: 0.002
# Episode: 240, episode steps: 11, avg. reward: 12.57, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 241, episode steps: 10, avg. reward: 12.56, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 242, episode steps: 8, avg. reward: 12.54, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 243, episode steps: 11, avg. reward: 12.53, loss_i: 0.001, loss_h: 0.145, loss_o: 0.002
# Episode: 244, episode steps: 10, avg. reward: 12.52, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 245, episode steps: 10, avg. reward: 12.51, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 246, episode steps: 11, avg. reward: 12.51, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 247, episode steps: 13, avg. reward: 12.51, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 248, episode steps: 10, avg. reward: 12.5, loss_i: 0.001, loss_h: 0.132, loss_o: 0.002
# Episode: 249, episode steps: 12, avg. reward: 12.5, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 250, episode steps: 12, avg. reward: 12.5, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 251, episode steps: 13, avg. reward: 12.5, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 252, episode steps: 11, avg. reward: 12.49, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 253, episode steps: 10, avg. reward: 12.48, loss_i: 0.001, loss_h: 0.131, loss_o: 0.002
# Episode: 254, episode steps: 12, avg. reward: 12.48, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 255, episode steps: 9, avg. reward: 12.47, loss_i: 0.001, loss_h: 0.108, loss_o: 0.002
# Episode: 256, episode steps: 9, avg. reward: 12.45, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 257, episode steps: 12, avg. reward: 12.45, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 258, episode steps: 11, avg. reward: 12.45, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 259, episode steps: 10, avg. reward: 12.44, loss_i: 0.001, loss_h: 0.109, loss_o: 0.002
# Episode: 260, episode steps: 10, avg. reward: 12.43, loss_i: 0.001, loss_h: 0.143, loss_o: 0.002
# Episode: 261, episode steps: 11, avg. reward: 12.42, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 262, episode steps: 9, avg. reward: 12.41, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 263, episode steps: 10, avg. reward: 12.4, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 264, episode steps: 10, avg. reward: 12.39, loss_i: 0.001, loss_h: 0.125, loss_o: 0.002
# Episode: 265, episode steps: 11, avg. reward: 12.38, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 266, episode steps: 8, avg. reward: 12.37, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 267, episode steps: 9, avg. reward: 12.36, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 268, episode steps: 8, avg. reward: 12.34, loss_i: 0.001, loss_h: 0.099, loss_o: 0.002
# Episode: 269, episode steps: 10, avg. reward: 12.33, loss_i: 0.001, loss_h: 0.099, loss_o: 0.002
# Episode: 270, episode steps: 10, avg. reward: 12.32, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 271, episode steps: 10, avg. reward: 12.31, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 272, episode steps: 12, avg. reward: 12.31, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 273, episode steps: 11, avg. reward: 12.31, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 274, episode steps: 11, avg. reward: 12.3, loss_i: 0.001, loss_h: 0.125, loss_o: 0.002
# Episode: 275, episode steps: 9, avg. reward: 12.29, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 276, episode steps: 11, avg. reward: 12.29, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 277, episode steps: 9, avg. reward: 12.27, loss_i: 0.001, loss_h: 0.09, loss_o: 0.002
# Episode: 278, episode steps: 9, avg. reward: 12.26, loss_i: 0.001, loss_h: 0.115, loss_o: 0.002
# Episode: 279, episode steps: 12, avg. reward: 12.26, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 280, episode steps: 13, avg. reward: 12.26, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 281, episode steps: 11, avg. reward: 12.26, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 282, episode steps: 9, avg. reward: 12.25, loss_i: 0.001, loss_h: 0.111, loss_o: 0.002
# Episode: 283, episode steps: 10, avg. reward: 12.24, loss_i: 0.001, loss_h: 0.114, loss_o: 0.002
# Episode: 284, episode steps: 10, avg. reward: 12.23, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 285, episode steps: 9, avg. reward: 12.22, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 286, episode steps: 10, avg. reward: 12.21, loss_i: 0.001, loss_h: 0.104, loss_o: 0.002
# Episode: 287, episode steps: 9, avg. reward: 12.2, loss_i: 0.001, loss_h: 0.109, loss_o: 0.002
# Episode: 288, episode steps: 12, avg. reward: 12.2, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 289, episode steps: 13, avg. reward: 12.2, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 290, episode steps: 9, avg. reward: 12.19, loss_i: 0.001, loss_h: 0.104, loss_o: 0.002
# Episode: 291, episode steps: 9, avg. reward: 12.18, loss_i: 0.001, loss_h: 0.079, loss_o: 0.002
# Episode: 292, episode steps: 11, avg. reward: 12.18, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 293, episode steps: 10, avg. reward: 12.17, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 294, episode steps: 10, avg. reward: 12.16, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 295, episode steps: 10, avg. reward: 12.16, loss_i: 0.001, loss_h: 0.127, loss_o: 0.002
# Episode: 296, episode steps: 8, avg. reward: 12.14, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 297, episode steps: 12, avg. reward: 12.14, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 298, episode steps: 9, avg. reward: 12.13, loss_i: 0.001, loss_h: 0.105, loss_o: 0.002
# Episode: 299, episode steps: 10, avg. reward: 12.12, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 300, episode steps: 9, avg. reward: 12.11, loss_i: 0.001, loss_h: 0.102, loss_o: 0.002
# Episode: 301, episode steps: 11, avg. reward: 12.11, loss_i: 0.001, loss_h: 0.1, loss_o: 0.002
# Episode: 302, episode steps: 10, avg. reward: 12.1, loss_i: 0.001, loss_h: 0.128, loss_o: 0.002
# Episode: 303, episode steps: 11, avg. reward: 12.1, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 304, episode steps: 10, avg. reward: 12.09, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 305, episode steps: 10, avg. reward: 12.09, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 306, episode steps: 15, avg. reward: 12.09, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 307, episode steps: 11, avg. reward: 12.09, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 308, episode steps: 11, avg. reward: 12.09, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 309, episode steps: 10, avg. reward: 12.08, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 310, episode steps: 10, avg. reward: 12.07, loss_i: 0.001, loss_h: 0.105, loss_o: 0.002
# Episode: 311, episode steps: 12, avg. reward: 12.07, loss_i: 0.001, loss_h: 0.115, loss_o: 0.002
# Episode: 312, episode steps: 10, avg. reward: 12.07, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 313, episode steps: 14, avg. reward: 12.07, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 314, episode steps: 10, avg. reward: 12.07, loss_i: 0.001, loss_h: 0.081, loss_o: 0.002
# Episode: 315, episode steps: 10, avg. reward: 12.06, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 316, episode steps: 10, avg. reward: 12.05, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 317, episode steps: 10, avg. reward: 12.05, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 318, episode steps: 8, avg. reward: 12.03, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 319, episode steps: 8, avg. reward: 12.02, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 320, episode steps: 9, avg. reward: 12.01, loss_i: 0.001, loss_h: 0.119, loss_o: 0.002
# Episode: 321, episode steps: 8, avg. reward: 12.0, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 322, episode steps: 11, avg. reward: 12.0, loss_i: 0.001, loss_h: 0.134, loss_o: 0.002
# Episode: 323, episode steps: 9, avg. reward: 11.99, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 324, episode steps: 9, avg. reward: 11.98, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 325, episode steps: 12, avg. reward: 11.98, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 326, episode steps: 9, avg. reward: 11.97, loss_i: 0.001, loss_h: 0.119, loss_o: 0.002
# Episode: 327, episode steps: 9, avg. reward: 11.96, loss_i: 0.001, loss_h: 0.101, loss_o: 0.002
# Episode: 328, episode steps: 13, avg. reward: 11.96, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 329, episode steps: 8, avg. reward: 11.95, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 330, episode steps: 9, avg. reward: 11.94, loss_i: 0.001, loss_h: 0.087, loss_o: 0.002
# Episode: 331, episode steps: 10, avg. reward: 11.94, loss_i: 0.001, loss_h: 0.106, loss_o: 0.002
# Episode: 332, episode steps: 13, avg. reward: 11.94, loss_i: 0.001, loss_h: 0.125, loss_o: 0.002
# Episode: 333, episode steps: 10, avg. reward: 11.93, loss_i: 0.001, loss_h: 0.112, loss_o: 0.002
# Episode: 334, episode steps: 8, avg. reward: 11.92, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 335, episode steps: 11, avg. reward: 11.92, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 336, episode steps: 10, avg. reward: 11.91, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 337, episode steps: 9, avg. reward: 11.91, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 338, episode steps: 10, avg. reward: 11.9, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 339, episode steps: 9, avg. reward: 11.89, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 340, episode steps: 12, avg. reward: 11.89, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 341, episode steps: 9, avg. reward: 11.88, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 342, episode steps: 11, avg. reward: 11.88, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 343, episode steps: 11, avg. reward: 11.88, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 344, episode steps: 12, avg. reward: 11.88, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 345, episode steps: 12, avg. reward: 11.88, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 346, episode steps: 10, avg. reward: 11.87, loss_i: 0.001, loss_h: 0.124, loss_o: 0.002
# Episode: 347, episode steps: 10, avg. reward: 11.87, loss_i: 0.001, loss_h: 0.077, loss_o: 0.002
# Episode: 348, episode steps: 10, avg. reward: 11.86, loss_i: 0.001, loss_h: 0.092, loss_o: 0.002
# Episode: 349, episode steps: 10, avg. reward: 11.86, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 350, episode steps: 9, avg. reward: 11.85, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 351, episode steps: 9, avg. reward: 11.84, loss_i: 0.001, loss_h: 0.113, loss_o: 0.002
# Episode: 352, episode steps: 10, avg. reward: 11.84, loss_i: 0.001, loss_h: 0.076, loss_o: 0.002
# Episode: 353, episode steps: 10, avg. reward: 11.83, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 354, episode steps: 8, avg. reward: 11.82, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 355, episode steps: 9, avg. reward: 11.81, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 356, episode steps: 12, avg. reward: 11.81, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 357, episode steps: 8, avg. reward: 11.8, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 358, episode steps: 8, avg. reward: 11.79, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 359, episode steps: 9, avg. reward: 11.78, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 360, episode steps: 8, avg. reward: 11.77, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 361, episode steps: 10, avg. reward: 11.77, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 362, episode steps: 10, avg. reward: 11.76, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 363, episode steps: 9, avg. reward: 11.75, loss_i: 0.001, loss_h: 0.083, loss_o: 0.002
# Episode: 364, episode steps: 8, avg. reward: 11.74, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 365, episode steps: 18, avg. reward: 11.76, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 366, episode steps: 11, avg. reward: 11.76, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 367, episode steps: 13, avg. reward: 11.76, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 368, episode steps: 8, avg. reward: 11.75, loss_i: 0.001, loss_h: 0.083, loss_o: 0.002
# Episode: 369, episode steps: 12, avg. reward: 11.75, loss_i: 0.001, loss_h: 0.123, loss_o: 0.002
# Episode: 370, episode steps: 10, avg. reward: 11.75, loss_i: 0.001, loss_h: 0.1, loss_o: 0.002
# Episode: 371, episode steps: 10, avg. reward: 11.74, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 372, episode steps: 11, avg. reward: 11.74, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 373, episode steps: 10, avg. reward: 11.74, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 374, episode steps: 11, avg. reward: 11.74, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 375, episode steps: 9, avg. reward: 11.73, loss_i: 0.001, loss_h: 0.086, loss_o: 0.002
# Episode: 376, episode steps: 10, avg. reward: 11.72, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 377, episode steps: 8, avg. reward: 11.71, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 378, episode steps: 11, avg. reward: 11.71, loss_i: 0.001, loss_h: 0.109, loss_o: 0.002
# Episode: 379, episode steps: 11, avg. reward: 11.71, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 380, episode steps: 12, avg. reward: 11.71, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 381, episode steps: 9, avg. reward: 11.7, loss_i: 0.001, loss_h: 0.093, loss_o: 0.002
# Episode: 382, episode steps: 12, avg. reward: 11.7, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 383, episode steps: 9, avg. reward: 11.7, loss_i: 0.001, loss_h: 0.082, loss_o: 0.002
# Episode: 384, episode steps: 11, avg. reward: 11.7, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 385, episode steps: 11, avg. reward: 11.69, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 386, episode steps: 11, avg. reward: 11.69, loss_i: 0.001, loss_h: 0.103, loss_o: 0.002
# Episode: 387, episode steps: 10, avg. reward: 11.69, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 388, episode steps: 10, avg. reward: 11.68, loss_i: 0.001, loss_h: 0.12, loss_o: 0.002
# Episode: 389, episode steps: 12, avg. reward: 11.68, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 390, episode steps: 11, avg. reward: 11.68, loss_i: 0.001, loss_h: 0.086, loss_o: 0.002
# Episode: 391, episode steps: 9, avg. reward: 11.68, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 392, episode steps: 10, avg. reward: 11.67, loss_i: 0.001, loss_h: 0.092, loss_o: 0.002
# Episode: 393, episode steps: 9, avg. reward: 11.66, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 394, episode steps: 13, avg. reward: 11.67, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 395, episode steps: 10, avg. reward: 11.66, loss_i: 0.001, loss_h: 0.001, loss_o: 0.002
# Episode: 396, episode steps: 9, avg. reward: 11.66, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 397, episode steps: 11, avg. reward: 11.65, loss_i: 0.001, loss_h: 0.094, loss_o: 0.002
# Episode: 398, episode steps: 12, avg. reward: 11.66, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# Episode: 399, episode steps: 9, avg. reward: 11.65, loss_i: 0.001, loss_h: 0.091, loss_o: 0.002
# Episode: 400, episode steps: 10, avg. reward: 11.64, loss_i: 0.001, loss_h: 0.002, loss_o: 0.002
# --TARGET UPDATED----TARGET UPDATED----TARGET UPDATED--
# i: [ True  True  True  True]
# h: [ True  True  True  True]
# o: [ True]
# --------------------------------------------------------------------------------
# Episode: 401, episode steps: 10, avg. reward: 11.64, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 402, episode steps: 9, avg. reward: 11.63, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 403, episode steps: 11, avg. reward: 11.63, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 404, episode steps: 9, avg. reward: 11.63, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 405, episode steps: 10, avg. reward: 11.62, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 406, episode steps: 12, avg. reward: 11.62, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 407, episode steps: 10, avg. reward: 11.62, loss_i: 34.851, loss_h: nan, loss_o: 2.754
# Episode: 408, episode steps: 17, avg. reward: 11.63, loss_i: 0.232, loss_h: nan, loss_o: 0.078
# Episode: 409, episode steps: 9, avg. reward: 11.63, loss_i: 0.163, loss_h: nan, loss_o: 0.073
# Episode: 410, episode steps: 14, avg. reward: 11.63, loss_i: 0.153, loss_h: nan, loss_o: 0.072
# Episode: 411, episode steps: 9, avg. reward: 11.63, loss_i: 0.127, loss_h: 3.0, loss_o: 0.069
# Episode: 412, episode steps: 15, avg. reward: 11.63, loss_i: 0.135, loss_h: 6.893, loss_o: 0.064
# Episode: 413, episode steps: 11, avg. reward: 11.63, loss_i: 0.127, loss_h: 2.656, loss_o: 0.069
# Episode: 414, episode steps: 9, avg. reward: 11.63, loss_i: 0.13, loss_h: 2.666, loss_o: 0.066
# Episode: 415, episode steps: 17, avg. reward: 11.64, loss_i: 0.122, loss_h: 8.604, loss_o: 0.068
# Episode: 416, episode steps: 10, avg. reward: 11.63, loss_i: 0.113, loss_h: 3.012, loss_o: 0.068
# Episode: 417, episode steps: 10, avg. reward: 11.63, loss_i: 0.111, loss_h: 2.811, loss_o: 0.072
# Episode: 418, episode steps: 8, avg. reward: 11.62, loss_i: 0.105, loss_h: 0.047, loss_o: 0.065
# Episode: 419, episode steps: 13, avg. reward: 11.63, loss_i: 0.104, loss_h: 3.571, loss_o: 0.072
# Episode: 420, episode steps: 10, avg. reward: 11.62, loss_i: 0.101, loss_h: 2.915, loss_o: 0.061
# Episode: 421, episode steps: 10, avg. reward: 11.62, loss_i: 0.11, loss_h: 2.767, loss_o: 0.061
# Episode: 422, episode steps: 13, avg. reward: 11.62, loss_i: 0.099, loss_h: 0.037, loss_o: 0.074
# Episode: 423, episode steps: 10, avg. reward: 11.62, loss_i: 0.099, loss_h: 0.039, loss_o: 0.062
# Episode: 424, episode steps: 8, avg. reward: 11.61, loss_i: 0.106, loss_h: 2.052, loss_o: 0.063
# Episode: 425, episode steps: 9, avg. reward: 11.6, loss_i: 0.096, loss_h: 0.036, loss_o: 0.061
# Episode: 426, episode steps: 9, avg. reward: 11.6, loss_i: 0.097, loss_h: 0.034, loss_o: 0.071
# Episode: 427, episode steps: 8, avg. reward: 11.59, loss_i: 0.091, loss_h: 2.017, loss_o: 0.063
# Episode: 428, episode steps: 9, avg. reward: 11.58, loss_i: 0.095, loss_h: 0.035, loss_o: 0.072
# Episode: 429, episode steps: 11, avg. reward: 11.58, loss_i: 0.094, loss_h: 0.036, loss_o: 0.059
# Episode: 430, episode steps: 10, avg. reward: 11.58, loss_i: 0.1, loss_h: 0.039, loss_o: 0.057
# Episode: 431, episode steps: 11, avg. reward: 11.58, loss_i: 0.099, loss_h: 0.038, loss_o: 0.062
# Episode: 432, episode steps: 10, avg. reward: 11.57, loss_i: 0.092, loss_h: 2.766, loss_o: 0.058
# Episode: 433, episode steps: 12, avg. reward: 11.57, loss_i: 0.091, loss_h: 0.039, loss_o: 0.058
# Episode: 434, episode steps: 11, avg. reward: 11.57, loss_i: 0.09, loss_h: 0.035, loss_o: 0.06
# Episode: 435, episode steps: 11, avg. reward: 11.57, loss_i: 0.094, loss_h: 2.879, loss_o: 0.062
# Episode: 436, episode steps: 10, avg. reward: 11.57, loss_i: 0.094, loss_h: 0.04, loss_o: 0.059
# Episode: 437, episode steps: 10, avg. reward: 11.56, loss_i: 0.086, loss_h: 0.037, loss_o: 0.058
# Episode: 438, episode steps: 9, avg. reward: 11.56, loss_i: 0.093, loss_h: 0.039, loss_o: 0.058
# Episode: 439, episode steps: 9, avg. reward: 11.55, loss_i: 0.093, loss_h: 2.29, loss_o: 0.058
# Episode: 440, episode steps: 12, avg. reward: 11.55, loss_i: 0.091, loss_h: 0.04, loss_o: 0.061
# Episode: 441, episode steps: 10, avg. reward: 11.55, loss_i: 0.085, loss_h: 0.036, loss_o: 0.064
# Episode: 442, episode steps: 11, avg. reward: 11.55, loss_i: 0.094, loss_h: 2.642, loss_o: 0.068
# Episode: 443, episode steps: 10, avg. reward: 11.54, loss_i: 0.087, loss_h: 0.038, loss_o: 0.072
# Episode: 444, episode steps: 10, avg. reward: 11.54, loss_i: 0.087, loss_h: 0.033, loss_o: 0.067
# Episode: 445, episode steps: 10, avg. reward: 11.54, loss_i: 0.091, loss_h: 2.349, loss_o: 0.06
# Episode: 446, episode steps: 10, avg. reward: 11.53, loss_i: 0.089, loss_h: 0.033, loss_o: 0.056
# Episode: 447, episode steps: 11, avg. reward: 11.53, loss_i: 0.093, loss_h: 2.502, loss_o: 0.061
# Episode: 448, episode steps: 9, avg. reward: 11.53, loss_i: 0.092, loss_h: 0.036, loss_o: 0.052
# Episode: 449, episode steps: 10, avg. reward: 11.52, loss_i: 0.087, loss_h: 2.315, loss_o: 0.053
# Episode: 450, episode steps: 12, avg. reward: 11.52, loss_i: 0.09, loss_h: 0.036, loss_o: 0.056
# Episode: 451, episode steps: 11, avg. reward: 11.52, loss_i: 0.09, loss_h: 0.038, loss_o: 0.061
# Episode: 452, episode steps: 12, avg. reward: 11.52, loss_i: 0.085, loss_h: 2.565, loss_o: 0.062
# Episode: 453, episode steps: 10, avg. reward: 11.52, loss_i: 0.088, loss_h: 2.348, loss_o: 0.055
# Episode: 454, episode steps: 10, avg. reward: 11.52, loss_i: 0.091, loss_h: 0.037, loss_o: 0.066
# Episode: 455, episode steps: 10, avg. reward: 11.51, loss_i: 0.086, loss_h: 0.036, loss_o: 0.063
# Episode: 456, episode steps: 12, avg. reward: 11.52, loss_i: 0.086, loss_h: 0.034, loss_o: 0.066
# Episode: 457, episode steps: 9, avg. reward: 11.51, loss_i: 0.093, loss_h: 1.979, loss_o: 0.059
# Episode: 458, episode steps: 13, avg. reward: 11.51, loss_i: 0.085, loss_h: 2.909, loss_o: 0.06
# Episode: 459, episode steps: 13, avg. reward: 11.52, loss_i: 0.08, loss_h: 0.036, loss_o: 0.065
# Episode: 460, episode steps: 10, avg. reward: 11.51, loss_i: 0.085, loss_h: 0.033, loss_o: 0.056
# Episode: 461, episode steps: 10, avg. reward: 11.51, loss_i: 0.082, loss_h: 2.192, loss_o: 0.06
# Episode: 462, episode steps: 9, avg. reward: 11.5, loss_i: 0.083, loss_h: 1.893, loss_o: 0.059
# Episode: 463, episode steps: 9, avg. reward: 11.5, loss_i: 0.08, loss_h: 2.338, loss_o: 0.058
# Episode: 464, episode steps: 9, avg. reward: 11.49, loss_i: 0.085, loss_h: 2.116, loss_o: 0.054
# Episode: 465, episode steps: 10, avg. reward: 11.49, loss_i: 0.08, loss_h: 0.036, loss_o: 0.055
# Episode: 466, episode steps: 10, avg. reward: 11.49, loss_i: 0.082, loss_h: 0.032, loss_o: 0.054
# Episode: 467, episode steps: 11, avg. reward: 11.49, loss_i: 0.09, loss_h: 0.032, loss_o: 0.055
# Episode: 468, episode steps: 9, avg. reward: 11.48, loss_i: 0.085, loss_h: 2.008, loss_o: 0.047
# Episode: 469, episode steps: 13, avg. reward: 11.48, loss_i: 0.083, loss_h: 0.03, loss_o: 0.059
# Episode: 470, episode steps: 10, avg. reward: 11.48, loss_i: 0.085, loss_h: 0.037, loss_o: 0.059
# Episode: 471, episode steps: 9, avg. reward: 11.48, loss_i: 0.085, loss_h: 1.941, loss_o: 0.055
# Episode: 472, episode steps: 11, avg. reward: 11.47, loss_i: 0.082, loss_h: 0.031, loss_o: 0.054
# Episode: 473, episode steps: 11, avg. reward: 11.47, loss_i: 0.086, loss_h: 2.853, loss_o: 0.051
# Episode: 474, episode steps: 9, avg. reward: 11.47, loss_i: 0.081, loss_h: 0.032, loss_o: 0.057
# Episode: 475, episode steps: 9, avg. reward: 11.46, loss_i: 0.089, loss_h: 0.034, loss_o: 0.062
# Episode: 476, episode steps: 9, avg. reward: 11.46, loss_i: 0.084, loss_h: 0.035, loss_o: 0.056
# Episode: 477, episode steps: 9, avg. reward: 11.45, loss_i: 0.083, loss_h: 1.87, loss_o: 0.053
# Episode: 478, episode steps: 10, avg. reward: 11.45, loss_i: 0.081, loss_h: 2.148, loss_o: 0.058
# Episode: 479, episode steps: 9, avg. reward: 11.44, loss_i: 0.079, loss_h: 0.035, loss_o: 0.06
# Episode: 480, episode steps: 11, avg. reward: 11.44, loss_i: 0.085, loss_h: 0.036, loss_o: 0.065
# Episode: 481, episode steps: 10, avg. reward: 11.44, loss_i: 0.087, loss_h: 2.496, loss_o: 0.043
# Episode: 482, episode steps: 8, avg. reward: 11.43, loss_i: 0.072, loss_h: 0.035, loss_o: 0.064
# Episode: 483, episode steps: 9, avg. reward: 11.43, loss_i: 0.082, loss_h: 0.03, loss_o: 0.059
# Episode: 484, episode steps: 10, avg. reward: 11.43, loss_i: 0.088, loss_h: 0.032, loss_o: 0.057
# Episode: 485, episode steps: 12, avg. reward: 11.43, loss_i: 0.084, loss_h: 0.031, loss_o: 0.047
# Episode: 486, episode steps: 9, avg. reward: 11.42, loss_i: 0.082, loss_h: 1.802, loss_o: 0.046
# Episode: 487, episode steps: 11, avg. reward: 11.42, loss_i: 0.082, loss_h: 0.038, loss_o: 0.058
# Episode: 488, episode steps: 10, avg. reward: 11.42, loss_i: 0.08, loss_h: 0.035, loss_o: 0.062
# Episode: 489, episode steps: 12, avg. reward: 11.42, loss_i: 0.084, loss_h: 0.033, loss_o: 0.056
# Episode: 490, episode steps: 9, avg. reward: 11.41, loss_i: 0.08, loss_h: 2.076, loss_o: 0.056
# Episode: 491, episode steps: 10, avg. reward: 11.41, loss_i: 0.088, loss_h: 0.034, loss_o: 0.063
# Episode: 492, episode steps: 10, avg. reward: 11.41, loss_i: 0.083, loss_h: 0.036, loss_o: 0.065
# Episode: 493, episode steps: 11, avg. reward: 11.41, loss_i: 0.086, loss_h: 0.036, loss_o: 0.063
# Episode: 494, episode steps: 9, avg. reward: 11.4, loss_i: 0.08, loss_h: 0.035, loss_o: 0.058
# Episode: 495, episode steps: 9, avg. reward: 11.4, loss_i: 0.089, loss_h: 0.036, loss_o: 0.054
# Episode: 496, episode steps: 8, avg. reward: 11.39, loss_i: 0.077, loss_h: 0.033, loss_o: 0.054
# ...
# Episode: 6485, episode steps: 9, avg. reward: 9.53, loss_i: 23.098, loss_h: 1.244, loss_o: 2.812
# Episode: 6486, episode steps: 11, avg. reward: 9.53, loss_i: 13.805, loss_h: 1.271, loss_o: 2.436
# Episode: 6487, episode steps: 10, avg. reward: 9.53, loss_i: 17.584, loss_h: 1.271, loss_o: 2.224
# Episode: 6488, episode steps: 10, avg. reward: 9.53, loss_i: 14.464, loss_h: 1.3, loss_o: 2.169
# Episode: 6489, episode steps: 9, avg. reward: 9.53, loss_i: 16.052, loss_h: 76.338, loss_o: 2.343
# Episode: 6490, episode steps: 10, avg. reward: 9.53, loss_i: 14.179, loss_h: 77.777, loss_o: 2.329
# Episode: 6491, episode steps: 10, avg. reward: 9.53, loss_i: 21.91, loss_h: 103.028, loss_o: 2.593
# Episode: 6492, episode steps: 12, avg. reward: 9.54, loss_i: 15.515, loss_h: 1.44, loss_o: 2.48
# Episode: 6493, episode steps: 10, avg. reward: 9.54, loss_i: 16.767, loss_h: 1.418, loss_o: 2.233
# Episode: 6494, episode steps: 11, avg. reward: 9.54, loss_i: 13.186, loss_h: 91.266, loss_o: 2.428
# Episode: 6495, episode steps: 9, avg. reward: 9.54, loss_i: 19.915, loss_h: 1.276, loss_o: 2.667
# Episode: 6496, episode steps: 9, avg. reward: 9.54, loss_i: 17.335, loss_h: 1.2, loss_o: 2.225
# Episode: 6497, episode steps: 9, avg. reward: 9.54, loss_i: 18.611, loss_h: 73.112, loss_o: 2.333
# Episode: 6498, episode steps: 10, avg. reward: 9.54, loss_i: 15.591, loss_h: 1.158, loss_o: 2.076
# Episode: 6499, episode steps: 8, avg. reward: 9.54, loss_i: 12.967, loss_h: 1.313, loss_o: 2.343
# Episode: 6500, episode steps: 9, avg. reward: 9.53, loss_i: 13.173, loss_h: 1.145, loss_o: 2.603
# Episode: 6501, episode steps: 9, avg. reward: 9.53, loss_i: 15.4, loss_h: 1.347, loss_o: 2.546
# Episode: 6502, episode steps: 9, avg. reward: 9.53, loss_i: 13.587, loss_h: 1.267, loss_o: 2.417
# Episode: 6503, episode steps: 8, avg. reward: 9.53, loss_i: 12.93, loss_h: 1.5, loss_o: 2.557
# Episode: 6504, episode steps: 8, avg. reward: 9.53, loss_i: 13.438, loss_h: 55.854, loss_o: 2.357
# Episode: 6505, episode steps: 10, avg. reward: 9.53, loss_i: 13.641, loss_h: 1.137, loss_o: 2.234
# Episode: 6506, episode steps: 9, avg. reward: 9.53, loss_i: 11.458, loss_h: 1.212, loss_o: 2.219
# Episode: 6507, episode steps: 10, avg. reward: 9.53, loss_i: 16.616, loss_h: 102.793, loss_o: 2.032
# Episode: 6508, episode steps: 8, avg. reward: 9.52, loss_i: 13.551, loss_h: 1.159, loss_o: 2.851
# Episode: 6509, episode steps: 9, avg. reward: 9.52, loss_i: 19.383, loss_h: 85.655, loss_o: 2.225
# Episode: 6510, episode steps: 9, avg. reward: 9.52, loss_i: 15.043, loss_h: 1.25, loss_o: 2.129
# Episode: 6511, episode steps: 8, avg. reward: 9.52, loss_i: 14.243, loss_h: 72.534, loss_o: 2.362
# Episode: 6512, episode steps: 9, avg. reward: 9.52, loss_i: 12.643, loss_h: 85.509, loss_o: 2.43
# Episode: 6513, episode steps: 12, avg. reward: 9.52, loss_i: 13.364, loss_h: 89.783, loss_o: 2.177
# Episode: 6514, episode steps: 8, avg. reward: 9.52, loss_i: 14.475, loss_h: 1.201, loss_o: 2.605
# Episode: 6515, episode steps: 9, avg. reward: 9.52, loss_i: 15.955, loss_h: 1.048, loss_o: 2.279
# Episode: 6516, episode steps: 8, avg. reward: 9.52, loss_i: 14.978, loss_h: 76.87, loss_o: 2.566
# Episode: 6517, episode steps: 9, avg. reward: 9.51, loss_i: 12.463, loss_h: 84.059, loss_o: 2.718
# Episode: 6518, episode steps: 9, avg. reward: 9.51, loss_i: 17.127, loss_h: 83.331, loss_o: 2.388
# Episode: 6519, episode steps: 9, avg. reward: 9.51, loss_i: 12.925, loss_h: 96.807, loss_o: 2.541
# Episode: 6520, episode steps: 9, avg. reward: 9.51, loss_i: 14.094, loss_h: 78.485, loss_o: 2.526
# Episode: 6521, episode steps: 10, avg. reward: 9.51, loss_i: 13.361, loss_h: 97.43, loss_o: 2.256
# Episode: 6522, episode steps: 10, avg. reward: 9.51, loss_i: 14.903, loss_h: 1.257, loss_o: 2.599
# Episode: 6523, episode steps: 9, avg. reward: 9.51, loss_i: 15.399, loss_h: 1.405, loss_o: 2.514
# Episode: 6524, episode steps: 9, avg. reward: 9.51, loss_i: 16.598, loss_h: 1.278, loss_o: 2.31
# Episode: 6525, episode steps: 9, avg. reward: 9.51, loss_i: 13.563, loss_h: 1.463, loss_o: 2.626
# Episode: 6526, episode steps: 10, avg. reward: 9.51, loss_i: 15.016, loss_h: 84.375, loss_o: 2.02
# Episode: 6527, episode steps: 10, avg. reward: 9.51, loss_i: 15.774, loss_h: 1.286, loss_o: 2.484
# Episode: 6528, episode steps: 11, avg. reward: 9.52, loss_i: 15.431, loss_h: 1.477, loss_o: 2.147
# Episode: 6529, episode steps: 11, avg. reward: 9.52, loss_i: 13.472, loss_h: 1.216, loss_o: 2.341
# Episode: 6530, episode steps: 9, avg. reward: 9.52, loss_i: 13.136, loss_h: 1.273, loss_o: 2.779
# Episode: 6531, episode steps: 11, avg. reward: 9.52, loss_i: 16.12, loss_h: 91.393, loss_o: 2.456
# Episode: 6532, episode steps: 10, avg. reward: 9.52, loss_i: 12.722, loss_h: 1.524, loss_o: 2.088
# Episode: 6533, episode steps: 9, avg. reward: 9.52, loss_i: 17.927, loss_h: 1.405, loss_o: 2.464
# Episode: 6534, episode steps: 10, avg. reward: 9.52, loss_i: 16.136, loss_h: 88.022, loss_o: 2.307
# Episode: 6535, episode steps: 9, avg. reward: 9.52, loss_i: 14.698, loss_h: 1.195, loss_o: 2.125
# Episode: 6536, episode steps: 9, avg. reward: 9.52, loss_i: 14.934, loss_h: 1.039, loss_o: 2.414
# Episode: 6537, episode steps: 9, avg. reward: 9.52, loss_i: 17.795, loss_h: 73.799, loss_o: 1.93
# Episode: 6538, episode steps: 10, avg. reward: 9.52, loss_i: 16.026, loss_h: 1.311, loss_o: 2.607
# Episode: 6539, episode steps: 9, avg. reward: 9.52, loss_i: 16.238, loss_h: 1.293, loss_o: 2.356
# Episode: 6540, episode steps: 13, avg. reward: 9.52, loss_i: 14.147, loss_h: 1.222, loss_o: 2.403
# Episode: 6541, episode steps: 12, avg. reward: 9.53, loss_i: 13.343, loss_h: 1.069, loss_o: 2.257
# Episode: 6542, episode steps: 9, avg. reward: 9.53, loss_i: 14.811, loss_h: 1.099, loss_o: 2.257
# Episode: 6543, episode steps: 10, avg. reward: 9.53, loss_i: 9.993, loss_h: 1.432, loss_o: 2.155
# Episode: 6544, episode steps: 10, avg. reward: 9.53, loss_i: 11.446, loss_h: 1.331, loss_o: 2.662
# Episode: 6545, episode steps: 10, avg. reward: 9.53, loss_i: 13.412, loss_h: 1.492, loss_o: 2.771
# Episode: 6546, episode steps: 12, avg. reward: 9.53, loss_i: 19.827, loss_h: 1.186, loss_o: 2.4
# Episode: 6547, episode steps: 10, avg. reward: 9.54, loss_i: 14.984, loss_h: 1.222, loss_o: 2.084
# Episode: 6548, episode steps: 9, avg. reward: 9.53, loss_i: 13.099, loss_h: 1.072, loss_o: 2.684
# Episode: 6549, episode steps: 9, avg. reward: 9.53, loss_i: 15.091, loss_h: 1.443, loss_o: 2.281
# Episode: 6550, episode steps: 10, avg. reward: 9.53, loss_i: 15.344, loss_h: 1.124, loss_o: 2.88
# Episode: 6551, episode steps: 10, avg. reward: 9.54, loss_i: 17.521, loss_h: 1.169, loss_o: 2.16
# Episode: 6552, episode steps: 8, avg. reward: 9.53, loss_i: 11.592, loss_h: 67.462, loss_o: 2.244
# Episode: 6553, episode steps: 10, avg. reward: 9.53, loss_i: 16.339, loss_h: 1.376, loss_o: 2.391
# Episode: 6554, episode steps: 10, avg. reward: 9.53, loss_i: 17.71, loss_h: 73.087, loss_o: 2.33
# Episode: 6555, episode steps: 10, avg. reward: 9.54, loss_i: 17.321, loss_h: 1.188, loss_o: 2.131
# Episode: 6556, episode steps: 10, avg. reward: 9.54, loss_i: 18.157, loss_h: 100.384, loss_o: 2.223
# Episode: 6557, episode steps: 9, avg. reward: 9.54, loss_i: 14.161, loss_h: 61.349, loss_o: 2.231
# Episode: 6558, episode steps: 10, avg. reward: 9.54, loss_i: 17.296, loss_h: 1.132, loss_o: 2.339
# Episode: 6559, episode steps: 9, avg. reward: 9.53, loss_i: 14.618, loss_h: 74.293, loss_o: 2.266
# Episode: 6560, episode steps: 9, avg. reward: 9.53, loss_i: 15.856, loss_h: 0.939, loss_o: 2.69
# Episode: 6561, episode steps: 8, avg. reward: 9.53, loss_i: 14.318, loss_h: 1.507, loss_o: 2.552
# Episode: 6562, episode steps: 9, avg. reward: 9.53, loss_i: 16.122, loss_h: 1.038, loss_o: 2.219
# Episode: 6563, episode steps: 9, avg. reward: 9.53, loss_i: 11.585, loss_h: 1.234, loss_o: 2.291
# Episode: 6564, episode steps: 12, avg. reward: 9.53, loss_i: 13.578, loss_h: 1.189, loss_o: 1.996
# Episode: 6565, episode steps: 10, avg. reward: 9.53, loss_i: 14.304, loss_h: 1.232, loss_o: 1.978
# Episode: 6566, episode steps: 10, avg. reward: 9.54, loss_i: 15.785, loss_h: 1.126, loss_o: 2.585
# Episode: 6567, episode steps: 11, avg. reward: 9.54, loss_i: 18.107, loss_h: 69.015, loss_o: 2.23
# Episode: 6568, episode steps: 10, avg. reward: 9.54, loss_i: 12.82, loss_h: 75.625, loss_o: 2.589
# Episode: 6569, episode steps: 9, avg. reward: 9.54, loss_i: 13.393, loss_h: 1.187, loss_o: 2.353
# Episode: 6570, episode steps: 10, avg. reward: 9.54, loss_i: 12.696, loss_h: 1.231, loss_o: 1.992
# Episode: 6571, episode steps: 9, avg. reward: 9.54, loss_i: 13.778, loss_h: 57.371, loss_o: 2.283
# Episode: 6572, episode steps: 10, avg. reward: 9.54, loss_i: 14.167, loss_h: 1.328, loss_o: 2.487
# Episode: 6573, episode steps: 10, avg. reward: 9.54, loss_i: 14.52, loss_h: 1.4, loss_o: 2.32
# Episode: 6574, episode steps: 10, avg. reward: 9.54, loss_i: 15.769, loss_h: 1.402, loss_o: 2.385
# Episode: 6575, episode steps: 8, avg. reward: 9.54, loss_i: 14.322, loss_h: 63.535, loss_o: 2.501
# Episode: 6576, episode steps: 8, avg. reward: 9.53, loss_i: 15.046, loss_h: 1.004, loss_o: 1.905
# Episode: 6577, episode steps: 10, avg. reward: 9.54, loss_i: 16.973, loss_h: 1.268, loss_o: 2.622
# Episode: 6578, episode steps: 9, avg. reward: 9.53, loss_i: 14.684, loss_h: 78.404, loss_o: 2.617
# Episode: 6579, episode steps: 9, avg. reward: 9.53, loss_i: 18.658, loss_h: 1.259, loss_o: 2.027
# Episode: 6580, episode steps: 9, avg. reward: 9.53, loss_i: 15.407, loss_h: 75.617, loss_o: 2.071
# Episode: 6581, episode steps: 9, avg. reward: 9.53, loss_i: 18.074, loss_h: 1.272, loss_o: 2.219
# Episode: 6582, episode steps: 9, avg. reward: 9.53, loss_i: 15.84, loss_h: 1.175, loss_o: 1.888
# Episode: 6583, episode steps: 9, avg. reward: 9.53, loss_i: 12.448, loss_h: 85.67, loss_o: 1.993
# Episode: 6584, episode steps: 10, avg. reward: 9.53, loss_i: 14.096, loss_h: 80.244, loss_o: 2.327
# Episode: 6585, episode steps: 9, avg. reward: 9.53, loss_i: 15.204, loss_h: 73.249, loss_o: 2.804
# Episode: 6586, episode steps: 10, avg. reward: 9.53, loss_i: 15.09, loss_h: 74.211, loss_o: 2.246
# Episode: 6587, episode steps: 9, avg. reward: 9.53, loss_i: 13.896, loss_h: 97.881, loss_o: 2.413
# Episode: 6588, episode steps: 10, avg. reward: 9.53, loss_i: 10.804, loss_h: 0.899, loss_o: 2.159
# Episode: 6589, episode steps: 9, avg. reward: 9.53, loss_i: 14.517, loss_h: 1.2, loss_o: 2.58
# Episode: 6590, episode steps: 8, avg. reward: 9.53, loss_i: 15.172, loss_h: 53.908, loss_o: 2.613
# Episode: 6591, episode steps: 10, avg. reward: 9.53, loss_i: 16.549, loss_h: 1.098, loss_o: 2.179
# Episode: 6592, episode steps: 8, avg. reward: 9.53, loss_i: 17.183, loss_h: 1.464, loss_o: 2.606
# Episode: 6593, episode steps: 9, avg. reward: 9.52, loss_i: 13.467, loss_h: 1.378, loss_o: 2.694
# Episode: 6594, episode steps: 10, avg. reward: 9.53, loss_i: 15.367, loss_h: 1.261, loss_o: 2.288
# Episode: 6595, episode steps: 9, avg. reward: 9.52, loss_i: 16.511, loss_h: 86.858, loss_o: 2.567
# Episode: 6596, episode steps: 9, avg. reward: 9.52, loss_i: 13.192, loss_h: 1.178, loss_o: 2.256
# Episode: 6597, episode steps: 10, avg. reward: 9.52, loss_i: 16.263, loss_h: 1.135, loss_o: 2.461
# Episode: 6598, episode steps: 9, avg. reward: 9.52, loss_i: 18.587, loss_h: 1.22, loss_o: 2.274
# Episode: 6599, episode steps: 9, avg. reward: 9.52, loss_i: 19.727, loss_h: 1.018, loss_o: 2.55
# Episode: 6600, episode steps: 8, avg. reward: 9.52, loss_i: 15.259, loss_h: 56.107, loss_o: 2.279
# Episode: 6601, episode steps: 11, avg. reward: 9.52, loss_i: 19.05, loss_h: 1.409, loss_o: 2.404
# Episode: 6602, episode steps: 9, avg. reward: 9.52, loss_i: 11.931, loss_h: 1.405, loss_o: 2.181
# Episode: 6603, episode steps: 10, avg. reward: 9.52, loss_i: 13.989, loss_h: 1.275, loss_o: 2.623
# Episode: 6604, episode steps: 10, avg. reward: 9.52, loss_i: 12.223, loss_h: 76.086, loss_o: 2.529
# Episode: 6605, episode steps: 9, avg. reward: 9.52, loss_i: 12.821, loss_h: 1.205, loss_o: 2.014
# Episode: 6606, episode steps: 13, avg. reward: 9.53, loss_i: 13.521, loss_h: 89.003, loss_o: 2.405
# Episode: 6607, episode steps: 8, avg. reward: 9.53, loss_i: 15.538, loss_h: 1.388, loss_o: 2.756
# Episode: 6608, episode steps: 10, avg. reward: 9.53, loss_i: 17.765, loss_h: 99.84, loss_o: 2.213
# Episode: 6609, episode steps: 9, avg. reward: 9.53, loss_i: 15.412, loss_h: 1.233, loss_o: 2.411
# Episode: 6610, episode steps: 10, avg. reward: 9.53, loss_i: 14.528, loss_h: 86.14, loss_o: 2.58
# Episode: 6611, episode steps: 8, avg. reward: 9.52, loss_i: 18.138, loss_h: 68.323, loss_o: 2.399
# Episode: 6612, episode steps: 9, avg. reward: 9.52, loss_i: 13.723, loss_h: 79.178, loss_o: 2.313
# Episode: 6613, episode steps: 10, avg. reward: 9.52, loss_i: 17.615, loss_h: 1.23, loss_o: 2.15
# Episode: 6614, episode steps: 11, avg. reward: 9.53, loss_i: 14.404, loss_h: 1.208, loss_o: 2.592
# Episode: 6615, episode steps: 10, avg. reward: 9.53, loss_i: 14.017, loss_h: 1.381, loss_o: 2.188
# Episode: 6616, episode steps: 11, avg. reward: 9.53, loss_i: 16.859, loss_h: 77.603, loss_o: 2.034
# Episode: 6617, episode steps: 9, avg. reward: 9.53, loss_i: 11.288, loss_h: 1.08, loss_o: 2.832
# Episode: 6618, episode steps: 9, avg. reward: 9.53, loss_i: 15.004, loss_h: 69.053, loss_o: 2.115
# Episode: 6619, episode steps: 9, avg. reward: 9.53, loss_i: 23.011, loss_h: 81.418, loss_o: 2.212
# Episode: 6620, episode steps: 10, avg. reward: 9.53, loss_i: 16.043, loss_h: 77.047, loss_o: 2.162
# Episode: 6621, episode steps: 10, avg. reward: 9.53, loss_i: 19.379, loss_h: 82.221, loss_o: 2.0
# Episode: 6622, episode steps: 9, avg. reward: 9.53, loss_i: 17.796, loss_h: 1.026, loss_o: 2.367
# Episode: 6623, episode steps: 10, avg. reward: 9.53, loss_i: 11.652, loss_h: 81.882, loss_o: 1.976
# Episode: 6624, episode steps: 10, avg. reward: 9.53, loss_i: 14.282, loss_h: 0.992, loss_o: 2.362
# Episode: 6625, episode steps: 8, avg. reward: 9.53, loss_i: 17.664, loss_h: 1.234, loss_o: 2.293
# Episode: 6626, episode steps: 10, avg. reward: 9.53, loss_i: 13.783, loss_h: 78.628, loss_o: 2.106
# Episode: 6627, episode steps: 9, avg. reward: 9.53, loss_i: 16.743, loss_h: 1.287, loss_o: 2.391
# Episode: 6628, episode steps: 9, avg. reward: 9.53, loss_i: 13.664, loss_h: 78.872, loss_o: 2.468
# Episode: 6629, episode steps: 9, avg. reward: 9.52, loss_i: 15.12, loss_h: 63.404, loss_o: 2.085
# Episode: 6630, episode steps: 9, avg. reward: 9.52, loss_i: 16.512, loss_h: 1.25, loss_o: 2.76
# Episode: 6631, episode steps: 9, avg. reward: 9.52, loss_i: 13.064, loss_h: 69.986, loss_o: 2.451
# Episode: 6632, episode steps: 10, avg. reward: 9.52, loss_i: 16.698, loss_h: 1.269, loss_o: 2.053
# Episode: 6633, episode steps: 9, avg. reward: 9.52, loss_i: 15.955, loss_h: 68.762, loss_o: 2.431
# Episode: 6634, episode steps: 8, avg. reward: 9.52, loss_i: 14.875, loss_h: 72.752, loss_o: 2.432
# Episode: 6635, episode steps: 11, avg. reward: 9.52, loss_i: 17.162, loss_h: 1.443, loss_o: 2.342
# Episode: 6636, episode steps: 8, avg. reward: 9.52, loss_i: 14.816, loss_h: 66.096, loss_o: 2.652
# Episode: 6637, episode steps: 9, avg. reward: 9.52, loss_i: 16.719, loss_h: 1.366, loss_o: 2.435
# Episode: 6638, episode steps: 9, avg. reward: 9.52, loss_i: 16.639, loss_h: 1.221, loss_o: 2.516
# Episode: 6639, episode steps: 10, avg. reward: 9.52, loss_i: 14.014, loss_h: 1.199, loss_o: 2.27
# Episode: 6640, episode steps: 9, avg. reward: 9.52, loss_i: 18.186, loss_h: 77.085, loss_o: 2.312
# Episode: 6641, episode steps: 10, avg. reward: 9.52, loss_i: 13.745, loss_h: 1.152, loss_o: 2.542
# Episode: 6642, episode steps: 10, avg. reward: 9.52, loss_i: 14.97, loss_h: 73.881, loss_o: 2.035
# Episode: 6643, episode steps: 8, avg. reward: 9.52, loss_i: 13.02, loss_h: 67.775, loss_o: 2.292
# Episode: 6644, episode steps: 8, avg. reward: 9.52, loss_i: 14.462, loss_h: 1.244, loss_o: 2.214
# Episode: 6645, episode steps: 9, avg. reward: 9.51, loss_i: 15.973, loss_h: 52.774, loss_o: 2.108
# Episode: 6646, episode steps: 9, avg. reward: 9.51, loss_i: 23.035, loss_h: 1.237, loss_o: 2.285
# Episode: 6647, episode steps: 8, avg. reward: 9.51, loss_i: 16.899, loss_h: 0.9, loss_o: 2.427
# Episode: 6648, episode steps: 8, avg. reward: 9.51, loss_i: 14.062, loss_h: 1.016, loss_o: 2.652
