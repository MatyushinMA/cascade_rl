# %%
from sac import SAC
from replay_memory import ReplayMemory
import gym
from gym import spaces
from addict import Dict
import numpy as np
import itertools
from scipy.special import softmax
import random
from tqdm import tqdm

# %%
WARM_UP = 0
MEMORY_SIZE = 10000
ACT_THRESHOLD = 0
BATCH_SIZE = 64
UPDATES_PER_STEP = 1
PRINT_FREQ = 1000
TEST_EPISODES = 1000
MIN_REQUIRED_UPDATES = 0

# %%
num_inputs = 4
num_hidden = 4
num_outputs = 1
bandwidth = 3

# %%
env = gym.make('CartPole-v0')
env.action_space.shape = (1,)
env.action_space.high = np.array([1])
env.action_space.low = np.array([0])

# %%
input_layer_action_space = gym.spaces.Box(low=0, high=1, shape=(num_hidden + bandwidth,))
hidden_layer_action_space = gym.spaces.Box(low=0, high=1, shape=(num_outputs + bandwidth,))
output_layer_action_space = env.action_space
# Out:
# /home/f1ery/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
args = Dict()
args.gamma = 0.99
args.tau = 1
args.alpha = 0.0
args.policy = 'Gaussian'
args.target_update_interval = 400
args.automatic_entropy_tuning = False
args.cuda = False
args.hidden_size = 256
args.lr = 0.003

# %%
input_layer = [SAC(1, input_layer_action_space, args) for _ in range(num_inputs)]
input_memory = [ReplayMemory(MEMORY_SIZE) for _ in range(num_inputs)]
input_updates = [0 for _ in range(num_inputs)]
hidden_layer = [SAC(bandwidth, hidden_layer_action_space, args) for _ in range(num_hidden)]
hidden_memory = [ReplayMemory(MEMORY_SIZE) for _ in range(num_hidden)]
hidden_updates = [0 for _ in range(num_hidden)]
output_layer = [SAC(bandwidth, output_layer_action_space, args) for _ in range(num_outputs)]
output_memory = [ReplayMemory(MEMORY_SIZE) for _ in range(num_outputs)]
output_updates = [0 for _ in range(num_outputs)]

# %%
def eval_layers(input_state):
    isa = [tuple() for _ in range(num_inputs)]
    hsa = [tuple() for _ in range(num_hidden)]
    osa = [tuple() for _ in range(num_outputs)]
    input_actions = [agent.select_action(input_state[i:i+1]) for i, agent in enumerate(input_layer)]
    for i, input_action in enumerate(input_actions):
        input_action[:num_hidden] = softmax(input_action[:num_hidden])
        if max(input_action[:num_hidden]) > ACT_THRESHOLD:
            isa[i] = (input_state[i:i+1], input_action, True)
            input_actions[i] = (np.argmax(input_action[:num_hidden]), input_action[num_hidden:])
        else:
            isa[i] = (input_state[i:i+1], input_action, False)
            input_actions[i] = tuple()
    hidden_state = [tuple() for _ in range(num_hidden)]
    for input_action in input_actions:
        try:
            hidden_i, hidden_msg = input_action
        except:
            continue
        try:
            hidden_state[hidden_i] += hidden_msg
        except:
            hidden_state[hidden_i] = hidden_msg
    hidden_actions = []
    for i, _hidden_state in enumerate(hidden_state):
        if len(_hidden_state):
            hidden_action = hidden_layer[i].select_action(softmax(hidden_state[i])) 
            if hidden_action[0] > ACT_THRESHOLD:
                hsa[i] = (_hidden_state, hidden_action, True)
                hidden_actions.append((0, hidden_action[1:]))
            else:
                hsa[i] = (_hidden_state, hidden_action, False)
                hidden_actions.append(tuple())
    output_state = [tuple() for _ in range(num_outputs)]
    for hidden_action in hidden_actions:
        try:
            output_i, output_msg = hidden_action
        except:
            continue
        try:
            output_state[output_i] += output_msg
        except:
            output_state[output_i] = output_msg
    output_actions = [agent.select_action(softmax(output_state[i])) for i, agent in enumerate(output_layer) if len(output_state[i])]
    if output_actions:
        osa = [(output_state[0], output_actions[0], True)]
    else:
        osa = [tuple()]
    inner_activations = Dict()
    inner_activations.isa = isa
    inner_activations.osa = osa
    inner_activations.hsa = hsa
    try:
        if output_actions[0] > 0.5:
            return 1, inner_activations
        else:
            return 0, inner_activations
    except:
        return random.randint(0, 1), inner_activations

# %%
def sample_layers(input_state):
    isa = [tuple() for _ in range(num_inputs)]
    hsa = [tuple() for _ in range(num_hidden)]
    osa = [tuple() for _ in range(num_outputs)]
    input_actions = [input_layer_action_space.sample() for _ in input_layer]
    for i, input_action in enumerate(input_actions):
        input_action[:num_hidden] = softmax(input_action[:num_hidden])
        if max(input_action[:num_hidden]) > ACT_THRESHOLD:
            isa[i] = (input_state[i:i+1], input_action, True)
            input_actions[i] = (np.argmax(input_action[:num_hidden]), input_action[num_hidden:])
        else:
            isa[i] = (input_state[i:i+1], input_action, False)
            input_actions[i] = tuple()
    hidden_state = [tuple() for _ in range(num_hidden)]
    for input_action in input_actions:
        try:
            hidden_i, hidden_msg = input_action
        except:
            continue
        try:
            hidden_state[hidden_i] += hidden_msg
        except:
            hidden_state[hidden_i] = hidden_msg
    hidden_actions = []
    for i, _hidden_state in enumerate(hidden_state):
        if len(_hidden_state):
            hidden_action = hidden_layer_action_space.sample()
            if hidden_action[0] > ACT_THRESHOLD:
                hidden_actions.append((0, hidden_action[1:]))
                hsa[i] = (_hidden_state, hidden_action, True)
            else:
                hidden_actions.append(tuple())
                hsa[i] = (_hidden_state, hidden_action, False)
    output_state = [tuple() for _ in range(num_outputs)]
    for hidden_action in hidden_actions:
        try:
            output_i, output_msg = hidden_action
        except:
            continue
        try:
            output_state[output_i] += output_msg
        except:
            output_state[output_i] = output_msg
    output_actions = [np.array([output_layer_action_space.sample()]) for i, _ in enumerate(output_layer) if len(output_state[i])]
    osa = [(output_state[0], output_actions[0], True)]
    inner_activations = Dict()
    inner_activations.isa = isa
    inner_activations.osa = osa
    inner_activations.hsa = hsa
    try:
        if output_actions[0] > 0.5:
            return 1, inner_activations
        else:
            return 0, inner_activations
    except:
        return random.randint(0, 1), inner_activations

# %%
def push_memory(inner_activations, reward, next_state, mask):
    isa = inner_activations.isa
    hsa = inner_activations.hsa
    osa = inner_activations.osa
    for i, ((state, action, flag), mem) in enumerate(zip(isa, input_memory)):
        _next_state = next_state[i:i+1]
        if flag:
            mem.push(state, action, reward, _next_state, mask)
        else:
            mem.push(state, action, 0, _next_state, mask)
    next_action, next_inner_activations = eval_layers(next_state)
    for hsa, mem, next_hsa in zip(hsa, hidden_memory, next_inner_activations.hsa):
        try:
            state, action, flag = hsa
            _next_state, _, _ = next_hsa
        except:
            continue
        if flag:
            mem.push(state, action, reward, _next_state, mask)
        else:
            mem.push(state, action, 0, _next_state, mask)
    for osa, mem, next_osa in zip(osa, output_memory, next_inner_activations.osa):
        try:
            state, action, flag = osa
            _next_state, _, _ = next_osa
        except:
            continue
        if flag:
            mem.push(state, action, reward, _next_state, mask)
        else:
            mem.push(state, action, 0, _next_state, mask)
    return next_action, next_inner_activations

# %%
def norm_stats(stats):
    for k in stats:
        stats[k] /= stats.cnt
    return stats
def average_stats(lst):
    avg = Dict()
    for stats in lst:
        for k in stats:
            avg[k] += stats[k]
        avg.cnt += 1
    return norm_stats(avg)
def get_avg_loss(train_stats):
    try:
        input_loss = (train_stats.input.critic_1_loss + train_stats.input.critic_2_loss)/2
    except:
        input_loss = float('nan')
    try:
        hidden_loss = (train_stats.hidden.critic_1_loss + train_stats.hidden.critic_2_loss)/2
    except:
        hidden_loss = float('nan')
    try:
        output_loss = (train_stats.output.critic_1_loss + train_stats.output.critic_2_loss)/2
    except:
        output_loss = float('nan')
    return input_loss, hidden_loss, output_loss

# %%
total_steps = 0
last_total_steps = 0
total_reward = 0.0
act_stats = Dict()
act_stats.input = np.array([0.0 for _ in input_layer])
act_stats.hidden = np.array([0.0 for _ in hidden_layer])
act_stats.output = np.array([0.0 for _ in output_layer])
for i_episode in itertools.count(1):
    episode_reward = 0
    episode_steps = 0
    done = False
    state = env.reset()
    inner_activations = {}
    action = None
    train_stats = Dict()
    train_stats.input = []
    train_stats.hidden = []
    train_stats.output = []
    while not done:
        if WARM_UP > total_steps:
            action, inner_activations = sample_layers(state)  # Sample random action
        else:
            if total_steps == WARM_UP:
                print('--WARM UP ENDED--'*3)
            if not inner_activations:
                action, inner_activations = eval_layers(state)  # Sample action from policy
        for i, isa in enumerate(inner_activations.isa):
            if len(isa):
                act_stats.input[i] += 1
        for i, hsa in enumerate(inner_activations.hsa):
            if len(hsa):
                act_stats.hidden[i] += 1
        for i, osa in enumerate(inner_activations.osa):
            if len(osa):
                act_stats.output[i] += 1

        # Number of updates per step in environment
        for i in range(UPDATES_PER_STEP):
            # Update parameters of all the networks
            for j, (agent, memory, updates) in enumerate(zip(input_layer, input_memory, input_updates)):
                input_stats = Dict()
                if len(memory) > BATCH_SIZE and inner_activations.isa[j]:
                    critic_1_loss, critic_2_loss, policy_loss, ent_loss, alpha = agent.update_parameters(memory, BATCH_SIZE, updates)
                    input_stats.critic_1_loss += critic_1_loss
                    input_stats.critic_2_loss += critic_2_loss
                    input_stats.policy_loss += policy_loss
                    input_stats.ent_loss += ent_loss
                    input_stats.alpha += alpha
                    input_stats.cnt += 1
                    input_updates[j] += 1
                norm_stats(input_stats)
                train_stats.input.append(input_stats)
            for j, (agent, memory, updates) in enumerate(zip(hidden_layer, hidden_memory, hidden_updates)):
                hidden_stats = Dict()
                if len(memory) > BATCH_SIZE and inner_activations.hsa[j]:
                    critic_1_loss, critic_2_loss, policy_loss, ent_loss, alpha = agent.update_parameters(memory, BATCH_SIZE, updates)
                    hidden_stats.critic_1_loss += critic_1_loss
                    hidden_stats.critic_2_loss += critic_2_loss
                    hidden_stats.policy_loss += policy_loss
                    hidden_stats.ent_loss += ent_loss
                    hidden_stats.alpha += alpha
                    hidden_stats.cnt += 1
                    hidden_updates[j] += 1
                norm_stats(hidden_stats)
                train_stats.hidden.append(hidden_stats)
            for j, (agent, memory, updates) in enumerate(zip(output_layer, output_memory, output_updates)):
                output_stats = Dict()
                if len(memory) > BATCH_SIZE and inner_activations.osa[j]:
                    critic_1_loss, critic_2_loss, policy_loss, ent_loss, alpha = agent.update_parameters(memory, BATCH_SIZE, updates)
                    output_stats.critic_1_loss += critic_1_loss
                    output_stats.critic_2_loss += critic_2_loss
                    output_stats.policy_loss += policy_loss
                    output_stats.ent_loss += ent_loss
                    output_stats.alpha += alpha
                    output_stats.cnt += 1
                    output_updates[j] += 1
                norm_stats(output_stats)
                train_stats.output.append(output_stats)

        next_state, reward, done, _ = env.step(action) # Step
        episode_steps += 1
        total_steps += 1
        episode_reward += reward

        # Ignore the "done" signal if it comes from hitting the time horizon.
        # (https://github.com/openai/spinningup/blob/master/spinup/algos/sac/sac.py)
        mask = 1 if episode_steps == env._max_episode_steps else float(not done)
        action, inner_activations = push_memory(inner_activations, reward, next_state, mask)

        state = next_state
    total_reward += episode_reward
    train_stats.input = average_stats(train_stats.input)
    train_stats.hidden = average_stats(train_stats.hidden)
    train_stats.output = average_stats(train_stats.output)
    loss = get_avg_loss(train_stats)
    print("Episode: {}, episode steps: {}, avg. reward: {}, loss_i: {}, loss_h: {}, loss_o: {}".format(i_episode, episode_steps, round(total_reward/((i_episode % PRINT_FREQ) or PRINT_FREQ), 2), *list(map(lambda x : round(x, 3), loss))))
    if i_episode % args.target_update_interval == 0 and total_steps > 0:
        ptr = -1
        input_update_map = np.array(input_updates) >= MIN_REQUIRED_UPDATES
        hidden_update_map = np.array(hidden_updates) >= MIN_REQUIRED_UPDATES
        output_update_map = np.array(output_updates) >= MIN_REQUIRED_UPDATES
        for j, agent, memory, updates in zip(list(range(num_inputs)) + list(range(num_hidden)) + list(range(num_outputs)), input_layer + hidden_layer + output_layer, input_memory + hidden_memory + output_memory, input_updates + hidden_updates + output_updates):
            if j == 0:
                ptr += 1
            if updates >= MIN_REQUIRED_UPDATES:
                agent.update_target()
                memory.empty()
                if ptr == 0:
                    input_updates[j] = 0
                elif ptr == 1:
                    hidden_updates[j] = 0
                else:
                    output_updates[j] = 0
        print('--TARGET UPDATED--'*3)
        print('i: %s' % input_update_map)
        print('h: %s' % hidden_update_map)
        print('o: %s' % output_update_map)
        print('-'*80)
    if i_episode % PRINT_FREQ == 0:
        act_stats.input /= total_steps - last_total_steps
        act_stats.hidden /= total_steps - last_total_steps
        act_stats.output /= total_steps - last_total_steps
        last_total_steps = total_steps
        total_reward = 0
        print("-"*80)
        print('Train episodes: %d' % PRINT_FREQ)
        print('-'*80)
        print('LOSS')
        print('i: %s' % str(train_stats.input))
        print('h: %s' % str(train_stats.hidden))
        print('o: %s' % str(train_stats.output))
        print('ACTIVATIONS')
        print('i: %s' % str(list(map(lambda x : round(x, 2), act_stats.input))))
        print('h: %s' % str(list(map(lambda x : round(x, 2), act_stats.hidden))))
        print('o: %s' % str(list(map(lambda x : round(x, 2), act_stats.output))))
        print('UPDATES')
        print('i: %s' % input_updates)
        print('h: %s' % hidden_updates)
        print('o: %s' % output_updates)
        print('MEMORY')
        print('i: %s' % str(list(map(len, input_memory))))
        print('h: %s' % str(list(map(len, hidden_memory))))
        print('o: %s' % str(list(map(len, output_memory))))
        act_stats.input = np.array([0.0 for _ in input_layer])
        act_stats.hidden = np.array([0.0 for _ in hidden_layer])
        act_stats.output = np.array([0.0 for _ in output_layer])
        print('\n')
        avg_reward = 0.
        max_reward = 0.
        for _  in tqdm(range(TEST_EPISODES)):
            state = env.reset()
            episode_reward = 0
            done = False
            while not done:
                action, _ = eval_layers(state)

                next_state, reward, done, _ = env.step(action)
                episode_reward += reward


                state = next_state
            avg_reward += episode_reward
            max_reward = max(episode_reward, max_reward)
        avg_reward /= TEST_EPISODES

        print("-"*80)
        print("Test Episodes: {}, Avg. Reward: {}, Max. Reward: {}".format(TEST_EPISODES, round(avg_reward, 2), round(max_reward, 2)))
        print("-"*80)
# Out:
# Episode: 1, episode steps: 16, avg. reward: 16.0, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 2, episode steps: 24, avg. reward: 20.0, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 3, episode steps: 54, avg. reward: 31.33, loss_i: 61.477, loss_h: nan, loss_o: 6.253
# Episode: 4, episode steps: 20, avg. reward: 28.5, loss_i: 0.081, loss_h: nan, loss_o: 0.03
# Episode: 5, episode steps: 33, avg. reward: 29.4, loss_i: 0.034, loss_h: nan, loss_o: 0.028
# Episode: 6, episode steps: 33, avg. reward: 30.0, loss_i: 0.02, loss_h: nan, loss_o: 0.025
# Episode: 7, episode steps: 40, avg. reward: 31.43, loss_i: 0.016, loss_h: nan, loss_o: 0.022
# Episode: 8, episode steps: 9, avg. reward: 28.62, loss_i: 0.015, loss_h: nan, loss_o: 0.021
# Episode: 9, episode steps: 36, avg. reward: 29.44, loss_i: 0.013, loss_h: nan, loss_o: 0.019
# Episode: 10, episode steps: 10, avg. reward: 27.5, loss_i: 0.013, loss_h: nan, loss_o: 0.018
# Episode: 11, episode steps: 30, avg. reward: 27.73, loss_i: 0.012, loss_h: nan, loss_o: 0.018
# Episode: 12, episode steps: 14, avg. reward: 26.58, loss_i: 0.011, loss_h: nan, loss_o: 0.018
# Episode: 13, episode steps: 33, avg. reward: 27.08, loss_i: 0.01, loss_h: 5.715, loss_o: 0.018
# Episode: 14, episode steps: 29, avg. reward: 27.21, loss_i: 0.01, loss_h: 9.647, loss_o: 0.016
# Episode: 15, episode steps: 10, avg. reward: 26.07, loss_i: 0.009, loss_h: 2.029, loss_o: 0.014
# Episode: 16, episode steps: 20, avg. reward: 25.69, loss_i: 0.009, loss_h: 14.317, loss_o: 0.015
# Episode: 17, episode steps: 25, avg. reward: 25.65, loss_i: 0.008, loss_h: 21.603, loss_o: 0.015
# Episode: 18, episode steps: 14, avg. reward: 25.0, loss_i: 0.008, loss_h: 0.06, loss_o: 0.014
# Episode: 19, episode steps: 15, avg. reward: 24.47, loss_i: 0.008, loss_h: 0.042, loss_o: 0.013
# Episode: 20, episode steps: 14, avg. reward: 23.95, loss_i: 0.008, loss_h: 0.025, loss_o: 0.013
# Episode: 21, episode steps: 14, avg. reward: 23.48, loss_i: 0.008, loss_h: 4.518, loss_o: 0.012
# Episode: 22, episode steps: 19, avg. reward: 23.27, loss_i: 0.007, loss_h: 0.044, loss_o: 0.013
# Episode: 23, episode steps: 16, avg. reward: 22.96, loss_i: 0.007, loss_h: 0.023, loss_o: 0.012
# Episode: 24, episode steps: 12, avg. reward: 22.5, loss_i: 0.007, loss_h: 3.206, loss_o: 0.012
# Episode: 25, episode steps: 16, avg. reward: 22.24, loss_i: 0.007, loss_h: 0.023, loss_o: 0.011
# Episode: 26, episode steps: 28, avg. reward: 22.46, loss_i: 0.007, loss_h: 0.018, loss_o: 0.01
# Episode: 27, episode steps: 17, avg. reward: 22.26, loss_i: 0.006, loss_h: 2.285, loss_o: 0.01
# Episode: 28, episode steps: 12, avg. reward: 21.89, loss_i: 0.006, loss_h: 0.013, loss_o: 0.01
# Episode: 29, episode steps: 20, avg. reward: 21.83, loss_i: 0.006, loss_h: 2.811, loss_o: 0.009
# Episode: 30, episode steps: 13, avg. reward: 21.53, loss_i: 0.006, loss_h: 0.013, loss_o: 0.009
# Episode: 31, episode steps: 13, avg. reward: 21.26, loss_i: 0.006, loss_h: 1.581, loss_o: 0.009
# Episode: 32, episode steps: 15, avg. reward: 21.06, loss_i: 0.006, loss_h: 2.008, loss_o: 0.008
# Episode: 33, episode steps: 17, avg. reward: 20.94, loss_i: 0.005, loss_h: 0.012, loss_o: 0.008
# Episode: 34, episode steps: 22, avg. reward: 20.97, loss_i: 0.005, loss_h: 2.697, loss_o: 0.008
# Episode: 35, episode steps: 11, avg. reward: 20.69, loss_i: 0.005, loss_h: 1.32, loss_o: 0.008
# Episode: 36, episode steps: 26, avg. reward: 20.83, loss_i: 0.005, loss_h: 0.011, loss_o: 0.007
# Episode: 37, episode steps: 15, avg. reward: 20.68, loss_i: 0.005, loss_h: 1.548, loss_o: 0.007
# Episode: 38, episode steps: 11, avg. reward: 20.42, loss_i: 0.004, loss_h: 1.22, loss_o: 0.007
# Episode: 39, episode steps: 30, avg. reward: 20.67, loss_i: 0.004, loss_h: 3.067, loss_o: 0.006
# Episode: 40, episode steps: 17, avg. reward: 20.57, loss_i: 0.004, loss_h: 1.772, loss_o: 0.006
# Episode: 41, episode steps: 21, avg. reward: 20.59, loss_i: 0.004, loss_h: 2.142, loss_o: 0.006
# Episode: 42, episode steps: 29, avg. reward: 20.79, loss_i: 0.004, loss_h: 2.83, loss_o: 0.006
# Episode: 43, episode steps: 22, avg. reward: 20.81, loss_i: 0.004, loss_h: 2.111, loss_o: 0.006
# Episode: 44, episode steps: 22, avg. reward: 20.84, loss_i: 0.004, loss_h: 1.975, loss_o: 0.005
# Episode: 45, episode steps: 21, avg. reward: 20.84, loss_i: 0.004, loss_h: 0.008, loss_o: 0.006
# Episode: 46, episode steps: 8, avg. reward: 20.57, loss_i: 0.003, loss_h: 0.762, loss_o: 0.005
# Episode: 47, episode steps: 20, avg. reward: 20.55, loss_i: 0.003, loss_h: 1.701, loss_o: 0.005
# Episode: 48, episode steps: 18, avg. reward: 20.5, loss_i: 0.004, loss_h: 1.533, loss_o: 0.005
# Episode: 49, episode steps: 16, avg. reward: 20.41, loss_i: 0.003, loss_h: 0.008, loss_o: 0.005
# Episode: 50, episode steps: 28, avg. reward: 20.56, loss_i: 0.003, loss_h: 2.169, loss_o: 0.005
# Episode: 51, episode steps: 38, avg. reward: 20.9, loss_i: 0.003, loss_h: 3.142, loss_o: 0.004
# Episode: 52, episode steps: 10, avg. reward: 20.69, loss_i: 0.003, loss_h: 0.816, loss_o: 0.004
# Episode: 53, episode steps: 13, avg. reward: 20.55, loss_i: 0.003, loss_h: 0.007, loss_o: 0.004
# Episode: 54, episode steps: 35, avg. reward: 20.81, loss_i: 0.003, loss_h: 0.007, loss_o: 0.004
# Episode: 55, episode steps: 14, avg. reward: 20.69, loss_i: 0.003, loss_h: 0.982, loss_o: 0.004
# Episode: 56, episode steps: 12, avg. reward: 20.54, loss_i: 0.003, loss_h: 0.943, loss_o: 0.003
# Episode: 57, episode steps: 16, avg. reward: 20.46, loss_i: 0.003, loss_h: 1.266, loss_o: 0.003
# Episode: 58, episode steps: 46, avg. reward: 20.9, loss_i: 0.003, loss_h: 0.007, loss_o: 0.003
# Episode: 59, episode steps: 33, avg. reward: 21.1, loss_i: 0.003, loss_h: 2.459, loss_o: 0.003
# Episode: 60, episode steps: 36, avg. reward: 21.35, loss_i: 0.003, loss_h: 2.556, loss_o: 0.003
# Episode: 61, episode steps: 17, avg. reward: 21.28, loss_i: 0.003, loss_h: 0.006, loss_o: 0.003
# Episode: 62, episode steps: 13, avg. reward: 21.15, loss_i: 0.003, loss_h: 0.007, loss_o: 0.003
# Episode: 63, episode steps: 40, avg. reward: 21.44, loss_i: 0.003, loss_h: 2.689, loss_o: 0.003
# Episode: 64, episode steps: 37, avg. reward: 21.69, loss_i: 0.002, loss_h: 2.307, loss_o: 0.003
# Episode: 65, episode steps: 24, avg. reward: 21.72, loss_i: 0.002, loss_h: 0.005, loss_o: 0.003
# Episode: 66, episode steps: 22, avg. reward: 21.73, loss_i: 0.002, loss_h: 0.005, loss_o: 0.002
# Episode: 67, episode steps: 12, avg. reward: 21.58, loss_i: 0.002, loss_h: 0.005, loss_o: 0.002
# Episode: 68, episode steps: 20, avg. reward: 21.56, loss_i: 0.002, loss_h: 0.005, loss_o: 0.002
# Episode: 69, episode steps: 20, avg. reward: 21.54, loss_i: 0.002, loss_h: 1.138, loss_o: 0.002
# Episode: 70, episode steps: 21, avg. reward: 21.53, loss_i: 0.002, loss_h: 0.005, loss_o: 0.002
# Episode: 71, episode steps: 20, avg. reward: 21.51, loss_i: 0.002, loss_h: 1.203, loss_o: 0.002
# Episode: 72, episode steps: 43, avg. reward: 21.81, loss_i: 0.002, loss_h: 2.373, loss_o: 0.002
# Episode: 73, episode steps: 15, avg. reward: 21.71, loss_i: 0.002, loss_h: 0.005, loss_o: 0.002
# Episode: 74, episode steps: 47, avg. reward: 22.05, loss_i: 0.002, loss_h: 2.52, loss_o: 0.002
# Episode: 75, episode steps: 13, avg. reward: 21.93, loss_i: 0.002, loss_h: 0.004, loss_o: 0.002
# Episode: 76, episode steps: 20, avg. reward: 21.91, loss_i: 0.002, loss_h: 0.005, loss_o: 0.002
# Episode: 77, episode steps: 23, avg. reward: 21.92, loss_i: 0.002, loss_h: 0.004, loss_o: 0.002
# Episode: 78, episode steps: 13, avg. reward: 21.81, loss_i: 0.002, loss_h: 0.005, loss_o: 0.002
# Episode: 79, episode steps: 13, avg. reward: 21.7, loss_i: 0.002, loss_h: 0.698, loss_o: 0.002
# Episode: 80, episode steps: 10, avg. reward: 21.55, loss_i: 0.002, loss_h: 0.004, loss_o: 0.002
# Episode: 81, episode steps: 24, avg. reward: 21.58, loss_i: 0.002, loss_h: 1.245, loss_o: 0.002
# Episode: 82, episode steps: 20, avg. reward: 21.56, loss_i: 0.002, loss_h: 0.005, loss_o: 0.002
# Episode: 83, episode steps: 82, avg. reward: 22.29, loss_i: 0.002, loss_h: 4.006, loss_o: 0.001
# Episode: 84, episode steps: 16, avg. reward: 22.21, loss_i: 0.002, loss_h: 0.776, loss_o: 0.001
# Episode: 85, episode steps: 44, avg. reward: 22.47, loss_i: 0.002, loss_h: 1.957, loss_o: 0.001
# Episode: 86, episode steps: 13, avg. reward: 22.36, loss_i: 0.002, loss_h: 0.004, loss_o: 0.001
# Episode: 87, episode steps: 14, avg. reward: 22.26, loss_i: 0.002, loss_h: 0.004, loss_o: 0.001
# Episode: 88, episode steps: 45, avg. reward: 22.52, loss_i: 0.002, loss_h: 2.072, loss_o: 0.001
# Episode: 89, episode steps: 10, avg. reward: 22.38, loss_i: 0.002, loss_h: 0.439, loss_o: 0.001
# Episode: 90, episode steps: 37, avg. reward: 22.54, loss_i: 0.002, loss_h: 1.563, loss_o: 0.001
# Episode: 91, episode steps: 13, avg. reward: 22.44, loss_i: 0.002, loss_h: 0.582, loss_o: 0.001
# Episode: 92, episode steps: 20, avg. reward: 22.41, loss_i: 0.002, loss_h: 0.833, loss_o: 0.001
# Episode: 93, episode steps: 22, avg. reward: 22.41, loss_i: 0.002, loss_h: 0.882, loss_o: 0.001
# Episode: 94, episode steps: 27, avg. reward: 22.46, loss_i: 0.002, loss_h: 0.004, loss_o: 0.001
# Episode: 95, episode steps: 61, avg. reward: 22.86, loss_i: 0.002, loss_h: 2.438, loss_o: 0.001
# Episode: 96, episode steps: 43, avg. reward: 23.07, loss_i: 0.002, loss_h: 1.744, loss_o: 0.001
# Episode: 97, episode steps: 21, avg. reward: 23.05, loss_i: 0.002, loss_h: 0.825, loss_o: 0.001
# Episode: 98, episode steps: 13, avg. reward: 22.95, loss_i: 0.002, loss_h: 0.541, loss_o: 0.001
# Episode: 99, episode steps: 14, avg. reward: 22.86, loss_i: 0.002, loss_h: 0.004, loss_o: 0.001
# Episode: 100, episode steps: 27, avg. reward: 22.9, loss_i: 0.002, loss_h: 0.003, loss_o: 0.001
# Episode: 101, episode steps: 28, avg. reward: 22.95, loss_i: 0.002, loss_h: 0.004, loss_o: 0.001
# Episode: 102, episode steps: 14, avg. reward: 22.86, loss_i: 0.002, loss_h: 0.493, loss_o: 0.001
# Episode: 103, episode steps: 12, avg. reward: 22.76, loss_i: 0.001, loss_h: 0.424, loss_o: 0.001
# Episode: 104, episode steps: 9, avg. reward: 22.62, loss_i: 0.001, loss_h: 0.332, loss_o: 0.001
# Episode: 105, episode steps: 9, avg. reward: 22.5, loss_i: 0.001, loss_h: 0.371, loss_o: 0.001
# Episode: 106, episode steps: 36, avg. reward: 22.62, loss_i: 0.001, loss_h: 0.003, loss_o: 0.001
# Episode: 107, episode steps: 23, avg. reward: 22.63, loss_i: 0.002, loss_h: 0.003, loss_o: 0.001
# Episode: 108, episode steps: 26, avg. reward: 22.66, loss_i: 0.001, loss_h: 0.003, loss_o: 0.001
# Episode: 109, episode steps: 58, avg. reward: 22.98, loss_i: 0.001, loss_h: 2.153, loss_o: 0.001
# Episode: 110, episode steps: 9, avg. reward: 22.85, loss_i: 0.001, loss_h: 0.003, loss_o: 0.001
# Episode: 111, episode steps: 26, avg. reward: 22.88, loss_i: 0.001, loss_h: 0.89, loss_o: 0.001
# Episode: 112, episode steps: 11, avg. reward: 22.78, loss_i: 0.001, loss_h: 0.003, loss_o: 0.001
# Episode: 113, episode steps: 19, avg. reward: 22.74, loss_i: 0.001, loss_h: 0.63, loss_o: 0.001
# Episode: 114, episode steps: 20, avg. reward: 22.72, loss_i: 0.001, loss_h: 0.673, loss_o: 0.001
# Episode: 115, episode steps: 13, avg. reward: 22.63, loss_i: 0.001, loss_h: 0.437, loss_o: 0.001
# Episode: 116, episode steps: 16, avg. reward: 22.58, loss_i: 0.001, loss_h: 0.551, loss_o: 0.001
# Episode: 117, episode steps: 23, avg. reward: 22.58, loss_i: 0.001, loss_h: 0.705, loss_o: 0.001
# Episode: 118, episode steps: 20, avg. reward: 22.56, loss_i: 0.001, loss_h: 0.684, loss_o: 0.001
# Episode: 119, episode steps: 14, avg. reward: 22.49, loss_i: 0.001, loss_h: 0.468, loss_o: 0.001
# Episode: 120, episode steps: 39, avg. reward: 22.62, loss_i: 0.001, loss_h: 0.003, loss_o: 0.001
# Episode: 121, episode steps: 37, avg. reward: 22.74, loss_i: 0.001, loss_h: 1.182, loss_o: 0.001
# Episode: 122, episode steps: 31, avg. reward: 22.81, loss_i: 0.001, loss_h: 0.954, loss_o: 0.001
# Episode: 123, episode steps: 11, avg. reward: 22.72, loss_i: 0.001, loss_h: 0.003, loss_o: 0.001
# Episode: 124, episode steps: 35, avg. reward: 22.81, loss_i: 0.001, loss_h: 1.189, loss_o: 0.001
# Episode: 125, episode steps: 33, avg. reward: 22.9, loss_i: 0.001, loss_h: 0.003, loss_o: 0.001
# Episode: 126, episode steps: 24, avg. reward: 22.9, loss_i: 0.001, loss_h: 0.003, loss_o: 0.001
# Episode: 127, episode steps: 45, avg. reward: 23.08, loss_i: 0.001, loss_h: 0.003, loss_o: 0.001
# Episode: 128, episode steps: 26, avg. reward: 23.1, loss_i: 0.001, loss_h: 0.726, loss_o: 0.001
# Episode: 129, episode steps: 38, avg. reward: 23.22, loss_i: 0.001, loss_h: 1.005, loss_o: 0.001
# Episode: 130, episode steps: 10, avg. reward: 23.12, loss_i: 0.001, loss_h: 0.003, loss_o: 0.001
# Episode: 131, episode steps: 25, avg. reward: 23.13, loss_i: 0.001, loss_h: 0.717, loss_o: 0.001
# Episode: 132, episode steps: 30, avg. reward: 23.18, loss_i: 0.001, loss_h: 0.003, loss_o: 0.001
# Episode: 133, episode steps: 20, avg. reward: 23.16, loss_i: 0.001, loss_h: 0.547, loss_o: 0.001
# Episode: 134, episode steps: 25, avg. reward: 23.17, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 135, episode steps: 25, avg. reward: 23.19, loss_i: 0.001, loss_h: 0.003, loss_o: 0.001
# Episode: 136, episode steps: 19, avg. reward: 23.15, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 137, episode steps: 17, avg. reward: 23.11, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 138, episode steps: 9, avg. reward: 23.01, loss_i: 0.001, loss_h: 0.271, loss_o: 0.001
# Episode: 139, episode steps: 19, avg. reward: 22.98, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 140, episode steps: 30, avg. reward: 23.03, loss_i: 0.001, loss_h: 0.758, loss_o: 0.001
# Episode: 141, episode steps: 27, avg. reward: 23.06, loss_i: 0.001, loss_h: 0.709, loss_o: 0.001
# Episode: 142, episode steps: 31, avg. reward: 23.11, loss_i: 0.001, loss_h: 0.81, loss_o: 0.001
# Episode: 143, episode steps: 26, avg. reward: 23.13, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 144, episode steps: 17, avg. reward: 23.09, loss_i: 0.001, loss_h: 0.505, loss_o: 0.001
# Episode: 145, episode steps: 18, avg. reward: 23.06, loss_i: 0.001, loss_h: 0.492, loss_o: 0.001
# Episode: 146, episode steps: 14, avg. reward: 22.99, loss_i: 0.001, loss_h: 0.352, loss_o: 0.001
# Episode: 147, episode steps: 17, avg. reward: 22.95, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 148, episode steps: 20, avg. reward: 22.93, loss_i: 0.001, loss_h: 0.542, loss_o: 0.001
# Episode: 149, episode steps: 27, avg. reward: 22.96, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 150, episode steps: 20, avg. reward: 22.94, loss_i: 0.001, loss_h: 0.485, loss_o: 0.001
# Episode: 151, episode steps: 12, avg. reward: 22.87, loss_i: 0.001, loss_h: 0.307, loss_o: 0.001
# Episode: 152, episode steps: 10, avg. reward: 22.78, loss_i: 0.001, loss_h: 0.266, loss_o: 0.001
# Episode: 153, episode steps: 14, avg. reward: 22.73, loss_i: 0.001, loss_h: 0.352, loss_o: 0.001
# Episode: 154, episode steps: 23, avg. reward: 22.73, loss_i: 0.001, loss_h: 0.571, loss_o: 0.001
# Episode: 155, episode steps: 19, avg. reward: 22.7, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 156, episode steps: 14, avg. reward: 22.65, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 157, episode steps: 15, avg. reward: 22.6, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 158, episode steps: 33, avg. reward: 22.66, loss_i: 0.001, loss_h: 0.776, loss_o: 0.001
# Episode: 159, episode steps: 71, avg. reward: 22.97, loss_i: 0.001, loss_h: 1.757, loss_o: 0.001
# Episode: 160, episode steps: 11, avg. reward: 22.89, loss_i: 0.001, loss_h: 0.244, loss_o: 0.001
# Episode: 161, episode steps: 25, avg. reward: 22.91, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 162, episode steps: 17, avg. reward: 22.87, loss_i: 0.001, loss_h: 0.372, loss_o: 0.001
# Episode: 163, episode steps: 13, avg. reward: 22.81, loss_i: 0.001, loss_h: 0.281, loss_o: 0.001
# Episode: 164, episode steps: 17, avg. reward: 22.77, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 165, episode steps: 50, avg. reward: 22.94, loss_i: 0.001, loss_h: 1.17, loss_o: 0.001
# Episode: 166, episode steps: 14, avg. reward: 22.89, loss_i: 0.001, loss_h: 0.303, loss_o: 0.0
# Episode: 167, episode steps: 25, avg. reward: 22.9, loss_i: 0.001, loss_h: 0.613, loss_o: 0.001
# Episode: 168, episode steps: 15, avg. reward: 22.85, loss_i: 0.001, loss_h: 0.319, loss_o: 0.001
# Episode: 169, episode steps: 20, avg. reward: 22.83, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 170, episode steps: 14, avg. reward: 22.78, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 171, episode steps: 41, avg. reward: 22.89, loss_i: 0.001, loss_h: 0.908, loss_o: 0.001
# Episode: 172, episode steps: 25, avg. reward: 22.9, loss_i: 0.001, loss_h: 0.569, loss_o: 0.0
# Episode: 173, episode steps: 23, avg. reward: 22.9, loss_i: 0.001, loss_h: 0.532, loss_o: 0.0
# Episode: 174, episode steps: 11, avg. reward: 22.83, loss_i: 0.001, loss_h: 0.256, loss_o: 0.001
# Episode: 175, episode steps: 16, avg. reward: 22.79, loss_i: 0.001, loss_h: 0.345, loss_o: 0.0
# Episode: 176, episode steps: 31, avg. reward: 22.84, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 177, episode steps: 36, avg. reward: 22.92, loss_i: 0.001, loss_h: 0.774, loss_o: 0.0
# Episode: 178, episode steps: 33, avg. reward: 22.97, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 179, episode steps: 16, avg. reward: 22.93, loss_i: 0.001, loss_h: 0.332, loss_o: 0.001
# Episode: 180, episode steps: 12, avg. reward: 22.87, loss_i: 0.001, loss_h: 0.262, loss_o: 0.0
# Episode: 181, episode steps: 20, avg. reward: 22.86, loss_i: 0.001, loss_h: 0.427, loss_o: 0.0
# Episode: 182, episode steps: 46, avg. reward: 22.98, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 183, episode steps: 16, avg. reward: 22.95, loss_i: 0.001, loss_h: 0.372, loss_o: 0.0
# Episode: 184, episode steps: 25, avg. reward: 22.96, loss_i: 0.001, loss_h: 0.592, loss_o: 0.001
# Episode: 185, episode steps: 15, avg. reward: 22.91, loss_i: 0.001, loss_h: 0.313, loss_o: 0.0
# Episode: 186, episode steps: 22, avg. reward: 22.91, loss_i: 0.001, loss_h: 0.455, loss_o: 0.001
# Episode: 187, episode steps: 23, avg. reward: 22.91, loss_i: 0.001, loss_h: 0.449, loss_o: 0.0
# Episode: 188, episode steps: 50, avg. reward: 23.05, loss_i: 0.001, loss_h: 0.927, loss_o: 0.0
# Episode: 189, episode steps: 16, avg. reward: 23.02, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 190, episode steps: 10, avg. reward: 22.95, loss_i: 0.001, loss_h: 0.19, loss_o: 0.001
# Episode: 191, episode steps: 21, avg. reward: 22.94, loss_i: 0.001, loss_h: 0.407, loss_o: 0.0
# Episode: 192, episode steps: 14, avg. reward: 22.89, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 193, episode steps: 18, avg. reward: 22.87, loss_i: 0.001, loss_h: 0.372, loss_o: 0.0
# Episode: 194, episode steps: 19, avg. reward: 22.85, loss_i: 0.001, loss_h: 0.383, loss_o: 0.0
# Episode: 195, episode steps: 12, avg. reward: 22.79, loss_i: 0.001, loss_h: 0.253, loss_o: 0.0
# Episode: 196, episode steps: 12, avg. reward: 22.73, loss_i: 0.001, loss_h: 0.241, loss_o: 0.0
# Episode: 197, episode steps: 16, avg. reward: 22.7, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 198, episode steps: 13, avg. reward: 22.65, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 199, episode steps: 18, avg. reward: 22.63, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 200, episode steps: 9, avg. reward: 22.56, loss_i: 0.001, loss_h: 0.185, loss_o: 0.0
# Episode: 201, episode steps: 13, avg. reward: 22.51, loss_i: 0.001, loss_h: 0.269, loss_o: 0.0
# Episode: 202, episode steps: 29, avg. reward: 22.54, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 203, episode steps: 23, avg. reward: 22.55, loss_i: 0.001, loss_h: 0.438, loss_o: 0.0
# Episode: 204, episode steps: 14, avg. reward: 22.5, loss_i: 0.001, loss_h: 0.259, loss_o: 0.0
# Episode: 205, episode steps: 12, avg. reward: 22.45, loss_i: 0.001, loss_h: 0.215, loss_o: 0.0
# Episode: 206, episode steps: 13, avg. reward: 22.41, loss_i: 0.001, loss_h: 0.257, loss_o: 0.0
# Episode: 207, episode steps: 13, avg. reward: 22.36, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 208, episode steps: 18, avg. reward: 22.34, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 209, episode steps: 12, avg. reward: 22.29, loss_i: 0.001, loss_h: 0.229, loss_o: 0.0
# Episode: 210, episode steps: 30, avg. reward: 22.33, loss_i: 0.001, loss_h: 0.586, loss_o: 0.0
# Episode: 211, episode steps: 49, avg. reward: 22.45, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 212, episode steps: 28, avg. reward: 22.48, loss_i: 0.001, loss_h: 0.516, loss_o: 0.0
# Episode: 213, episode steps: 18, avg. reward: 22.46, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 214, episode steps: 10, avg. reward: 22.4, loss_i: 0.001, loss_h: 0.205, loss_o: 0.0
# Episode: 215, episode steps: 61, avg. reward: 22.58, loss_i: 0.001, loss_h: 1.156, loss_o: 0.0
# Episode: 216, episode steps: 42, avg. reward: 22.67, loss_i: 0.001, loss_h: 0.823, loss_o: 0.0
# Episode: 217, episode steps: 17, avg. reward: 22.65, loss_i: 0.001, loss_h: 0.002, loss_o: 0.001
# Episode: 218, episode steps: 15, avg. reward: 22.61, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 219, episode steps: 36, avg. reward: 22.67, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 220, episode steps: 25, avg. reward: 22.68, loss_i: 0.001, loss_h: 0.429, loss_o: 0.0
# Episode: 221, episode steps: 13, avg. reward: 22.64, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 222, episode steps: 15, avg. reward: 22.6, loss_i: 0.0, loss_h: 0.288, loss_o: 0.0
# Episode: 223, episode steps: 17, avg. reward: 22.58, loss_i: 0.001, loss_h: 0.33, loss_o: 0.0
# Episode: 224, episode steps: 17, avg. reward: 22.55, loss_i: 0.001, loss_h: 0.267, loss_o: 0.0
# Episode: 225, episode steps: 11, avg. reward: 22.5, loss_i: 0.0, loss_h: 0.002, loss_o: 0.0
# Episode: 226, episode steps: 22, avg. reward: 22.5, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 227, episode steps: 14, avg. reward: 22.46, loss_i: 0.001, loss_h: 0.26, loss_o: 0.0
# Episode: 228, episode steps: 30, avg. reward: 22.5, loss_i: 0.001, loss_h: 0.561, loss_o: 0.0
# Episode: 229, episode steps: 10, avg. reward: 22.44, loss_i: 0.001, loss_h: 0.172, loss_o: 0.0
# Episode: 230, episode steps: 46, avg. reward: 22.54, loss_i: 0.001, loss_h: 0.765, loss_o: 0.0
# Episode: 231, episode steps: 12, avg. reward: 22.5, loss_i: 0.0, loss_h: 0.002, loss_o: 0.001
# Episode: 232, episode steps: 18, avg. reward: 22.48, loss_i: 0.001, loss_h: 0.331, loss_o: 0.0
# Episode: 233, episode steps: 17, avg. reward: 22.45, loss_i: 0.001, loss_h: 0.296, loss_o: 0.0
# Episode: 234, episode steps: 21, avg. reward: 22.45, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 235, episode steps: 17, avg. reward: 22.43, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 236, episode steps: 33, avg. reward: 22.47, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 237, episode steps: 16, avg. reward: 22.44, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 238, episode steps: 35, avg. reward: 22.5, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 239, episode steps: 21, avg. reward: 22.49, loss_i: 0.001, loss_h: 0.362, loss_o: 0.0
# Episode: 240, episode steps: 20, avg. reward: 22.48, loss_i: 0.0, loss_h: 0.326, loss_o: 0.0
# Episode: 241, episode steps: 44, avg. reward: 22.57, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 242, episode steps: 19, avg. reward: 22.55, loss_i: 0.001, loss_h: 0.001, loss_o: 0.0
# Episode: 243, episode steps: 22, avg. reward: 22.55, loss_i: 0.0, loss_h: 0.002, loss_o: 0.0
# Episode: 244, episode steps: 23, avg. reward: 22.55, loss_i: 0.0, loss_h: 0.002, loss_o: 0.0
# Episode: 245, episode steps: 16, avg. reward: 22.53, loss_i: 0.001, loss_h: 0.002, loss_o: 0.0
# Episode: 246, episode steps: 13, avg. reward: 22.49, loss_i: 0.0, loss_h: 0.002, loss_o: 0.0
# Episode: 247, episode steps: 18, avg. reward: 22.47, loss_i: 0.0, loss_h: 0.002, loss_o: 0.0
# Episode: 248, episode steps: 23, avg. reward: 22.47, loss_i: 0.0, loss_h: 0.002, loss_o: 0.0
# Episode: 249, episode steps: 13, avg. reward: 22.43, loss_i: 0.0, loss_h: 0.222, loss_o: 0.0
# Episode: 250, episode steps: 31, avg. reward: 22.47, loss_i: 0.0, loss_h: 0.002, loss_o: 0.0
# Episode: 251, episode steps: 17, avg. reward: 22.45, loss_i: 0.0, loss_h: 0.303, loss_o: 0.0
# Episode: 252, episode steps: 73, avg. reward: 22.65, loss_i: 0.0, loss_h: 1.345, loss_o: 0.0
# Episode: 253, episode steps: 9, avg. reward: 22.59, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 254, episode steps: 22, avg. reward: 22.59, loss_i: 0.0, loss_h: 0.356, loss_o: 0.0
# Episode: 255, episode steps: 26, avg. reward: 22.6, loss_i: 0.001, loss_h: 0.001, loss_o: 0.0
# Episode: 256, episode steps: 22, avg. reward: 22.6, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 257, episode steps: 12, avg. reward: 22.56, loss_i: 0.0, loss_h: 0.002, loss_o: 0.0
# Episode: 258, episode steps: 11, avg. reward: 22.52, loss_i: 0.0, loss_h: 0.179, loss_o: 0.0
# Episode: 259, episode steps: 10, avg. reward: 22.47, loss_i: 0.001, loss_h: 0.001, loss_o: 0.0
# Episode: 260, episode steps: 40, avg. reward: 22.53, loss_i: 0.0, loss_h: 0.717, loss_o: 0.0
# Episode: 261, episode steps: 34, avg. reward: 22.58, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 262, episode steps: 38, avg. reward: 22.64, loss_i: 0.0, loss_h: 0.607, loss_o: 0.0
# Episode: 263, episode steps: 13, avg. reward: 22.6, loss_i: 0.001, loss_h: 0.191, loss_o: 0.0
# Episode: 264, episode steps: 13, avg. reward: 22.56, loss_i: 0.001, loss_h: 0.204, loss_o: 0.0
# Episode: 265, episode steps: 12, avg. reward: 22.52, loss_i: 0.0, loss_h: 0.236, loss_o: 0.0
# Episode: 266, episode steps: 19, avg. reward: 22.51, loss_i: 0.0, loss_h: 0.002, loss_o: 0.0
# Episode: 267, episode steps: 9, avg. reward: 22.46, loss_i: 0.0, loss_h: 0.156, loss_o: 0.0
# Episode: 268, episode steps: 11, avg. reward: 22.42, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 269, episode steps: 24, avg. reward: 22.42, loss_i: 0.0, loss_h: 0.369, loss_o: 0.0
# Episode: 270, episode steps: 12, avg. reward: 22.39, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 271, episode steps: 18, avg. reward: 22.37, loss_i: 0.0, loss_h: 0.26, loss_o: 0.0
# Episode: 272, episode steps: 19, avg. reward: 22.36, loss_i: 0.0, loss_h: 0.305, loss_o: 0.0
# Episode: 273, episode steps: 10, avg. reward: 22.31, loss_i: 0.001, loss_h: 0.194, loss_o: 0.0
# Episode: 274, episode steps: 50, avg. reward: 22.41, loss_i: 0.0, loss_h: 0.817, loss_o: 0.0
# Episode: 275, episode steps: 32, avg. reward: 22.45, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 276, episode steps: 48, avg. reward: 22.54, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 277, episode steps: 69, avg. reward: 22.71, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 278, episode steps: 22, avg. reward: 22.71, loss_i: 0.0, loss_h: 0.332, loss_o: 0.0
# Episode: 279, episode steps: 12, avg. reward: 22.67, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 280, episode steps: 55, avg. reward: 22.78, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 281, episode steps: 20, avg. reward: 22.77, loss_i: 0.0, loss_h: 0.319, loss_o: 0.0
# Episode: 282, episode steps: 13, avg. reward: 22.74, loss_i: 0.0, loss_h: 0.189, loss_o: 0.0
# Episode: 283, episode steps: 11, avg. reward: 22.7, loss_i: 0.001, loss_h: 0.196, loss_o: 0.0
# Episode: 284, episode steps: 22, avg. reward: 22.69, loss_i: 0.0, loss_h: 0.324, loss_o: 0.0
# Episode: 285, episode steps: 35, avg. reward: 22.74, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 286, episode steps: 39, avg. reward: 22.79, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 287, episode steps: 12, avg. reward: 22.76, loss_i: 0.0, loss_h: 0.194, loss_o: 0.0
# Episode: 288, episode steps: 16, avg. reward: 22.73, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 289, episode steps: 19, avg. reward: 22.72, loss_i: 0.0, loss_h: 0.282, loss_o: 0.0
# Episode: 290, episode steps: 19, avg. reward: 22.71, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 291, episode steps: 20, avg. reward: 22.7, loss_i: 0.0, loss_h: 0.318, loss_o: 0.0
# Episode: 292, episode steps: 16, avg. reward: 22.67, loss_i: 0.0, loss_h: 0.273, loss_o: 0.0
# Episode: 293, episode steps: 25, avg. reward: 22.68, loss_i: 0.0, loss_h: 0.44, loss_o: 0.0
# Episode: 294, episode steps: 22, avg. reward: 22.68, loss_i: 0.0, loss_h: 0.353, loss_o: 0.0
# Episode: 295, episode steps: 18, avg. reward: 22.66, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 296, episode steps: 9, avg. reward: 22.62, loss_i: 0.0, loss_h: 0.159, loss_o: 0.0
# Episode: 297, episode steps: 33, avg. reward: 22.65, loss_i: 0.0, loss_h: 0.486, loss_o: 0.0
# Episode: 298, episode steps: 9, avg. reward: 22.61, loss_i: 0.0, loss_h: 0.107, loss_o: 0.0
# Episode: 299, episode steps: 41, avg. reward: 22.67, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 300, episode steps: 21, avg. reward: 22.66, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 301, episode steps: 16, avg. reward: 22.64, loss_i: 0.0, loss_h: 0.234, loss_o: 0.0
# Episode: 302, episode steps: 31, avg. reward: 22.67, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 303, episode steps: 11, avg. reward: 22.63, loss_i: 0.0, loss_h: 0.18, loss_o: 0.0
# Episode: 304, episode steps: 21, avg. reward: 22.62, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 305, episode steps: 11, avg. reward: 22.59, loss_i: 0.0, loss_h: 0.177, loss_o: 0.0
# Episode: 306, episode steps: 12, avg. reward: 22.55, loss_i: 0.0, loss_h: 0.185, loss_o: 0.0
# Episode: 307, episode steps: 25, avg. reward: 22.56, loss_i: 0.0, loss_h: 0.397, loss_o: 0.0
# Episode: 308, episode steps: 20, avg. reward: 22.55, loss_i: 0.0, loss_h: 0.297, loss_o: 0.0
# Episode: 309, episode steps: 14, avg. reward: 22.52, loss_i: 0.0, loss_h: 0.185, loss_o: 0.0
# Episode: 310, episode steps: 17, avg. reward: 22.51, loss_i: 0.0, loss_h: 0.244, loss_o: 0.0
# Episode: 311, episode steps: 35, avg. reward: 22.55, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 312, episode steps: 19, avg. reward: 22.54, loss_i: 0.0, loss_h: 0.291, loss_o: 0.0
# Episode: 313, episode steps: 31, avg. reward: 22.56, loss_i: 0.0, loss_h: 0.421, loss_o: 0.0
# Episode: 314, episode steps: 17, avg. reward: 22.54, loss_i: 0.0, loss_h: 0.269, loss_o: 0.0
# Episode: 315, episode steps: 25, avg. reward: 22.55, loss_i: 0.0, loss_h: 0.428, loss_o: 0.0
# Episode: 316, episode steps: 15, avg. reward: 22.53, loss_i: 0.0, loss_h: 0.236, loss_o: 0.0
# Episode: 317, episode steps: 34, avg. reward: 22.56, loss_i: 0.0, loss_h: 0.557, loss_o: 0.0
# Episode: 318, episode steps: 46, avg. reward: 22.64, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 319, episode steps: 44, avg. reward: 22.71, loss_i: 0.0, loss_h: 0.687, loss_o: 0.0
# Episode: 320, episode steps: 27, avg. reward: 22.72, loss_i: 0.0, loss_h: 0.336, loss_o: 0.0
# Episode: 321, episode steps: 19, avg. reward: 22.71, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 322, episode steps: 11, avg. reward: 22.67, loss_i: 0.0, loss_h: 0.135, loss_o: 0.0
# Episode: 323, episode steps: 15, avg. reward: 22.65, loss_i: 0.0, loss_h: 0.214, loss_o: 0.0
# Episode: 324, episode steps: 22, avg. reward: 22.65, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 325, episode steps: 22, avg. reward: 22.64, loss_i: 0.0, loss_h: 0.326, loss_o: 0.0
# Episode: 326, episode steps: 21, avg. reward: 22.64, loss_i: 0.0, loss_h: 0.322, loss_o: 0.0
# Episode: 327, episode steps: 25, avg. reward: 22.65, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 328, episode steps: 17, avg. reward: 22.63, loss_i: 0.0, loss_h: 0.244, loss_o: 0.0
# Episode: 329, episode steps: 36, avg. reward: 22.67, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 330, episode steps: 27, avg. reward: 22.68, loss_i: 0.0, loss_h: 0.417, loss_o: 0.0
# Episode: 331, episode steps: 17, avg. reward: 22.66, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 332, episode steps: 22, avg. reward: 22.66, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 333, episode steps: 26, avg. reward: 22.67, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 334, episode steps: 19, avg. reward: 22.66, loss_i: 0.0, loss_h: 0.26, loss_o: 0.0
# Episode: 335, episode steps: 10, avg. reward: 22.62, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 336, episode steps: 11, avg. reward: 22.59, loss_i: 0.0, loss_h: 0.162, loss_o: 0.0
# Episode: 337, episode steps: 11, avg. reward: 22.55, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 338, episode steps: 23, avg. reward: 22.56, loss_i: 0.0, loss_h: 0.291, loss_o: 0.0
# Episode: 339, episode steps: 44, avg. reward: 22.62, loss_i: 0.0, loss_h: 0.608, loss_o: 0.0
# Episode: 340, episode steps: 12, avg. reward: 22.59, loss_i: 0.0, loss_h: 0.171, loss_o: 0.0
# Episode: 341, episode steps: 20, avg. reward: 22.58, loss_i: 0.0, loss_h: 0.287, loss_o: 0.0
# Episode: 342, episode steps: 60, avg. reward: 22.69, loss_i: 0.0, loss_h: 0.9, loss_o: 0.0
# Episode: 343, episode steps: 26, avg. reward: 22.7, loss_i: 0.0, loss_h: 0.393, loss_o: 0.0
# Episode: 344, episode steps: 38, avg. reward: 22.74, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 345, episode steps: 29, avg. reward: 22.76, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 346, episode steps: 21, avg. reward: 22.76, loss_i: 0.0, loss_h: 0.312, loss_o: 0.0
# Episode: 347, episode steps: 25, avg. reward: 22.76, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 348, episode steps: 15, avg. reward: 22.74, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 349, episode steps: 18, avg. reward: 22.73, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 350, episode steps: 14, avg. reward: 22.7, loss_i: 0.0, loss_h: 0.194, loss_o: 0.0
# Episode: 351, episode steps: 36, avg. reward: 22.74, loss_i: 0.0, loss_h: 0.493, loss_o: 0.0
# Episode: 352, episode steps: 26, avg. reward: 22.75, loss_i: 0.0, loss_h: 0.382, loss_o: 0.0
# Episode: 353, episode steps: 16, avg. reward: 22.73, loss_i: 0.0, loss_h: 0.199, loss_o: 0.0
# Episode: 354, episode steps: 12, avg. reward: 22.7, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 355, episode steps: 15, avg. reward: 22.68, loss_i: 0.0, loss_h: 0.179, loss_o: 0.0
# Episode: 356, episode steps: 18, avg. reward: 22.67, loss_i: 0.0, loss_h: 0.272, loss_o: 0.0
# Episode: 357, episode steps: 41, avg. reward: 22.72, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 358, episode steps: 23, avg. reward: 22.72, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 359, episode steps: 17, avg. reward: 22.7, loss_i: 0.0, loss_h: 0.217, loss_o: 0.0
# Episode: 360, episode steps: 25, avg. reward: 22.71, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 361, episode steps: 37, avg. reward: 22.75, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 362, episode steps: 16, avg. reward: 22.73, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 363, episode steps: 10, avg. reward: 22.69, loss_i: 0.0, loss_h: 0.126, loss_o: 0.0
# Episode: 364, episode steps: 22, avg. reward: 22.69, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 365, episode steps: 14, avg. reward: 22.67, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 366, episode steps: 8, avg. reward: 22.63, loss_i: 0.0, loss_h: 0.111, loss_o: 0.0
# Episode: 367, episode steps: 37, avg. reward: 22.67, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 368, episode steps: 9, avg. reward: 22.63, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 369, episode steps: 36, avg. reward: 22.67, loss_i: 0.0, loss_h: 0.456, loss_o: 0.0
# Episode: 370, episode steps: 22, avg. reward: 22.66, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 371, episode steps: 39, avg. reward: 22.71, loss_i: 0.0, loss_h: 0.445, loss_o: 0.0
# Episode: 372, episode steps: 14, avg. reward: 22.69, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 373, episode steps: 25, avg. reward: 22.69, loss_i: 0.0, loss_h: 0.399, loss_o: 0.0
# Episode: 374, episode steps: 19, avg. reward: 22.68, loss_i: 0.0, loss_h: 0.309, loss_o: 0.0
# Episode: 375, episode steps: 31, avg. reward: 22.7, loss_i: 0.0, loss_h: 0.427, loss_o: 0.0
# Episode: 376, episode steps: 16, avg. reward: 22.69, loss_i: 0.0, loss_h: 0.208, loss_o: 0.0
# Episode: 377, episode steps: 13, avg. reward: 22.66, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 378, episode steps: 19, avg. reward: 22.65, loss_i: 0.0, loss_h: 0.281, loss_o: 0.0
# Episode: 379, episode steps: 14, avg. reward: 22.63, loss_i: 0.0, loss_h: 0.209, loss_o: 0.0
# Episode: 380, episode steps: 22, avg. reward: 22.63, loss_i: 0.0, loss_h: 0.324, loss_o: 0.0
# Episode: 381, episode steps: 30, avg. reward: 22.65, loss_i: 0.0, loss_h: 0.46, loss_o: 0.0
# Episode: 382, episode steps: 13, avg. reward: 22.62, loss_i: 0.0, loss_h: 0.17, loss_o: 0.0
# Episode: 383, episode steps: 16, avg. reward: 22.6, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 384, episode steps: 11, avg. reward: 22.57, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 385, episode steps: 20, avg. reward: 22.57, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 386, episode steps: 16, avg. reward: 22.55, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 387, episode steps: 19, avg. reward: 22.54, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 388, episode steps: 12, avg. reward: 22.51, loss_i: 0.0, loss_h: 0.151, loss_o: 0.0
# Episode: 389, episode steps: 21, avg. reward: 22.51, loss_i: 0.0, loss_h: 0.268, loss_o: 0.0
# Episode: 390, episode steps: 23, avg. reward: 22.51, loss_i: 0.0, loss_h: 0.331, loss_o: 0.0
# Episode: 391, episode steps: 26, avg. reward: 22.52, loss_i: 0.0, loss_h: 0.326, loss_o: 0.0
# Episode: 392, episode steps: 16, avg. reward: 22.5, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 393, episode steps: 11, avg. reward: 22.47, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 394, episode steps: 11, avg. reward: 22.44, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 395, episode steps: 16, avg. reward: 22.43, loss_i: 0.0, loss_h: 0.189, loss_o: 0.0
# Episode: 396, episode steps: 40, avg. reward: 22.47, loss_i: 0.0, loss_h: 0.491, loss_o: 0.0
# Episode: 397, episode steps: 25, avg. reward: 22.48, loss_i: 0.0, loss_h: 0.358, loss_o: 0.0
# Episode: 398, episode steps: 17, avg. reward: 22.46, loss_i: 0.0, loss_h: 0.209, loss_o: 0.0
# Episode: 399, episode steps: 36, avg. reward: 22.5, loss_i: 0.0, loss_h: 0.001, loss_o: 0.0
# Episode: 400, episode steps: 26, avg. reward: 22.51, loss_i: 0.0, loss_h: 0.308, loss_o: 0.0
# --TARGET UPDATED----TARGET UPDATED----TARGET UPDATED--
# i: [ True  True  True  True]
# h: [ True  True  True  True  True  True  True  True]
# o: [ True]
# --------------------------------------------------------------------------------
# Episode: 401, episode steps: 18, avg. reward: 22.5, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 402, episode steps: 20, avg. reward: 22.49, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 403, episode steps: 16, avg. reward: 22.47, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 404, episode steps: 12, avg. reward: 22.45, loss_i: 10.727, loss_h: nan, loss_o: 0.922
# Episode: 405, episode steps: 21, avg. reward: 22.44, loss_i: 0.617, loss_h: nan, loss_o: 0.094
# Episode: 406, episode steps: 13, avg. reward: 22.42, loss_i: 0.19, loss_h: nan, loss_o: 0.049
# Episode: 407, episode steps: 21, avg. reward: 22.42, loss_i: 0.142, loss_h: nan, loss_o: 0.046
# Episode: 408, episode steps: 18, avg. reward: 22.41, loss_i: 0.126, loss_h: nan, loss_o: 0.043
# Episode: 409, episode steps: 21, avg. reward: 22.4, loss_i: 0.113, loss_h: nan, loss_o: 0.042
# Episode: 410, episode steps: 21, avg. reward: 22.4, loss_i: 0.108, loss_h: nan, loss_o: 0.041
# Episode: 411, episode steps: 18, avg. reward: 22.39, loss_i: 0.102, loss_h: 3.356, loss_o: 0.04
# Episode: 412, episode steps: 39, avg. reward: 22.43, loss_i: 0.098, loss_h: 12.71, loss_o: 0.036
# Episode: 413, episode steps: 12, avg. reward: 22.4, loss_i: 0.088, loss_h: 2.064, loss_o: 0.038
# Episode: 414, episode steps: 12, avg. reward: 22.38, loss_i: 0.092, loss_h: 2.744, loss_o: 0.036
# Episode: 415, episode steps: 22, avg. reward: 22.38, loss_i: 0.096, loss_h: 7.615, loss_o: 0.04
# Episode: 416, episode steps: 29, avg. reward: 22.39, loss_i: 0.088, loss_h: 11.063, loss_o: 0.03
# Episode: 417, episode steps: 14, avg. reward: 22.37, loss_i: 0.09, loss_h: 3.718, loss_o: 0.033
# Episode: 418, episode steps: 21, avg. reward: 22.37, loss_i: 0.084, loss_h: 3.616, loss_o: 0.031
# Episode: 419, episode steps: 17, avg. reward: 22.36, loss_i: 0.085, loss_h: 2.354, loss_o: 0.032
# Episode: 420, episode steps: 28, avg. reward: 22.37, loss_i: 0.075, loss_h: 3.514, loss_o: 0.028
# Episode: 421, episode steps: 13, avg. reward: 22.35, loss_i: 0.081, loss_h: 1.539, loss_o: 0.029
# Episode: 422, episode steps: 23, avg. reward: 22.35, loss_i: 0.078, loss_h: 3.021, loss_o: 0.029
# Episode: 423, episode steps: 28, avg. reward: 22.36, loss_i: 0.074, loss_h: 4.929, loss_o: 0.029
# Episode: 424, episode steps: 12, avg. reward: 22.34, loss_i: 0.072, loss_h: 2.526, loss_o: 0.03
# Episode: 425, episode steps: 21, avg. reward: 22.34, loss_i: 0.078, loss_h: 3.266, loss_o: 0.027
# Episode: 426, episode steps: 9, avg. reward: 22.31, loss_i: 0.064, loss_h: 0.016, loss_o: 0.029
# Episode: 427, episode steps: 17, avg. reward: 22.29, loss_i: 0.077, loss_h: 0.014, loss_o: 0.025
# Episode: 428, episode steps: 32, avg. reward: 22.32, loss_i: 0.081, loss_h: 4.465, loss_o: 0.03
# Episode: 429, episode steps: 16, avg. reward: 22.3, loss_i: 0.074, loss_h: 1.336, loss_o: 0.027
# Episode: 430, episode steps: 39, avg. reward: 22.34, loss_i: 0.075, loss_h: 4.875, loss_o: 0.027
# Episode: 431, episode steps: 37, avg. reward: 22.37, loss_i: 0.072, loss_h: 0.024, loss_o: 0.027
# Episode: 432, episode steps: 13, avg. reward: 22.35, loss_i: 0.075, loss_h: 0.024, loss_o: 0.028
# Episode: 433, episode steps: 14, avg. reward: 22.33, loss_i: 0.076, loss_h: 3.652, loss_o: 0.019
# Episode: 434, episode steps: 34, avg. reward: 22.36, loss_i: 0.078, loss_h: 6.345, loss_o: 0.025
# Episode: 435, episode steps: 9, avg. reward: 22.33, loss_i: 0.065, loss_h: 1.241, loss_o: 0.023
# Episode: 436, episode steps: 16, avg. reward: 22.31, loss_i: 0.07, loss_h: 2.354, loss_o: 0.024
# Episode: 437, episode steps: 34, avg. reward: 22.34, loss_i: 0.073, loss_h: 5.316, loss_o: 0.028
# Episode: 438, episode steps: 30, avg. reward: 22.36, loss_i: 0.071, loss_h: 0.016, loss_o: 0.025
# Episode: 439, episode steps: 27, avg. reward: 22.37, loss_i: 0.068, loss_h: 0.016, loss_o: 0.026
# Episode: 440, episode steps: 21, avg. reward: 22.37, loss_i: 0.065, loss_h: 3.109, loss_o: 0.026
# Episode: 441, episode steps: 12, avg. reward: 22.34, loss_i: 0.069, loss_h: 1.729, loss_o: 0.026
# Episode: 442, episode steps: 13, avg. reward: 22.32, loss_i: 0.077, loss_h: 1.999, loss_o: 0.028
# Episode: 443, episode steps: 27, avg. reward: 22.33, loss_i: 0.069, loss_h: 0.013, loss_o: 0.027
# Episode: 444, episode steps: 16, avg. reward: 22.32, loss_i: 0.07, loss_h: 2.369, loss_o: 0.022
# Episode: 445, episode steps: 10, avg. reward: 22.29, loss_i: 0.07, loss_h: 3.733, loss_o: 0.02
# Episode: 446, episode steps: 33, avg. reward: 22.31, loss_i: 0.071, loss_h: 0.024, loss_o: 0.027
# Episode: 447, episode steps: 45, avg. reward: 22.36, loss_i: 0.073, loss_h: 8.647, loss_o: 0.026
# Episode: 448, episode steps: 10, avg. reward: 22.34, loss_i: 0.059, loss_h: 1.511, loss_o: 0.022
# Episode: 449, episode steps: 16, avg. reward: 22.32, loss_i: 0.068, loss_h: 0.018, loss_o: 0.022
# Episode: 450, episode steps: 26, avg. reward: 22.33, loss_i: 0.067, loss_h: 0.017, loss_o: 0.021
# Episode: 451, episode steps: 18, avg. reward: 22.32, loss_i: 0.067, loss_h: 3.258, loss_o: 0.026
# Episode: 452, episode steps: 23, avg. reward: 22.32, loss_i: 0.066, loss_h: 4.036, loss_o: 0.026
# Episode: 453, episode steps: 24, avg. reward: 22.33, loss_i: 0.066, loss_h: 3.885, loss_o: 0.024
# Episode: 454, episode steps: 25, avg. reward: 22.33, loss_i: 0.067, loss_h: 0.015, loss_o: 0.021
# Episode: 455, episode steps: 10, avg. reward: 22.31, loss_i: 0.072, loss_h: 0.013, loss_o: 0.032
# Episode: 456, episode steps: 16, avg. reward: 22.29, loss_i: 0.073, loss_h: 0.015, loss_o: 0.019
# Episode: 457, episode steps: 26, avg. reward: 22.3, loss_i: 0.061, loss_h: 0.015, loss_o: 0.022
# Episode: 458, episode steps: 28, avg. reward: 22.31, loss_i: 0.074, loss_h: 4.101, loss_o: 0.023
# Episode: 459, episode steps: 11, avg. reward: 22.29, loss_i: 0.075, loss_h: 1.866, loss_o: 0.022
# Episode: 460, episode steps: 26, avg. reward: 22.3, loss_i: 0.061, loss_h: 3.698, loss_o: 0.022
# Episode: 461, episode steps: 18, avg. reward: 22.29, loss_i: 0.064, loss_h: 2.896, loss_o: 0.022
# Episode: 462, episode steps: 34, avg. reward: 22.31, loss_i: 0.065, loss_h: 0.014, loss_o: 0.025
# Episode: 463, episode steps: 20, avg. reward: 22.31, loss_i: 0.07, loss_h: 2.547, loss_o: 0.02
# Episode: 464, episode steps: 14, avg. reward: 22.29, loss_i: 0.066, loss_h: 0.011, loss_o: 0.023
# Episode: 465, episode steps: 14, avg. reward: 22.27, loss_i: 0.073, loss_h: 0.014, loss_o: 0.026
# Episode: 466, episode steps: 18, avg. reward: 22.26, loss_i: 0.071, loss_h: 2.347, loss_o: 0.028
# Episode: 467, episode steps: 26, avg. reward: 22.27, loss_i: 0.069, loss_h: 3.493, loss_o: 0.025
# Episode: 468, episode steps: 16, avg. reward: 22.26, loss_i: 0.061, loss_h: 2.414, loss_o: 0.025
# Episode: 469, episode steps: 17, avg. reward: 22.25, loss_i: 0.067, loss_h: 0.013, loss_o: 0.024
# Episode: 470, episode steps: 53, avg. reward: 22.31, loss_i: 0.066, loss_h: 6.869, loss_o: 0.023
# Episode: 471, episode steps: 10, avg. reward: 22.28, loss_i: 0.057, loss_h: 1.025, loss_o: 0.025
# Episode: 472, episode steps: 14, avg. reward: 22.27, loss_i: 0.063, loss_h: 0.012, loss_o: 0.026
# Episode: 473, episode steps: 23, avg. reward: 22.27, loss_i: 0.063, loss_h: 2.986, loss_o: 0.023
# Episode: 474, episode steps: 21, avg. reward: 22.27, loss_i: 0.063, loss_h: 2.848, loss_o: 0.026
# Episode: 475, episode steps: 16, avg. reward: 22.25, loss_i: 0.066, loss_h: 0.012, loss_o: 0.023
# Episode: 476, episode steps: 52, avg. reward: 22.32, loss_i: 0.069, loss_h: 0.013, loss_o: 0.023
# Episode: 477, episode steps: 58, avg. reward: 22.39, loss_i: 0.063, loss_h: 7.559, loss_o: 0.023
# Episode: 478, episode steps: 11, avg. reward: 22.37, loss_i: 0.067, loss_h: 1.418, loss_o: 0.02
# Episode: 479, episode steps: 19, avg. reward: 22.36, loss_i: 0.065, loss_h: 2.487, loss_o: 0.023
# Episode: 480, episode steps: 16, avg. reward: 22.35, loss_i: 0.062, loss_h: 2.168, loss_o: 0.017
# Episode: 481, episode steps: 16, avg. reward: 22.33, loss_i: 0.064, loss_h: 2.112, loss_o: 0.025
# Episode: 482, episode steps: 12, avg. reward: 22.31, loss_i: 0.057, loss_h: 0.012, loss_o: 0.023
# Episode: 483, episode steps: 21, avg. reward: 22.31, loss_i: 0.07, loss_h: 0.012, loss_o: 0.023
# Episode: 484, episode steps: 13, avg. reward: 22.29, loss_i: 0.064, loss_h: 0.012, loss_o: 0.028
# Episode: 485, episode steps: 15, avg. reward: 22.27, loss_i: 0.069, loss_h: 0.012, loss_o: 0.028
# Episode: 486, episode steps: 15, avg. reward: 22.26, loss_i: 0.06, loss_h: 1.682, loss_o: 0.028
# Episode: 487, episode steps: 11, avg. reward: 22.24, loss_i: 0.064, loss_h: 1.098, loss_o: 0.019
# Episode: 488, episode steps: 15, avg. reward: 22.22, loss_i: 0.066, loss_h: 1.73, loss_o: 0.022
# Episode: 489, episode steps: 15, avg. reward: 22.21, loss_i: 0.063, loss_h: 0.012, loss_o: 0.026
# Episode: 490, episode steps: 21, avg. reward: 22.2, loss_i: 0.065, loss_h: 2.375, loss_o: 0.022
# Episode: 491, episode steps: 15, avg. reward: 22.19, loss_i: 0.069, loss_h: 0.011, loss_o: 0.021
# Episode: 492, episode steps: 37, avg. reward: 22.22, loss_i: 0.07, loss_h: 4.381, loss_o: 0.02
# Episode: 493, episode steps: 17, avg. reward: 22.21, loss_i: 0.065, loss_h: 1.874, loss_o: 0.02
# Episode: 494, episode steps: 32, avg. reward: 22.23, loss_i: 0.069, loss_h: 3.646, loss_o: 0.02
# Episode: 495, episode steps: 21, avg. reward: 22.23, loss_i: 0.071, loss_h: 2.213, loss_o: 0.027
# Episode: 496, episode steps: 19, avg. reward: 22.22, loss_i: 0.064, loss_h: 0.011, loss_o: 0.021
# Episode: 497, episode steps: 17, avg. reward: 22.21, loss_i: 0.064, loss_h: 2.084, loss_o: 0.022
# Episode: 498, episode steps: 18, avg. reward: 22.2, loss_i: 0.064, loss_h: 0.009, loss_o: 0.028
# Episode: 499, episode steps: 35, avg. reward: 22.23, loss_i: 0.064, loss_h: 3.788, loss_o: 0.021
# Episode: 500, episode steps: 17, avg. reward: 22.22, loss_i: 0.066, loss_h: 0.011, loss_o: 0.024
# Episode: 501, episode steps: 27, avg. reward: 22.23, loss_i: 0.068, loss_h: 3.354, loss_o: 0.02
# Episode: 502, episode steps: 12, avg. reward: 22.21, loss_i: 0.062, loss_h: 0.011, loss_o: 0.025
# Episode: 503, episode steps: 16, avg. reward: 22.19, loss_i: 0.07, loss_h: 1.635, loss_o: 0.024
# ...
# Episode: 14269, episode steps: 10, avg. reward: 9.32, loss_i: 7.798, loss_h: 179.786, loss_o: 1.444
# Episode: 14270, episode steps: 9, avg. reward: 9.31, loss_i: 7.158, loss_h: 1.671, loss_o: 1.404
# Episode: 14271, episode steps: 10, avg. reward: 9.32, loss_i: 7.8, loss_h: 141.102, loss_o: 1.575
# Episode: 14272, episode steps: 9, avg. reward: 9.32, loss_i: 8.299, loss_h: 174.738, loss_o: 1.755
# Episode: 14273, episode steps: 10, avg. reward: 9.32, loss_i: 7.835, loss_h: 174.894, loss_o: 1.809
# Episode: 14274, episode steps: 10, avg. reward: 9.32, loss_i: 9.597, loss_h: 133.145, loss_o: 1.421
# Episode: 14275, episode steps: 11, avg. reward: 9.33, loss_i: 7.37, loss_h: 1.24, loss_o: 1.545
# Episode: 14276, episode steps: 10, avg. reward: 9.33, loss_i: 8.606, loss_h: 151.319, loss_o: 1.585
# Episode: 14277, episode steps: 10, avg. reward: 9.33, loss_i: 6.754, loss_h: 162.023, loss_o: 1.529
# Episode: 14278, episode steps: 10, avg. reward: 9.33, loss_i: 8.994, loss_h: 136.24, loss_o: 1.733
# Episode: 14279, episode steps: 9, avg. reward: 9.33, loss_i: 8.632, loss_h: 1.639, loss_o: 1.467
# Episode: 14280, episode steps: 8, avg. reward: 9.33, loss_i: 8.844, loss_h: 125.604, loss_o: 1.695
# Episode: 14281, episode steps: 10, avg. reward: 9.33, loss_i: 9.526, loss_h: 133.931, loss_o: 1.681
# Episode: 14282, episode steps: 9, avg. reward: 9.33, loss_i: 7.943, loss_h: 1.789, loss_o: 1.921
# Episode: 14283, episode steps: 9, avg. reward: 9.33, loss_i: 9.654, loss_h: 168.953, loss_o: 1.59
# Episode: 14284, episode steps: 8, avg. reward: 9.32, loss_i: 8.565, loss_h: 137.908, loss_o: 1.839
# Episode: 14285, episode steps: 10, avg. reward: 9.33, loss_i: 9.178, loss_h: 156.154, loss_o: 1.838
# Episode: 14286, episode steps: 10, avg. reward: 9.33, loss_i: 8.122, loss_h: 1.208, loss_o: 1.594
# Episode: 14287, episode steps: 8, avg. reward: 9.32, loss_i: 8.148, loss_h: 169.88, loss_o: 1.537
# Episode: 14288, episode steps: 8, avg. reward: 9.32, loss_i: 8.815, loss_h: 102.888, loss_o: 1.762
# Episode: 14289, episode steps: 9, avg. reward: 9.32, loss_i: 8.269, loss_h: 134.844, loss_o: 1.582
# Episode: 14290, episode steps: 9, avg. reward: 9.32, loss_i: 7.789, loss_h: 141.536, loss_o: 1.448
# Episode: 14291, episode steps: 10, avg. reward: 9.32, loss_i: 8.346, loss_h: 161.087, loss_o: 1.618
# Episode: 14292, episode steps: 9, avg. reward: 9.32, loss_i: 7.352, loss_h: 156.105, loss_o: 1.662
# Episode: 14293, episode steps: 8, avg. reward: 9.31, loss_i: 8.786, loss_h: 132.335, loss_o: 1.676
# Episode: 14294, episode steps: 10, avg. reward: 9.32, loss_i: 7.835, loss_h: 199.07, loss_o: 1.692
# Episode: 14295, episode steps: 10, avg. reward: 9.32, loss_i: 7.855, loss_h: 191.649, loss_o: 1.573
# Episode: 14296, episode steps: 10, avg. reward: 9.32, loss_i: 9.284, loss_h: 161.534, loss_o: 1.645
# Episode: 14297, episode steps: 10, avg. reward: 9.32, loss_i: 6.902, loss_h: 1.471, loss_o: 1.654
# Episode: 14298, episode steps: 9, avg. reward: 9.32, loss_i: 8.52, loss_h: 138.459, loss_o: 1.766
# Episode: 14299, episode steps: 8, avg. reward: 9.32, loss_i: 9.542, loss_h: 149.986, loss_o: 1.646
# Episode: 14300, episode steps: 9, avg. reward: 9.32, loss_i: 8.997, loss_h: 156.016, loss_o: 1.566
# Episode: 14301, episode steps: 10, avg. reward: 9.32, loss_i: 8.388, loss_h: 1.147, loss_o: 1.452
# Episode: 14302, episode steps: 9, avg. reward: 9.32, loss_i: 9.771, loss_h: 1.355, loss_o: 1.709
# Episode: 14303, episode steps: 9, avg. reward: 9.32, loss_i: 8.076, loss_h: 140.387, loss_o: 1.523
# Episode: 14304, episode steps: 10, avg. reward: 9.32, loss_i: 7.807, loss_h: 162.423, loss_o: 1.676
# Episode: 14305, episode steps: 10, avg. reward: 9.32, loss_i: 8.303, loss_h: 181.487, loss_o: 1.706
# Episode: 14306, episode steps: 10, avg. reward: 9.32, loss_i: 10.063, loss_h: 133.107, loss_o: 1.689
# Episode: 14307, episode steps: 10, avg. reward: 9.33, loss_i: 9.572, loss_h: 144.128, loss_o: 1.549
# Episode: 14308, episode steps: 8, avg. reward: 9.32, loss_i: 9.243, loss_h: 127.856, loss_o: 1.476
# Episode: 14309, episode steps: 9, avg. reward: 9.32, loss_i: 7.815, loss_h: 1.767, loss_o: 1.568
# Episode: 14310, episode steps: 8, avg. reward: 9.32, loss_i: 9.24, loss_h: 144.235, loss_o: 1.807
# Episode: 14311, episode steps: 8, avg. reward: 9.31, loss_i: 8.525, loss_h: 141.664, loss_o: 1.508
# Episode: 14312, episode steps: 10, avg. reward: 9.31, loss_i: 8.12, loss_h: 1.395, loss_o: 1.462
# Episode: 14313, episode steps: 11, avg. reward: 9.32, loss_i: 7.457, loss_h: 1.647, loss_o: 1.615
# Episode: 14314, episode steps: 10, avg. reward: 9.32, loss_i: 8.88, loss_h: 156.593, loss_o: 1.477
# Episode: 14315, episode steps: 9, avg. reward: 9.32, loss_i: 9.101, loss_h: 112.964, loss_o: 1.645
# Episode: 14316, episode steps: 9, avg. reward: 9.32, loss_i: 7.176, loss_h: 132.066, loss_o: 1.748
# Episode: 14317, episode steps: 10, avg. reward: 9.32, loss_i: 8.983, loss_h: 156.232, loss_o: 1.531
# Episode: 14318, episode steps: 9, avg. reward: 9.32, loss_i: 9.36, loss_h: 165.723, loss_o: 1.624
# Episode: 14319, episode steps: 9, avg. reward: 9.32, loss_i: 8.051, loss_h: 141.328, loss_o: 1.447
# Episode: 14320, episode steps: 11, avg. reward: 9.32, loss_i: 8.922, loss_h: 173.544, loss_o: 1.67
# Episode: 14321, episode steps: 10, avg. reward: 9.33, loss_i: 7.347, loss_h: 1.043, loss_o: 1.629
# Episode: 14322, episode steps: 9, avg. reward: 9.33, loss_i: 7.256, loss_h: 155.346, loss_o: 1.663
# Episode: 14323, episode steps: 10, avg. reward: 9.33, loss_i: 9.764, loss_h: 162.412, loss_o: 1.758
# Episode: 14324, episode steps: 9, avg. reward: 9.33, loss_i: 9.421, loss_h: 140.714, loss_o: 1.635
# Episode: 14325, episode steps: 10, avg. reward: 9.33, loss_i: 8.243, loss_h: 152.862, loss_o: 1.643
# Episode: 14326, episode steps: 9, avg. reward: 9.33, loss_i: 6.245, loss_h: 130.432, loss_o: 1.686
# Episode: 14327, episode steps: 10, avg. reward: 9.33, loss_i: 9.76, loss_h: 161.804, loss_o: 1.677
# Episode: 14328, episode steps: 10, avg. reward: 9.33, loss_i: 7.376, loss_h: 1.282, loss_o: 1.384
# Episode: 14329, episode steps: 9, avg. reward: 9.33, loss_i: 7.858, loss_h: 156.792, loss_o: 1.655
# Episode: 14330, episode steps: 9, avg. reward: 9.33, loss_i: 8.32, loss_h: 134.926, loss_o: 1.354
# Episode: 14331, episode steps: 10, avg. reward: 9.33, loss_i: 8.2, loss_h: 151.642, loss_o: 1.646
# Episode: 14332, episode steps: 8, avg. reward: 9.33, loss_i: 7.428, loss_h: 1.187, loss_o: 1.742
# Episode: 14333, episode steps: 9, avg. reward: 9.33, loss_i: 10.12, loss_h: 127.845, loss_o: 1.869
# Episode: 14334, episode steps: 9, avg. reward: 9.33, loss_i: 8.284, loss_h: 139.022, loss_o: 1.681
# Episode: 14335, episode steps: 10, avg. reward: 9.33, loss_i: 7.348, loss_h: 144.033, loss_o: 1.582
# Episode: 14336, episode steps: 10, avg. reward: 9.33, loss_i: 7.98, loss_h: 149.641, loss_o: 1.79
# Episode: 14337, episode steps: 9, avg. reward: 9.33, loss_i: 8.892, loss_h: 167.963, loss_o: 1.849
# Episode: 14338, episode steps: 9, avg. reward: 9.33, loss_i: 9.06, loss_h: 1.444, loss_o: 1.565
# Episode: 14339, episode steps: 11, avg. reward: 9.33, loss_i: 8.337, loss_h: 184.576, loss_o: 1.543
# Episode: 14340, episode steps: 8, avg. reward: 9.33, loss_i: 8.977, loss_h: 135.471, loss_o: 1.849
# Episode: 14341, episode steps: 8, avg. reward: 9.33, loss_i: 8.248, loss_h: 126.039, loss_o: 1.563
# Episode: 14342, episode steps: 9, avg. reward: 9.32, loss_i: 8.05, loss_h: 1.454, loss_o: 1.592
# Episode: 14343, episode steps: 9, avg. reward: 9.32, loss_i: 8.944, loss_h: 1.345, loss_o: 1.731
# Episode: 14344, episode steps: 10, avg. reward: 9.33, loss_i: 7.607, loss_h: 179.079, loss_o: 1.777
# Episode: 14345, episode steps: 9, avg. reward: 9.32, loss_i: 6.793, loss_h: 136.849, loss_o: 1.574
# Episode: 14346, episode steps: 9, avg. reward: 9.32, loss_i: 7.837, loss_h: 1.454, loss_o: 1.54
# Episode: 14347, episode steps: 10, avg. reward: 9.33, loss_i: 7.801, loss_h: 149.583, loss_o: 1.518
# Episode: 14348, episode steps: 11, avg. reward: 9.33, loss_i: 8.097, loss_h: 181.676, loss_o: 1.801
# Episode: 14349, episode steps: 9, avg. reward: 9.33, loss_i: 8.929, loss_h: 137.388, loss_o: 1.797
# Episode: 14350, episode steps: 10, avg. reward: 9.33, loss_i: 8.227, loss_h: 124.877, loss_o: 1.626
# Episode: 14351, episode steps: 8, avg. reward: 9.33, loss_i: 8.349, loss_h: 125.357, loss_o: 1.563
# Episode: 14352, episode steps: 9, avg. reward: 9.33, loss_i: 7.301, loss_h: 182.009, loss_o: 1.743
# Episode: 14353, episode steps: 10, avg. reward: 9.33, loss_i: 6.041, loss_h: 161.202, loss_o: 1.704
# Episode: 14354, episode steps: 10, avg. reward: 9.33, loss_i: 9.03, loss_h: 152.937, loss_o: 1.787
# Episode: 14355, episode steps: 9, avg. reward: 9.33, loss_i: 7.654, loss_h: 132.703, loss_o: 1.58
# Episode: 14356, episode steps: 8, avg. reward: 9.33, loss_i: 7.131, loss_h: 133.002, loss_o: 1.467
# Episode: 14357, episode steps: 11, avg. reward: 9.33, loss_i: 8.061, loss_h: 1.25, loss_o: 1.551
# Episode: 14358, episode steps: 8, avg. reward: 9.33, loss_i: 9.68, loss_h: 130.151, loss_o: 1.427
# Episode: 14359, episode steps: 10, avg. reward: 9.33, loss_i: 8.84, loss_h: 190.76, loss_o: 1.709
# Episode: 14360, episode steps: 9, avg. reward: 9.33, loss_i: 7.588, loss_h: 120.503, loss_o: 1.578
# Episode: 14361, episode steps: 10, avg. reward: 9.33, loss_i: 10.253, loss_h: 130.443, loss_o: 1.596
# Episode: 14362, episode steps: 10, avg. reward: 9.33, loss_i: 8.486, loss_h: 124.172, loss_o: 1.776
# Episode: 14363, episode steps: 8, avg. reward: 9.33, loss_i: 8.432, loss_h: 1.421, loss_o: 1.367
# Episode: 14364, episode steps: 8, avg. reward: 9.32, loss_i: 9.453, loss_h: 1.158, loss_o: 1.533
# Episode: 14365, episode steps: 9, avg. reward: 9.32, loss_i: 7.714, loss_h: 1.036, loss_o: 1.59
# Episode: 14366, episode steps: 9, avg. reward: 9.32, loss_i: 7.801, loss_h: 122.56, loss_o: 1.761
# Episode: 14367, episode steps: 8, avg. reward: 9.32, loss_i: 8.255, loss_h: 1.387, loss_o: 1.572
# Episode: 14368, episode steps: 9, avg. reward: 9.32, loss_i: 7.922, loss_h: 1.134, loss_o: 1.615
# Episode: 14369, episode steps: 10, avg. reward: 9.32, loss_i: 8.585, loss_h: 165.345, loss_o: 1.618
# Episode: 14370, episode steps: 9, avg. reward: 9.32, loss_i: 9.009, loss_h: 132.534, loss_o: 1.603
# Episode: 14371, episode steps: 9, avg. reward: 9.32, loss_i: 8.433, loss_h: 144.933, loss_o: 1.77
# Episode: 14372, episode steps: 10, avg. reward: 9.32, loss_i: 7.671, loss_h: 1.495, loss_o: 1.655
# Episode: 14373, episode steps: 9, avg. reward: 9.32, loss_i: 8.152, loss_h: 151.689, loss_o: 1.561
# Episode: 14374, episode steps: 10, avg. reward: 9.32, loss_i: 7.751, loss_h: 146.799, loss_o: 1.7
# Episode: 14375, episode steps: 9, avg. reward: 9.32, loss_i: 9.211, loss_h: 105.918, loss_o: 1.554
# Episode: 14376, episode steps: 9, avg. reward: 9.32, loss_i: 8.539, loss_h: 123.042, loss_o: 1.697
# Episode: 14377, episode steps: 10, avg. reward: 9.32, loss_i: 10.208, loss_h: 1.493, loss_o: 1.645
# Episode: 14378, episode steps: 9, avg. reward: 9.32, loss_i: 8.241, loss_h: 148.136, loss_o: 1.487
# Episode: 14379, episode steps: 8, avg. reward: 9.32, loss_i: 7.51, loss_h: 1.474, loss_o: 1.71
# Episode: 14380, episode steps: 9, avg. reward: 9.32, loss_i: 8.525, loss_h: 150.118, loss_o: 1.52
# Episode: 14381, episode steps: 10, avg. reward: 9.32, loss_i: 8.2, loss_h: 131.256, loss_o: 1.633
# Episode: 14382, episode steps: 10, avg. reward: 9.32, loss_i: 8.411, loss_h: 1.287, loss_o: 1.753
# Episode: 14383, episode steps: 9, avg. reward: 9.32, loss_i: 7.854, loss_h: 157.485, loss_o: 1.726
# Episode: 14384, episode steps: 9, avg. reward: 9.32, loss_i: 8.019, loss_h: 166.348, loss_o: 1.525
# Episode: 14385, episode steps: 9, avg. reward: 9.32, loss_i: 10.581, loss_h: 175.339, loss_o: 1.76
# Episode: 14386, episode steps: 10, avg. reward: 9.32, loss_i: 7.887, loss_h: 150.836, loss_o: 1.636
# Episode: 14387, episode steps: 9, avg. reward: 9.32, loss_i: 8.304, loss_h: 124.911, loss_o: 1.567
# Episode: 14388, episode steps: 10, avg. reward: 9.32, loss_i: 8.551, loss_h: 136.837, loss_o: 1.498
# Episode: 14389, episode steps: 10, avg. reward: 9.32, loss_i: 8.955, loss_h: 1.01, loss_o: 1.637
# Episode: 14390, episode steps: 9, avg. reward: 9.32, loss_i: 9.879, loss_h: 151.713, loss_o: 1.599
# Episode: 14391, episode steps: 9, avg. reward: 9.32, loss_i: 7.532, loss_h: 126.432, loss_o: 1.685
# Episode: 14392, episode steps: 10, avg. reward: 9.32, loss_i: 7.529, loss_h: 150.151, loss_o: 1.558
# Episode: 14393, episode steps: 9, avg. reward: 9.32, loss_i: 7.851, loss_h: 134.946, loss_o: 1.674
# Episode: 14394, episode steps: 10, avg. reward: 9.32, loss_i: 8.7, loss_h: 138.576, loss_o: 1.575
# Episode: 14395, episode steps: 8, avg. reward: 9.32, loss_i: 8.027, loss_h: 108.045, loss_o: 1.716
# Episode: 14396, episode steps: 9, avg. reward: 9.32, loss_i: 8.386, loss_h: 126.826, loss_o: 1.58
# Episode: 14397, episode steps: 10, avg. reward: 9.32, loss_i: 8.152, loss_h: 155.0, loss_o: 1.582
# Episode: 14398, episode steps: 9, avg. reward: 9.32, loss_i: 6.822, loss_h: 178.858, loss_o: 1.608
# Episode: 14399, episode steps: 10, avg. reward: 9.32, loss_i: 8.891, loss_h: 159.2, loss_o: 1.703
# Episode: 14400, episode steps: 9, avg. reward: 9.32, loss_i: 9.031, loss_h: 160.671, loss_o: 1.71
# --TARGET UPDATED----TARGET UPDATED----TARGET UPDATED--
# i: [ True  True  True  True]
# h: [ True  True  True  True  True  True  True  True]
# o: [ True]
# --------------------------------------------------------------------------------
# Episode: 14401, episode steps: 10, avg. reward: 9.32, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 14402, episode steps: 9, avg. reward: 9.32, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 14403, episode steps: 9, avg. reward: 9.32, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 14404, episode steps: 9, avg. reward: 9.32, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 14405, episode steps: 8, avg. reward: 9.32, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 14406, episode steps: 9, avg. reward: 9.32, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 14407, episode steps: 9, avg. reward: 9.31, loss_i: nan, loss_h: nan, loss_o: nan
# Episode: 14408, episode steps: 10, avg. reward: 9.32, loss_i: 590.483, loss_h: 60.735, loss_o: 35.444
# Episode: 14409, episode steps: 10, avg. reward: 9.32, loss_i: 7.978, loss_h: 125.521, loss_o: 2.066
# Episode: 14410, episode steps: 9, avg. reward: 9.32, loss_i: 6.05, loss_h: 95.303, loss_o: 1.986
# Episode: 14411, episode steps: 8, avg. reward: 9.31, loss_i: 6.067, loss_h: 95.852, loss_o: 1.998
# Episode: 14412, episode steps: 9, avg. reward: 9.31, loss_i: 7.157, loss_h: 120.163, loss_o: 1.925
# Episode: 14413, episode steps: 10, avg. reward: 9.31, loss_i: 6.446, loss_h: 128.78, loss_o: 1.894
# Episode: 14414, episode steps: 11, avg. reward: 9.32, loss_i: 6.579, loss_h: 167.972, loss_o: 1.923
# Episode: 14415, episode steps: 10, avg. reward: 9.32, loss_i: 5.944, loss_h: 125.535, loss_o: 2.069
# Episode: 14416, episode steps: 10, avg. reward: 9.32, loss_i: 6.936, loss_h: 121.748, loss_o: 1.927
# Episode: 14417, episode steps: 10, avg. reward: 9.32, loss_i: 6.72, loss_h: 126.991, loss_o: 2.107
# Episode: 14418, episode steps: 10, avg. reward: 9.33, loss_i: 6.82, loss_h: 109.54, loss_o: 1.897
# Episode: 14419, episode steps: 9, avg. reward: 9.32, loss_i: 6.088, loss_h: 96.331, loss_o: 1.929
# Episode: 14420, episode steps: 8, avg. reward: 9.32, loss_i: 6.289, loss_h: 89.992, loss_o: 1.933
# Episode: 14421, episode steps: 10, avg. reward: 9.32, loss_i: 6.598, loss_h: 95.186, loss_o: 2.002
# Episode: 14422, episode steps: 9, avg. reward: 9.32, loss_i: 7.064, loss_h: 139.422, loss_o: 2.083
# Episode: 14423, episode steps: 8, avg. reward: 9.32, loss_i: 6.98, loss_h: 115.31, loss_o: 2.076
# Episode: 14424, episode steps: 9, avg. reward: 9.32, loss_i: 8.003, loss_h: 104.079, loss_o: 1.973
# Episode: 14425, episode steps: 9, avg. reward: 9.32, loss_i: 7.497, loss_h: 125.309, loss_o: 2.07
# Episode: 14426, episode steps: 10, avg. reward: 9.32, loss_i: 7.361, loss_h: 113.583, loss_o: 1.824
# Episode: 14427, episode steps: 10, avg. reward: 9.32, loss_i: 7.012, loss_h: 127.292, loss_o: 2.019
# Episode: 14428, episode steps: 9, avg. reward: 9.32, loss_i: 6.757, loss_h: 126.757, loss_o: 1.899
